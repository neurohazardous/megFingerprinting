# %% [markdown]
# ## License
# This file is part of the project megFingerprinting. All of megFingerprinting code is free software: you can redistribute it and/or modify it under the terms of the GNU General Public License as published by the Free Software Foundation, either version 3 of the License, or (at your option) any later version. megFingerprinting is distributed in the hope that it will be useful, but WITHOUT ANY WARRANTY; without even the implied warranty of MERCHANTABILITY or FITNESS FOR A PARTICULAR PURPOSE. See the GNU General Public License for more details. You should have received a copy of the GNU General Public License along with megFingerprinting. If not, see https://www.gnu.org/licenses/.

# %%
import difflib
from fuzzywuzzy import fuzz
import matplotlib.pyplot as plt
from mpl_toolkits.axes_grid1 import make_axes_locatable
import numpy as np
from os import listdir
from os.path import isfile, join
import pandas as pd
import re
import seaborn as sns
import scipy as sp
import scipy.io as sio
from sklearn.decomposition import PCA
from sklearn.metrics import accuracy_score
sns.set()
sns.set_style("whitegrid")
sns.set_palette(sns.color_palette("husl", 8))

# %% [markdown]
# # I. Subject Identifiability: Original Feature Space vs PCA Reconstructed
#
# ## Select appropriate folder for Training 1, 2, or valdiation

# %%
# Parameters
n_subs = 158 # Change here to get number of participants! 
n_feats = int(68*301)
n_measurements = 2

# %%
# Warangle data set into two big feature matrices
## USING FIRST TIME SEGEMNET VS LAST FOR VALIDATION
def prune_subject_csv(filename):
    '''
    This function takes in the subject's csv file from MATLAB, takes out the 
    doubled correlations (because of symmetry) and outputs a numpy array ready to be concatenated
    in the grand feature matrix
    Args:
        filename (string): Name of the csv matrix
    Returns: 
        sub_feat (np.array): Subject's features 
    '''
    #print(filename)
    print(filename[39:43])
    n_feats = int(68*301)
    sub_feat = np.zeros([1, (n_feats)+1]) # Number of unique values in corr matrix + subject label
    psd_matrix = pd.read_csv(filename, header=None)
    mat=np.asmatrix(psd_matrix)
    sub_feat[0, :-1]=mat.flatten()
    sub_feat[0, -1] = int(filename[39:43])    
    return sub_feat


# Get n subjects: both training and testing datasets
onlyfiles = [f for f in listdir('output/Short_PSD_source_1/fullband/') if isfile(join('output/Short_PSD_source_1/fullband/', f))]
sub_target = np.zeros([n_subs, (n_feats)+1])
sub_database = np.zeros([n_subs, (n_feats)+1])
iv = 0
it = 0
for iFile in sorted(onlyfiles)[0:(n_subs*2)]: 
    sub = 'output/Short_PSD_source_1/fullband/' + iFile
    print(sub)
    # [50] == 'v'
    # [59] == '2'
    if sub[50] == 'v':
        sub_target[iv, :] = prune_subject_csv(sub)
        iv += 1
    else:
        sub_database[it, :] = prune_subject_csv(sub)
        it += 1
# Out:
# output/Short_PSD_source_1/fullband/sub_0001_gamm__training_1.csv
# 0001
# output/Short_PSD_source_1/fullband/sub_0001_gamm__validation.csv
# 0001
# output/Short_PSD_source_1/fullband/sub_0002_gamm__training_1.csv
# 0002
# output/Short_PSD_source_1/fullband/sub_0002_gamm__validation.csv
# 0002
# output/Short_PSD_source_1/fullband/sub_0003_gamm__training_1.csv
# 0003
# output/Short_PSD_source_1/fullband/sub_0003_gamm__validation.csv
# 0003
# output/Short_PSD_source_1/fullband/sub_0004_gamm__training_1.csv
# 0004
# output/Short_PSD_source_1/fullband/sub_0004_gamm__validation.csv
# 0004
# output/Short_PSD_source_1/fullband/sub_0005_gamm__training_1.csv
# 0005
# output/Short_PSD_source_1/fullband/sub_0005_gamm__validation.csv
# 0005
# output/Short_PSD_source_1/fullband/sub_0006_gamm__training_1.csv
# 0006
# output/Short_PSD_source_1/fullband/sub_0006_gamm__validation.csv
# 0006
# output/Short_PSD_source_1/fullband/sub_0007_gamm__training_1.csv
# 0007
# output/Short_PSD_source_1/fullband/sub_0007_gamm__validation.csv
# 0007
# output/Short_PSD_source_1/fullband/sub_0008_gamm__training_1.csv
# 0008
# output/Short_PSD_source_1/fullband/sub_0008_gamm__validation.csv
# 0008
# output/Short_PSD_source_1/fullband/sub_0009_gamm__training_1.csv
# 0009
# output/Short_PSD_source_1/fullband/sub_0009_gamm__validation.csv
# 0009
# output/Short_PSD_source_1/fullband/sub_0011_gamm__training_1.csv
# 0011
# output/Short_PSD_source_1/fullband/sub_0011_gamm__validation.csv
# 0011
# output/Short_PSD_source_1/fullband/sub_0012_gamm__training_1.csv
# 0012
# output/Short_PSD_source_1/fullband/sub_0012_gamm__validation.csv
# 0012
# output/Short_PSD_source_1/fullband/sub_0013_gamm__training_1.csv
# 0013
# output/Short_PSD_source_1/fullband/sub_0013_gamm__validation.csv
# 0013
# output/Short_PSD_source_1/fullband/sub_0014_gamm__training_1.csv
# 0014
# output/Short_PSD_source_1/fullband/sub_0014_gamm__validation.csv
# 0014
# output/Short_PSD_source_1/fullband/sub_0015_gamm__training_1.csv
# 0015
# output/Short_PSD_source_1/fullband/sub_0015_gamm__validation.csv
# 0015
# output/Short_PSD_source_1/fullband/sub_0016_gamm__training_1.csv
# 0016
# output/Short_PSD_source_1/fullband/sub_0016_gamm__validation.csv
# 0016
# output/Short_PSD_source_1/fullband/sub_0018_gamm__training_1.csv
# 0018
# output/Short_PSD_source_1/fullband/sub_0018_gamm__validation.csv
# 0018
# output/Short_PSD_source_1/fullband/sub_0020_gamm__training_1.csv
# 0020
# output/Short_PSD_source_1/fullband/sub_0020_gamm__validation.csv
# 0020
# output/Short_PSD_source_1/fullband/sub_0021_gamm__training_1.csv
# 0021
# output/Short_PSD_source_1/fullband/sub_0021_gamm__validation.csv
# 0021
# output/Short_PSD_source_1/fullband/sub_0022_gamm__training_1.csv
# 0022
# output/Short_PSD_source_1/fullband/sub_0022_gamm__validation.csv
# 0022
# output/Short_PSD_source_1/fullband/sub_0023_gamm__training_1.csv
# 0023
# output/Short_PSD_source_1/fullband/sub_0023_gamm__validation.csv
# 0023
# output/Short_PSD_source_1/fullband/sub_0024_gamm__training_1.csv
# 0024
# output/Short_PSD_source_1/fullband/sub_0024_gamm__validation.csv
# 0024
# output/Short_PSD_source_1/fullband/sub_0025_gamm__training_1.csv
# 0025
# output/Short_PSD_source_1/fullband/sub_0025_gamm__validation.csv
# 0025
# output/Short_PSD_source_1/fullband/sub_0026_gamm__training_1.csv
# 0026
# output/Short_PSD_source_1/fullband/sub_0026_gamm__validation.csv
# 0026
# output/Short_PSD_source_1/fullband/sub_0028_gamm__training_1.csv
# 0028
# output/Short_PSD_source_1/fullband/sub_0028_gamm__validation.csv
# 0028
# output/Short_PSD_source_1/fullband/sub_0029_gamm__training_1.csv
# 0029
# output/Short_PSD_source_1/fullband/sub_0029_gamm__validation.csv
# 0029
# output/Short_PSD_source_1/fullband/sub_0030_gamm__training_1.csv
# 0030
# output/Short_PSD_source_1/fullband/sub_0030_gamm__validation.csv
# 0030
# output/Short_PSD_source_1/fullband/sub_0031_gamm__training_1.csv
# 0031
# output/Short_PSD_source_1/fullband/sub_0031_gamm__validation.csv
# 0031
# output/Short_PSD_source_1/fullband/sub_0032_gamm__training_1.csv
# 0032
# output/Short_PSD_source_1/fullband/sub_0032_gamm__validation.csv
# 0032
# output/Short_PSD_source_1/fullband/sub_0033_gamm__training_1.csv
# 0033
# output/Short_PSD_source_1/fullband/sub_0033_gamm__validation.csv
# 0033
# output/Short_PSD_source_1/fullband/sub_0035_gamm__training_1.csv
# 0035
# output/Short_PSD_source_1/fullband/sub_0035_gamm__validation.csv
# 0035
# output/Short_PSD_source_1/fullband/sub_0036_gamm__training_1.csv
# 0036
# output/Short_PSD_source_1/fullband/sub_0036_gamm__validation.csv
# 0036
# output/Short_PSD_source_1/fullband/sub_0037_gamm__training_1.csv
# 0037
# output/Short_PSD_source_1/fullband/sub_0037_gamm__validation.csv
# 0037
# output/Short_PSD_source_1/fullband/sub_0040_gamm__training_1.csv
# 0040
# output/Short_PSD_source_1/fullband/sub_0040_gamm__validation.csv
# 0040
# output/Short_PSD_source_1/fullband/sub_0041_gamm__training_1.csv
# 0041
# output/Short_PSD_source_1/fullband/sub_0041_gamm__validation.csv
# 0041
# output/Short_PSD_source_1/fullband/sub_0045_gamm__training_1.csv
# 0045
# output/Short_PSD_source_1/fullband/sub_0045_gamm__validation.csv
# 0045
# output/Short_PSD_source_1/fullband/sub_0046_gamm__training_1.csv
# 0046
# output/Short_PSD_source_1/fullband/sub_0046_gamm__validation.csv
# 0046
# output/Short_PSD_source_1/fullband/sub_0047_gamm__training_1.csv
# 0047
# output/Short_PSD_source_1/fullband/sub_0047_gamm__validation.csv
# 0047
# output/Short_PSD_source_1/fullband/sub_0048_gamm__training_1.csv
# 0048
# output/Short_PSD_source_1/fullband/sub_0048_gamm__validation.csv
# 0048
# output/Short_PSD_source_1/fullband/sub_0049_gamm__training_1.csv
# 0049
# output/Short_PSD_source_1/fullband/sub_0049_gamm__validation.csv
# 0049
# output/Short_PSD_source_1/fullband/sub_0050_gamm__training_1.csv
# 0050
# output/Short_PSD_source_1/fullband/sub_0050_gamm__validation.csv
# 0050
# output/Short_PSD_source_1/fullband/sub_0051_gamm__training_1.csv
# 0051
# output/Short_PSD_source_1/fullband/sub_0051_gamm__validation.csv
# 0051
# output/Short_PSD_source_1/fullband/sub_0052_gamm__training_1.csv
# 0052
# output/Short_PSD_source_1/fullband/sub_0052_gamm__validation.csv
# 0052
# output/Short_PSD_source_1/fullband/sub_0053_gamm__training_1.csv
# 0053
# output/Short_PSD_source_1/fullband/sub_0053_gamm__validation.csv
# 0053
# output/Short_PSD_source_1/fullband/sub_0054_gamm__training_1.csv
# 0054
# output/Short_PSD_source_1/fullband/sub_0054_gamm__validation.csv
# 0054
# output/Short_PSD_source_1/fullband/sub_0055_gamm__training_1.csv
# 0055
# output/Short_PSD_source_1/fullband/sub_0055_gamm__validation.csv
# 0055
# output/Short_PSD_source_1/fullband/sub_0056_gamm__training_1.csv
# 0056
# output/Short_PSD_source_1/fullband/sub_0056_gamm__validation.csv
# 0056
# output/Short_PSD_source_1/fullband/sub_0058_gamm__training_1.csv
# 0058
# output/Short_PSD_source_1/fullband/sub_0058_gamm__validation.csv
# 0058
# output/Short_PSD_source_1/fullband/sub_0059_gamm__training_1.csv
# 0059
# output/Short_PSD_source_1/fullband/sub_0059_gamm__validation.csv
# 0059
# output/Short_PSD_source_1/fullband/sub_0060_gamm__training_1.csv
# 0060
# output/Short_PSD_source_1/fullband/sub_0060_gamm__validation.csv
# 0060
# output/Short_PSD_source_1/fullband/sub_0061_gamm__training_1.csv
# 0061
# output/Short_PSD_source_1/fullband/sub_0061_gamm__validation.csv
# 0061
# output/Short_PSD_source_1/fullband/sub_0062_gamm__training_1.csv
# 0062
# output/Short_PSD_source_1/fullband/sub_0062_gamm__validation.csv
# 0062
# output/Short_PSD_source_1/fullband/sub_0063_gamm__training_1.csv
# 0063
# output/Short_PSD_source_1/fullband/sub_0063_gamm__validation.csv
# 0063
# output/Short_PSD_source_1/fullband/sub_0064_gamm__training_1.csv
# 0064
# output/Short_PSD_source_1/fullband/sub_0064_gamm__validation.csv
# 0064
# output/Short_PSD_source_1/fullband/sub_0065_gamm__training_1.csv
# 0065
# output/Short_PSD_source_1/fullband/sub_0065_gamm__validation.csv
# 0065
# output/Short_PSD_source_1/fullband/sub_0066_gamm__training_1.csv
# 0066
# output/Short_PSD_source_1/fullband/sub_0066_gamm__validation.csv
# 0066
# output/Short_PSD_source_1/fullband/sub_0068_gamm__training_1.csv
# 0068
# output/Short_PSD_source_1/fullband/sub_0068_gamm__validation.csv
# 0068
# output/Short_PSD_source_1/fullband/sub_0069_gamm__training_1.csv
# 0069
# output/Short_PSD_source_1/fullband/sub_0069_gamm__validation.csv
# 0069
# output/Short_PSD_source_1/fullband/sub_0070_gamm__training_1.csv
# 0070
# output/Short_PSD_source_1/fullband/sub_0070_gamm__validation.csv
# 0070
# output/Short_PSD_source_1/fullband/sub_0071_gamm__training_1.csv
# 0071
# output/Short_PSD_source_1/fullband/sub_0071_gamm__validation.csv
# 0071
# output/Short_PSD_source_1/fullband/sub_0074_gamm__training_1.csv
# 0074
# output/Short_PSD_source_1/fullband/sub_0074_gamm__validation.csv
# 0074
# output/Short_PSD_source_1/fullband/sub_0075_gamm__training_1.csv
# 0075
# output/Short_PSD_source_1/fullband/sub_0075_gamm__validation.csv
# 0075
# output/Short_PSD_source_1/fullband/sub_0076_gamm__training_1.csv
# 0076
# output/Short_PSD_source_1/fullband/sub_0076_gamm__validation.csv
# 0076
# output/Short_PSD_source_1/fullband/sub_0077_gamm__training_1.csv
# 0077
# output/Short_PSD_source_1/fullband/sub_0077_gamm__validation.csv
# 0077
# output/Short_PSD_source_1/fullband/sub_0078_gamm__training_1.csv
# 0078
# output/Short_PSD_source_1/fullband/sub_0078_gamm__validation.csv
# 0078
# output/Short_PSD_source_1/fullband/sub_0079_gamm__training_1.csv
# 0079
# output/Short_PSD_source_1/fullband/sub_0079_gamm__validation.csv
# 0079
# output/Short_PSD_source_1/fullband/sub_0080_gamm__training_1.csv
# 0080
# output/Short_PSD_source_1/fullband/sub_0080_gamm__validation.csv
# 0080
# output/Short_PSD_source_1/fullband/sub_0082_gamm__training_1.csv
# 0082
# output/Short_PSD_source_1/fullband/sub_0082_gamm__validation.csv
# 0082
# output/Short_PSD_source_1/fullband/sub_0083_gamm__training_1.csv
# 0083
# output/Short_PSD_source_1/fullband/sub_0083_gamm__validation.csv
# 0083
# output/Short_PSD_source_1/fullband/sub_0084_gamm__training_1.csv
# 0084
# output/Short_PSD_source_1/fullband/sub_0084_gamm__validation.csv
# 0084
# output/Short_PSD_source_1/fullband/sub_0085_gamm__training_1.csv
# 0085
# output/Short_PSD_source_1/fullband/sub_0085_gamm__validation.csv
# 0085
# output/Short_PSD_source_1/fullband/sub_0086_gamm__training_1.csv
# 0086
# output/Short_PSD_source_1/fullband/sub_0086_gamm__validation.csv
# 0086
# output/Short_PSD_source_1/fullband/sub_0087_gamm__training_1.csv
# 0087
# output/Short_PSD_source_1/fullband/sub_0087_gamm__validation.csv
# 0087
# output/Short_PSD_source_1/fullband/sub_0088_gamm__training_1.csv
# 0088
# output/Short_PSD_source_1/fullband/sub_0088_gamm__validation.csv
# 0088
# output/Short_PSD_source_1/fullband/sub_0089_gamm__training_1.csv
# 0089
# output/Short_PSD_source_1/fullband/sub_0089_gamm__validation.csv
# 0089
# output/Short_PSD_source_1/fullband/sub_0090_gamm__training_1.csv
# 0090
# output/Short_PSD_source_1/fullband/sub_0090_gamm__validation.csv
# 0090
# output/Short_PSD_source_1/fullband/sub_0091_gamm__training_1.csv
# 0091
# output/Short_PSD_source_1/fullband/sub_0091_gamm__validation.csv
# 0091
# output/Short_PSD_source_1/fullband/sub_0093_gamm__training_1.csv
# 0093
# output/Short_PSD_source_1/fullband/sub_0093_gamm__validation.csv
# 0093
# output/Short_PSD_source_1/fullband/sub_0094_gamm__training_1.csv
# 0094
# output/Short_PSD_source_1/fullband/sub_0094_gamm__validation.csv
# 0094
# output/Short_PSD_source_1/fullband/sub_0095_gamm__training_1.csv
# 0095
# output/Short_PSD_source_1/fullband/sub_0095_gamm__validation.csv
# 0095
# output/Short_PSD_source_1/fullband/sub_0096_gamm__training_1.csv
# 0096
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-4-5326f8b3dad5> in <module>
#      36         iv += 1
#      37     else:
# ---> 38         sub_database[it, :] = prune_subject_csv(sub)
#      39         it += 1
#      40
#
# IndexError: index 158 is out of bounds for axis 0 with size 158

# %%
# Warangle data set into two big feature matrices
## USE SECOND WINDOW VS LAST 
def prune_subject_csv(filename):
    '''
    This function takes in the subject's csv file from MATLAB, takes out the 
    doubled correlations (because of symmetry) and outputs a numpy array ready to be concatenated
    in the grand feature matrix
    Args:
        filename (string): Name of the csv matrix
    Returns: 
        sub_feat (np.array): Subject's features 
    '''
    #print(filename)
    print(filename[39:43])
    n_feats = int(68*301)
    sub_feat = np.zeros([1, (n_feats)+1]) # Number of unique values in corr matrix + subject label
    psd_matrix = pd.read_csv(filename, header=None)
    mat=np.asmatrix(psd_matrix)
    sub_feat[0, :-1]=mat.flatten()
    sub_feat[0, -1] = int(filename[39:43])    
    return sub_feat


# Get n subjects: both training and testing datasets
onlyfiles = [f for f in listdir('output/Short_PSD_source_2/fullband/') if isfile(join('output/Short_PSD_source_2/fullband/', f))]
sub_target = np.zeros([n_subs, (n_feats)+1])
sub_database = np.zeros([n_subs, (n_feats)+1])
iv = 0
it = 0
for iFile in sorted(onlyfiles)[0:(n_subs*2)]: 
    sub = 'output/Short_PSD_source_2/fullband/' + iFile
    print(sub)
    # [50] == 'v'
    # [59] == '2'
    if sub[50] == 'v':
        sub_target[iv, :] = prune_subject_csv(sub)
        iv += 1
    else:
        sub_database[it, :] = prune_subject_csv(sub)
        it += 1
# Out:
# output/Short_PSD_source_2/fullband/sub_0001_gamm__training_2.csv
# 0001
# output/Short_PSD_source_2/fullband/sub_0001_gamm__validation.csv
# 0001
# output/Short_PSD_source_2/fullband/sub_0002_gamm__training_2.csv
# 0002
# output/Short_PSD_source_2/fullband/sub_0002_gamm__validation.csv
# 0002
# output/Short_PSD_source_2/fullband/sub_0003_gamm__training_2.csv
# 0003
# output/Short_PSD_source_2/fullband/sub_0003_gamm__validation.csv
# 0003
# output/Short_PSD_source_2/fullband/sub_0004_gamm__training_2.csv
# 0004
# output/Short_PSD_source_2/fullband/sub_0004_gamm__validation.csv
# 0004
# output/Short_PSD_source_2/fullband/sub_0005_gamm__training_2.csv
# 0005
# output/Short_PSD_source_2/fullband/sub_0005_gamm__validation.csv
# 0005
# output/Short_PSD_source_2/fullband/sub_0006_gamm__training_2.csv
# 0006
# output/Short_PSD_source_2/fullband/sub_0006_gamm__validation.csv
# 0006
# output/Short_PSD_source_2/fullband/sub_0007_gamm__training_2.csv
# 0007
# output/Short_PSD_source_2/fullband/sub_0007_gamm__validation.csv
# 0007
# output/Short_PSD_source_2/fullband/sub_0008_gamm__training_2.csv
# 0008
# output/Short_PSD_source_2/fullband/sub_0008_gamm__validation.csv
# 0008
# output/Short_PSD_source_2/fullband/sub_0009_gamm__training_2.csv
# 0009
# output/Short_PSD_source_2/fullband/sub_0009_gamm__validation.csv
# 0009
# output/Short_PSD_source_2/fullband/sub_0011_gamm__training_2.csv
# 0011
# output/Short_PSD_source_2/fullband/sub_0011_gamm__validation.csv
# 0011
# output/Short_PSD_source_2/fullband/sub_0012_gamm__training_2.csv
# 0012
# output/Short_PSD_source_2/fullband/sub_0012_gamm__validation.csv
# 0012
# output/Short_PSD_source_2/fullband/sub_0013_gamm__training_2.csv
# 0013
# output/Short_PSD_source_2/fullband/sub_0013_gamm__validation.csv
# 0013
# output/Short_PSD_source_2/fullband/sub_0014_gamm__training_2.csv
# 0014
# output/Short_PSD_source_2/fullband/sub_0014_gamm__validation.csv
# 0014
# output/Short_PSD_source_2/fullband/sub_0015_gamm__training_2.csv
# 0015
# output/Short_PSD_source_2/fullband/sub_0015_gamm__validation.csv
# 0015
# output/Short_PSD_source_2/fullband/sub_0016_gamm__training_2.csv
# 0016
# 0185
# output/Short_PSD_source_2/fullband/sub_0185_gamm__validation.csv
# 0185
# output/Short_PSD_source_2/fullband/sub_0186_gamm__training_2.csv
# 0186
# output/Short_PSD_source_2/fullband/sub_0186_gamm__validation.csv
# 0186
# output/Short_PSD_source_2/fullband/sub_0187_gamm__training_2.csv
# 0187
# output/Short_PSD_source_2/fullband/sub_0187_gamm__validation.csv
# 0187
# output/Short_PSD_source_2/fullband/sub_0188_gamm__training_2.csv
# 0188
# output/Short_PSD_source_2/fullband/sub_0188_gamm__validation.csv
# 0188
# output/Short_PSD_source_2/fullband/sub_0189_gamm__training_2.csv
# 0189
# output/Short_PSD_source_2/fullband/sub_0189_gamm__validation.csv
# 0189
# output/Short_PSD_source_2/fullband/sub_0190_gamm__training_2.csv
# 0190
# output/Short_PSD_source_2/fullband/sub_0190_gamm__validation.csv
# 0190

# %%
# Warangle data set into two big feature matrices
## USE FIRST AND SECOND WINDOW 
def prune_subject_csv(filename):
    '''
    This function takes in the subject's csv file from MATLAB, takes out the 
    doubled correlations (because of symmetry) and outputs a numpy array ready to be concatenated
    in the grand feature matrix
    Args:
        filename (string): Name of the csv matrix
    Returns: 
        sub_feat (np.array): Subject's features 
    '''
    #print(filename)
    print(filename[39:43])
    n_feats = int(68*301)
    sub_feat = np.zeros([1, (n_feats)+1]) # Number of unique values in corr matrix + subject label
    psd_matrix = pd.read_csv(filename, header=None)
    mat=np.asmatrix(psd_matrix)
    sub_feat[0, :-1]=mat.flatten()
    sub_feat[0, -1] = int(filename[39:43])    
    return sub_feat


# Get n subjects: both training and testing datasets
onlyfiles = [f for f in listdir('output/Short_PSD_source_3/fullband/') if isfile(join('output/Short_PSD_source_3/fullband/', f))]
sub_target = np.zeros([n_subs, (n_feats)+1])
sub_database = np.zeros([n_subs, (n_feats)+1])
iv = 0
it = 0
for iFile in sorted(onlyfiles)[0:(n_subs*2)]: 
    sub = 'output/Short_PSD_source_3/fullband/' + iFile
    print(sub)
    # [50] == 'v'
    # [59] == '2'
    if sub[59] == '2':
        sub_target[iv, :] = prune_subject_csv(sub)
        iv += 1
    else:
        sub_database[it, :] = prune_subject_csv(sub)
        it += 1
# Out:
# output/Short_PSD_source_3/fullband/sub_0001_gamm__training_1.csv
# 0001
# output/Short_PSD_source_3/fullband/sub_0001_gamm__training_2.csv
# 0001
# output/Short_PSD_source_3/fullband/sub_0002_gamm__training_1.csv
# 0002
# output/Short_PSD_source_3/fullband/sub_0002_gamm__training_2.csv
# 0002
# output/Short_PSD_source_3/fullband/sub_0003_gamm__training_1.csv
# 0003
# output/Short_PSD_source_3/fullband/sub_0003_gamm__training_2.csv
# 0003
# output/Short_PSD_source_3/fullband/sub_0004_gamm__training_1.csv
# 0004
# output/Short_PSD_source_3/fullband/sub_0004_gamm__training_2.csv
# 0004
# output/Short_PSD_source_3/fullband/sub_0005_gamm__training_1.csv
# 0005
# output/Short_PSD_source_3/fullband/sub_0005_gamm__training_2.csv
# 0005
# output/Short_PSD_source_3/fullband/sub_0006_gamm__training_1.csv
# 0169
# output/Short_PSD_source_3/fullband/sub_0169_gamm__training_2.csv
# 0169
# output/Short_PSD_source_3/fullband/sub_0170_gamm__training_1.csv
# 0170
# output/Short_PSD_source_3/fullband/sub_0170_gamm__training_2.csv
# 0170
# output/Short_PSD_source_3/fullband/sub_0172_gamm__training_1.csv
# 0172
# output/Short_PSD_source_3/fullband/sub_0172_gamm__training_2.csv
# 0172
# output/Short_PSD_source_3/fullband/sub_0174_gamm__training_1.csv
# 0174
# output/Short_PSD_source_3/fullband/sub_0174_gamm__training_2.csv
# 0174
# output/Short_PSD_source_3/fullband/sub_0175_gamm__training_1.csv
# 0175
# output/Short_PSD_source_3/fullband/sub_0175_gamm__training_2.csv
# 0175
# output/Short_PSD_source_3/fullband/sub_0176_gamm__training_1.csv
# 0176
# output/Short_PSD_source_3/fullband/sub_0176_gamm__training_2.csv
# 0176
# output/Short_PSD_source_3/fullband/sub_0177_gamm__training_1.csv
# 0177
# output/Short_PSD_source_3/fullband/sub_0177_gamm__training_2.csv
# 0177
# output/Short_PSD_source_3/fullband/sub_0179_gamm__training_1.csv
# 0179
# output/Short_PSD_source_3/fullband/sub_0179_gamm__training_2.csv
# 0179
# output/Short_PSD_source_3/fullband/sub_0181_gamm__training_1.csv
# 0181
# output/Short_PSD_source_3/fullband/sub_0181_gamm__training_2.csv
# 0181
# output/Short_PSD_source_3/fullband/sub_0183_gamm__training_1.csv
# 0183
# output/Short_PSD_source_3/fullband/sub_0183_gamm__training_2.csv
# 0183
# output/Short_PSD_source_3/fullband/sub_0184_gamm__training_1.csv
# 0184
# output/Short_PSD_source_3/fullband/sub_0184_gamm__training_2.csv
# 0184
# output/Short_PSD_source_3/fullband/sub_0185_gamm__training_1.csv
# 0185
# output/Short_PSD_source_3/fullband/sub_0185_gamm__training_2.csv
# 0185
# output/Short_PSD_source_3/fullband/sub_0186_gamm__training_1.csv
# 0186
# output/Short_PSD_source_3/fullband/sub_0186_gamm__training_2.csv
# 0186
# output/Short_PSD_source_3/fullband/sub_0187_gamm__training_1.csv
# 0187
# output/Short_PSD_source_3/fullband/sub_0187_gamm__training_2.csv
# 0187
# output/Short_PSD_source_3/fullband/sub_0188_gamm__training_1.csv
# 0188
# output/Short_PSD_source_3/fullband/sub_0188_gamm__training_2.csv
# 0188
# output/Short_PSD_source_3/fullband/sub_0189_gamm__training_1.csv
# 0189
# output/Short_PSD_source_3/fullband/sub_0189_gamm__training_2.csv
# 0189
# output/Short_PSD_source_3/fullband/sub_0190_gamm__training_1.csv
# 0190
# output/Short_PSD_source_3/fullband/sub_0190_gamm__training_2.csv
# 0190

# %%
# Correlations can be computed as the dot product between two z-scored vectors
z_target = sp.stats.zscore(sub_target[:, :-1], axis = 1)
z_database = sp.stats.zscore(sub_database[:,:-1], axis = 1)
predictions = z_target.dot(z_database.transpose()) / (sub_database.shape[1] - 1) # target, database
target_from_database = accuracy_score(range(n_subs), predictions.argmax(axis = 1))
database_from_target = accuracy_score(range(n_subs), predictions.argmax(axis = 0))

print('When predicting the target from the database, we get a ' + str(target_from_database*100)[0:5] + '% accuracy')
print('When predicting the database from the target, we get a ' + str(database_from_target*100)[0:5] + '% accuracy')
# Out:
# When predicting the target from the database, we get a 90.50% accuracy
# When predicting the database from the target, we get a 93.03% accuracy

# %% [markdown]
# # We get pretty high raw accuracy scores (similar to what Finn et al., 2015). Now we look at the influence of using a PCA reconstruction (i.e. the framework Amico & Goni suggested) on the feature space

# %%
# Take feature matrix of each subject and put it in one, big matrix (n_subs * 2, features)
fc = np.concatenate((sub_target[:, :-1], sub_database[:, :-1]), axis = 0)
labels = np.concatenate((sub_target[:, -1], sub_database[:, -1]), axis = 0)
steps = np.concatenate((np.array([2, 5]), np.arange(10, (n_subs*2) ,10)), axis = 0) # 2, 5, 10 - n_subs*2 in 10 
pca_target_from_database = np.zeros(len(steps))
pca_database_from_target = np.zeros(len(steps))
pca_self_id = np.zeros((len(steps), n_subs))
# Get the PCA decomposition in an iterative manner and calculate raw accuracy at each step of the way 
for i in range(len(steps)):
    # PCA reconstruction usin i components
    pca = PCA(n_components = steps[i]) 
    pca.fit(fc) # Estimate the components (using an SVD on the centered fc)
    fc_pca = pca.transform(fc) # Calculate the loadings
    fc_recon = pca.inverse_transform(fc_pca) # Get projection onto components in signal space and add back means
    
    # Accuracy and self-identifiability
    pca_sub_target = fc_recon[:n_subs, :]
    pca_sub_database = fc_recon[n_subs:, :]
    pca_z_target = sp.stats.zscore(pca_sub_target, axis = 1)
    pca_z_database = sp.stats.zscore(pca_sub_database, axis = 1)
    pca_predictions = pca_z_target.dot(pca_z_database.transpose()) / (sub_database.shape[1] - 1) # target, database
    pca_target_from_database[i] = accuracy_score(range(n_subs), pca_predictions.argmax(axis = 1))
    pca_database_from_target[i] = accuracy_score(range(n_subs), pca_predictions.argmax(axis = 0))
    pca_self_id[i, :] = np.diagonal(sp.stats.zscore(pca_predictions, axis = 1))
    
# For the figure, we also get self-identifiability and reconstructed self-identifiability
self_id = np.diagonal(sp.stats.zscore(predictions, axis = 1))

# %%
# Get the fig initiated
fig, axs = plt.subplots(1,3, figsize=(30, 10))
fig.subplots_adjust(hspace = .2, wspace = .2)
axs = axs.ravel()

# Variance explained vs Components
axs[0].plot(pca.explained_variance_ratio_*100, linewidth=2)
axs[0].set_xlabel('Components')
axs[0].set_ylabel('Variance Explained [%]')
axs[0].set_title('PCA reconstruction', size = 'x-large')

# Accuracy vs Components
axs[1].plot(steps, pca_target_from_database*100, linewidth = 2, label = 'Reconstructed')
axs[1].plot(steps, target_from_database.repeat(len(steps))*100, linewidth = 2, label = 'Original')
axs[1].set_xlabel('Components')
axs[1].set_ylabel('Accuracy [%]')
axs[1].set_title('Accuracy as a function of PCs', size = 'x-large')
axs[1].legend(fontsize = 13, frameon = True)

# Self identifiability vs Components
axs[2].plot(steps, pca_self_id.mean(axis = 1), linewidth = 2, label = 'Reconstructed')
axs[2].plot(steps, self_id.mean().repeat(len(steps)), linewidth = 2, label = 'Original')
axs[2].set_xlabel('Components')
axs[2].set_ylabel('Self identifiability')
axs[2].set_title('Self-Identifiability as a function of PCs', size = 'x-large')
axs[2].legend(fontsize = 13, frameon = True)

sns.despine()
plt.show()

# %%
# Get the PCA reconstruction from the number of components that give us the max self_identifiability 
pca = PCA(n_components = steps[np.argmax(pca_self_id.mean(axis = 1))]) 
pca.fit(fc) # Estimate the components (using an SVD on the centered fc)
fc_pca = pca.transform(fc) # Calculate the loadings
fc_recon = pca.inverse_transform(fc_pca) # Get projection onto components in signal space

# Accuracy and self-identifiability
pca_sub_target = fc_recon[:n_subs, :]
pca_sub_database = fc_recon[n_subs:, :]
pca_z_target = sp.stats.zscore(pca_sub_target, axis = 1)
pca_z_database = sp.stats.zscore(pca_sub_database, axis = 1)
pca_predictions = pca_z_target.dot(pca_z_database.transpose()) / (sub_database.shape[1] - 1) # target, database
pca_target_from_database = accuracy_score(range(n_subs), pca_predictions.argmax(axis = 1))
pca_database_from_target = accuracy_score(range(n_subs), pca_predictions.argmax(axis = 0))
pca_self_id = np.diagonal(sp.stats.zscore(pca_predictions, axis = 1))

print('When predicting the reconstructed target from the reconstructed database, we get a ' + str(pca_target_from_database) + ' accuracy')
print('When predicting the reconstructed database from the reconstructed target, we get a ' + str(pca_database_from_target) + ' accuracy')
# Out:
# When predicting the reconstructed target from the reconstructed database, we get a 0.8987341772151899 accuracy
# When predicting the reconstructed database from the reconstructed target, we get a 0.9177215189873418 accuracy

# %%
import numpy as np
vp_original = np.concatenate((np.expand_dims(self_id, axis = 1), np.expand_dims(np.repeat('Original', n_subs), axis = 1)), axis = 1)
vp_recon = np.concatenate((np.expand_dims(pca_self_id, axis = 1), np.expand_dims(np.repeat('Reconstructed', n_subs), axis = 1)), axis = 1)
self_id_grand = np.concatenate((vp_original, vp_recon), axis = 0)
self_id_plot = pd.DataFrame(data = self_id_grand, columns = ['Self Identifiability', 'Feature Space'])
self_id_plot['Self Identifiability'] = self_id_plot['Self Identifiability'].astype(float)
self_id_plot['Feature Space'] = self_id_plot['Feature Space'].astype('category', ordered = False, categories = ['Original', 'Reconstructed'])

plt.figure(figsize=(10, 10))
axs = sns.violinplot(x = 'Feature Space', y = 'Self Identifiability', data = self_id_plot)
axs.set_title('Self-identifiability: Original and Reconstructed Space', size = 'x-large')
sns.despine()
plt.show()

plt.figure(figsize=(10, 10))
axs = sns.heatmap(predictions, cmap='Reds', square=True)
plt.figure(figsize=(10, 10))
axs = sns.heatmap(pca_predictions, cmap='Reds', square=True)
# Out:
# /Users/jasondsc/opt/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3331: FutureWarning: specifying 'categories' or 'ordered' in .astype() is deprecated; pass a CategoricalDtype instead
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %% [markdown]
# # II. Edgewise contributions to identifiability
#
# ## Now that we know subjects are highly identifiable, we ask the question: what edges are driving this? Are there edges that are more important than others? To do so, we compare three measurements: differential power and group consistency (Finn et al., 2015) and interclass correlation coefficient
#
# ## We start with differential power with both the reconstructed and the original data

# %%
differential_power = np.zeros(z_target.shape[1])
pca_differential_power = np.zeros(pca_z_target.shape[1])
for iEdge in range(z_target.shape[1]):
    p_e = np.zeros(n_subs)
    pca_p_e = np.zeros(n_subs)
    for iSubject in range(n_subs):
        # Original
        rho_ii = z_target[iSubject, iEdge] * z_database[iSubject, iEdge] #subjects to itself; the higher, the more consistent across target and database measurements
        rho_ij = z_target[iSubject, iEdge] * z_database[np.arange(n_subs)!= iSubject, iEdge]
        rho_ji = z_database[iSubject, iEdge] * z_target[np.arange(n_subs)!= iSubject, iEdge]
        prob_ij = (rho_ij > rho_ii).astype(float)
        prob_ji = (rho_ji > rho_ii).astype(float)
        p_e[iSubject] = (prob_ij.sum() + prob_ji.sum())/(2.*(n_subs - 1))
        if p_e[iSubject] == 0:
            p_e[iSubject] = 1/(2.*(n_subs - 1))
        
        # Reconstructed
        pca_rho_ii = pca_z_target[iSubject, iEdge] * pca_z_database[iSubject, iEdge] #subjects to itself; the higher, the more consistent across target and database measurements
        pca_rho_ij = pca_z_target[iSubject, iEdge] * pca_z_database[np.arange(n_subs)!= iSubject, iEdge]
        pca_rho_ji = pca_z_database[iSubject, iEdge] * pca_z_target[np.arange(n_subs)!= iSubject, iEdge]  
        pca_prob_ij = (pca_rho_ij > pca_rho_ii).astype(float)
        pca_prob_ji = (pca_rho_ji > pca_rho_ii).astype(float)
        pca_p_e[iSubject] = (pca_prob_ij.sum() + pca_prob_ji.sum())/(2.*(n_subs - 1))
        if pca_p_e[iSubject] == 0:
            pca_p_e[iSubject] = 1/(2.*(n_subs - 1))
            
    differential_power[iEdge] = (-1 * np.log(p_e)).sum() 
    pca_differential_power[iEdge] = (-1 * np.log(pca_p_e)).sum() 
    
min_dp = np.min(differential_power)
max_dp = np.max(differential_power)
pca_min_dp = np.min(pca_differential_power)
pca_max_dp = np.max(pca_differential_power)

# %%
#print(differential_power)
reshaped_differential_power=np.reshape(differential_power, (68,-1))
reshaped_differential_power.shape
reshaped_pca_differential_power=np.reshape(pca_differential_power, (68,-1))
reshaped_pca_differential_power.shape

atlasdk=pd.read_csv('/Users/jasondsc/Desktop/McGill/python_codes/dependencies/desikan_yeo_68.csv', header=None)
#print(differential_power)
plt.figure(figsize=(15, 10))
axs = sns.heatmap(reshaped_differential_power, cmap='Reds')
plt.xticks(np.arange(0, 300, 5), np.arange(0, 150, 0.5)[range(0,300,5)])
plt.yticks(np.arange(0, 68, 1),atlasdk[atlasdk.columns[0]], rotation=0)

plt.figure(figsize=(15, 10))
axs = sns.heatmap(reshaped_pca_differential_power, cmap='Reds')
plt.xticks(np.arange(0, 300, 5), np.arange(0, 150, 0.5)[range(0,300,5)])
plt.yticks(np.arange(0, 68, 1),atlasdk[atlasdk.columns[0]], rotation=0)
# Out:
# ([<matplotlib.axis.YTick at 0x7fd574d95990>,
#   <matplotlib.axis.YTick at 0x7fd574d8efd0>,
#   <matplotlib.axis.YTick at 0x7fd574d7ebd0>,
#   <matplotlib.axis.YTick at 0x7fd576945e10>,
#   <matplotlib.axis.YTick at 0x7fd57694f450>,
#   <matplotlib.axis.YTick at 0x7fd57694fa90>,
#   <matplotlib.axis.YTick at 0x7fd576954190>,
#   <matplotlib.axis.YTick at 0x7fd576954790>,
#   <matplotlib.axis.YTick at 0x7fd576954dd0>,
#   <matplotlib.axis.YTick at 0x7fd576954690>,
#   <matplotlib.axis.YTick at 0x7fd576945d90>,
#   <matplotlib.axis.YTick at 0x7fd576ea6250>,
#   <matplotlib.axis.YTick at 0x7fd576ea68d0>,
#   <matplotlib.axis.YTick at 0x7fd576ea6f10>,
#   <matplotlib.axis.YTick at 0x7fd576ead590>,
#   <matplotlib.axis.YTick at 0x7fd576eadbd0>,
#   <matplotlib.axis.YTick at 0x7fd576eb4250>,
#   <matplotlib.axis.YTick at 0x7fd576eb4890>,
#   <matplotlib.axis.YTick at 0x7fd576eb4ed0>,
#   <matplotlib.axis.YTick at 0x7fd576ead990>,
#   <matplotlib.axis.YTick at 0x7fd576eadd50>,
#   <matplotlib.axis.YTick at 0x7fd576ebc4d0>,
#   <matplotlib.axis.YTick at 0x7fd576ebcb10>,
#   <matplotlib.axis.YTick at 0x7fd576ec31d0>,
#   <matplotlib.axis.YTick at 0x7fd576ec37d0>,
#   <matplotlib.axis.YTick at 0x7fd576ec3e10>,
#   <matplotlib.axis.YTick at 0x7fd576ec9490>,
#   <matplotlib.axis.YTick at 0x7fd576ec9ad0>,
#   <matplotlib.axis.YTick at 0x7fd576ec99d0>,
#   <matplotlib.axis.YTick at 0x7fd576ec3890>,
#   <matplotlib.axis.YTick at 0x7fd576ead490>,
#   <matplotlib.axis.YTick at 0x7fd576ed1690>,
#   <matplotlib.axis.YTick at 0x7fd576ed1cd0>,
#   <matplotlib.axis.YTick at 0x7fd576ed8350>,
#   <matplotlib.axis.YTick at 0x7fd576945990>,
#   <matplotlib.axis.YTick at 0x7fd5775be790>,
#   <matplotlib.axis.YTick at 0x7fd5775bedd0>,
#   <matplotlib.axis.YTick at 0x7fd5775c2450>,
#   <matplotlib.axis.YTick at 0x7fd5775c2a90>,
#   <matplotlib.axis.YTick at 0x7fd5775ca050>,
#   <matplotlib.axis.YTick at 0x7fd5775ca750>,
#   <matplotlib.axis.YTick at 0x7fd5775cad90>,
#   <matplotlib.axis.YTick at 0x7fd5775c24d0>,
#   <matplotlib.axis.YTick at 0x7fd5775b88d0>,
#   <matplotlib.axis.YTick at 0x7fd5775d0310>,
#   <matplotlib.axis.YTick at 0x7fd5775d0950>,
#   <matplotlib.axis.YTick at 0x7fd5775d0810>,
#   <matplotlib.axis.YTick at 0x7fd5775d6610>,
#   <matplotlib.axis.YTick at 0x7fd5775d6c50>,
#   <matplotlib.axis.YTick at 0x7fd5775de2d0>,
#   <matplotlib.axis.YTick at 0x7fd5775de910>,
#   <matplotlib.axis.YTick at 0x7fd5775def50>,
#   <matplotlib.axis.YTick at 0x7fd5775d6150>,
#   <matplotlib.axis.YTick at 0x7fd5775c2850>,
#   <matplotlib.axis.YTick at 0x7fd5775e54d0>,
#   <matplotlib.axis.YTick at 0x7fd5775e5b10>,
#   <matplotlib.axis.YTick at 0x7fd5775ea1d0>,
#   <matplotlib.axis.YTick at 0x7fd5775ea7d0>,
#   <matplotlib.axis.YTick at 0x7fd5775eae10>,
#   <matplotlib.axis.YTick at 0x7fd5775f1490>,
#   <matplotlib.axis.YTick at 0x7fd5775f1ad0>,
#   <matplotlib.axis.YTick at 0x7fd5775ea590>,
#   <matplotlib.axis.YTick at 0x7fd5775de890>,
#   <matplotlib.axis.YTick at 0x7fd5771dad50>,
#   <matplotlib.axis.YTick at 0x7fd576ec9bd0>,
#   <matplotlib.axis.YTick at 0x7fd5775f1890>,
#   <matplotlib.axis.YTick at 0x7fd5775fb710>,
#   <matplotlib.axis.YTick at 0x7fd5775fbd50>],
#  <a list of 68 Text yticklabel objects>)

# %% [markdown]
# ## Group Consistency: Original Data

# %%
# To get phi, we get mean across subjects of rho_ii (larger values of this indicate edges that are important for identification)
group_consistency = np.mean(z_target * z_database, axis = 0)
min_gc = np.min(group_consistency)
max_gc = np.max(group_consistency)


reshaped_group_consistency=np.reshape(group_consistency, (68,-1))
reshaped_group_consistency.shape
plt.figure(figsize=(15, 10))
axs = sns.heatmap(reshaped_group_consistency, cmap='Reds')
plt.xticks(np.arange(0, 300, 5), np.arange(0, 150, 0.5)[range(0,300,5)])
plt.yticks(np.arange(0, 68, 1),atlasdk[atlasdk.columns[0]], rotation=0)
# Out:
# ([<matplotlib.axis.YTick at 0x7fd5739103d0>,
#   <matplotlib.axis.YTick at 0x7fd574b795d0>,
#   <matplotlib.axis.YTick at 0x7fd5738d8d90>,
#   <matplotlib.axis.YTick at 0x7fd5738d88d0>,
#   <matplotlib.axis.YTick at 0x7fd574dfdb50>,
#   <matplotlib.axis.YTick at 0x7fd574dfd890>,
#   <matplotlib.axis.YTick at 0x7fd574dfd210>,
#   <matplotlib.axis.YTick at 0x7fd5738d8d50>,
#   <matplotlib.axis.YTick at 0x7fd5738de950>,
#   <matplotlib.axis.YTick at 0x7fd577208d50>,
#   <matplotlib.axis.YTick at 0x7fd577208850>,
#   <matplotlib.axis.YTick at 0x7fd5738e63d0>,
#   <matplotlib.axis.YTick at 0x7fd5738e6a50>,
#   <matplotlib.axis.YTick at 0x7fd577600690>,
#   <matplotlib.axis.YTick at 0x7fd5738e8390>,
#   <matplotlib.axis.YTick at 0x7fd5738e7c10>,
#   <matplotlib.axis.YTick at 0x7fd5738e7510>,
#   <matplotlib.axis.YTick at 0x7fd5738f7f10>,
#   <matplotlib.axis.YTick at 0x7fd5769d3a10>,
#   <matplotlib.axis.YTick at 0x7fd574f0cb10>,
#   <matplotlib.axis.YTick at 0x7fd574f0c850>,
#   <matplotlib.axis.YTick at 0x7fd5738ff390>,
#   <matplotlib.axis.YTick at 0x7fd5738ff690>,
#   <matplotlib.axis.YTick at 0x7fd57696df90>,
#   <matplotlib.axis.YTick at 0x7fd57696d950>,
#   <matplotlib.axis.YTick at 0x7fd57696d510>,
#   <matplotlib.axis.YTick at 0x7fd574f0c8d0>,
#   <matplotlib.axis.YTick at 0x7fd5769d43d0>,
#   <matplotlib.axis.YTick at 0x7fd5769d4890>,
#   <matplotlib.axis.YTick at 0x7fd574858dd0>,
#   <matplotlib.axis.YTick at 0x7fd5748589d0>,
#   <matplotlib.axis.YTick at 0x7fd574858590>,
#   <matplotlib.axis.YTick at 0x7fd573b28dd0>,
#   <matplotlib.axis.YTick at 0x7fd574778a50>,
#   <matplotlib.axis.YTick at 0x7fd5738d8110>,
#   <matplotlib.axis.YTick at 0x7fd5742fafd0>,
#   <matplotlib.axis.YTick at 0x7fd5742e4750>,
#   <matplotlib.axis.YTick at 0x7fd577600cd0>,
#   <matplotlib.axis.YTick at 0x7fd578770a90>,
#   <matplotlib.axis.YTick at 0x7fd574307710>,
#   <matplotlib.axis.YTick at 0x7fd5743073d0>,
#   <matplotlib.axis.YTick at 0x7fd57431d150>,
#   <matplotlib.axis.YTick at 0x7fd574320c50>,
#   <matplotlib.axis.YTick at 0x7fd574320910>,
#   <matplotlib.axis.YTick at 0x7fd574ff6e50>,
#   <matplotlib.axis.YTick at 0x7fd574320290>,
#   <matplotlib.axis.YTick at 0x7fd5742e4c90>,
#   <matplotlib.axis.YTick at 0x7fd574ff6190>,
#   <matplotlib.axis.YTick at 0x7fd574ad3c90>,
#   <matplotlib.axis.YTick at 0x7fd5787bca10>,
#   <matplotlib.axis.YTick at 0x7fd5787bc890>,
#   <matplotlib.axis.YTick at 0x7fd576bd4710>,
#   <matplotlib.axis.YTick at 0x7fd574340b10>,
#   <matplotlib.axis.YTick at 0x7fd5747cfbd0>,
#   <matplotlib.axis.YTick at 0x7fd574340ed0>,
#   <matplotlib.axis.YTick at 0x7fd5787bc650>,
#   <matplotlib.axis.YTick at 0x7fd5742e4b10>,
#   <matplotlib.axis.YTick at 0x7fd576bda150>,
#   <matplotlib.axis.YTick at 0x7fd5741d9510>,
#   <matplotlib.axis.YTick at 0x7fd5741d9190>,
#   <matplotlib.axis.YTick at 0x7fd578aa9fd0>,
#   <matplotlib.axis.YTick at 0x7fd578aa9690>,
#   <matplotlib.axis.YTick at 0x7fd5741bcf50>,
#   <matplotlib.axis.YTick at 0x7fd5741bc4d0>,
#   <matplotlib.axis.YTick at 0x7fd578aa9390>,
#   <matplotlib.axis.YTick at 0x7fd5787bc7d0>,
#   <matplotlib.axis.YTick at 0x7fd5741bc110>,
#   <matplotlib.axis.YTick at 0x7fd578680510>],
#  <a list of 68 Text yticklabel objects>)

# %% [markdown]
# ## Group Consistency: Reconstructed Data

# %%
# To get phi, we get mean across subjects of rho_ii (larger values of this indicate edges that are important for identification)
pca_group_consistency = np.mean(pca_z_target * pca_z_database, axis = 0)
pca_min_gc = np.min(pca_group_consistency)
pca_max_gc = np.max(pca_group_consistency)

reshaped_pca_group_consistency=np.reshape(pca_group_consistency, (68,-1))
reshaped_pca_group_consistency.shape
plt.figure(figsize=(15, 10))
axs = sns.heatmap(reshaped_pca_group_consistency, cmap='Reds')
plt.xticks(np.arange(0, 300, 5), np.arange(0, 150, 0.5)[range(0,300,5)])
plt.yticks(np.arange(0, 68, 1),atlasdk[atlasdk.columns[0]], rotation=0)
# Out:
# ([<matplotlib.axis.YTick at 0x7fd574ba7a10>,
#   <matplotlib.axis.YTick at 0x7fd574b446d0>,
#   <matplotlib.axis.YTick at 0x7fd5757c5c90>,
#   <matplotlib.axis.YTick at 0x7fd5760b0510>,
#   <matplotlib.axis.YTick at 0x7fd5760b0b10>,
#   <matplotlib.axis.YTick at 0x7fd5760b41d0>,
#   <matplotlib.axis.YTick at 0x7fd5760b4810>,
#   <matplotlib.axis.YTick at 0x7fd5760b4e50>,
#   <matplotlib.axis.YTick at 0x7fd5760ba4d0>,
#   <matplotlib.axis.YTick at 0x7fd5760bab10>,
#   <matplotlib.axis.YTick at 0x7fd5760c2190>,
#   <matplotlib.axis.YTick at 0x7fd5760c2790>,
#   <matplotlib.axis.YTick at 0x7fd5760c2dd0>,
#   <matplotlib.axis.YTick at 0x7fd5760baa10>,
#   <matplotlib.axis.YTick at 0x7fd5760b4990>,
#   <matplotlib.axis.YTick at 0x7fd5760c63d0>,
#   <matplotlib.axis.YTick at 0x7fd5760c6a10>,
#   <matplotlib.axis.YTick at 0x7fd5760c6d50>,
#   <matplotlib.axis.YTick at 0x7fd5760cf6d0>,
#   <matplotlib.axis.YTick at 0x7fd5760cfd10>,
#   <matplotlib.axis.YTick at 0x7fd5760d6390>,
#   <matplotlib.axis.YTick at 0x7fd5760d69d0>,
#   <matplotlib.axis.YTick at 0x7fd5760cf5d0>,
#   <matplotlib.axis.YTick at 0x7fd5760ba650>,
#   <matplotlib.axis.YTick at 0x7fd5760d6f10>,
#   <matplotlib.axis.YTick at 0x7fd5760de590>,
#   <matplotlib.axis.YTick at 0x7fd5760debd0>,
#   <matplotlib.axis.YTick at 0x7fd5785f6250>,
#   <matplotlib.axis.YTick at 0x7fd5785f6890>,
#   <matplotlib.axis.YTick at 0x7fd5785f6ed0>,
#   <matplotlib.axis.YTick at 0x7fd5785fd550>,
#   <matplotlib.axis.YTick at 0x7fd5785f61d0>,
#   <matplotlib.axis.YTick at 0x7fd5760d6a50>,
#   <matplotlib.axis.YTick at 0x7fd5785fd790>,
#   <matplotlib.axis.YTick at 0x7fd5760b0090>,
#   <matplotlib.axis.YTick at 0x7fd578693a90>,
#   <matplotlib.axis.YTick at 0x7fd578696050>,
#   <matplotlib.axis.YTick at 0x7fd578696750>,
#   <matplotlib.axis.YTick at 0x7fd578696d90>,
#   <matplotlib.axis.YTick at 0x7fd57869e410>,
#   <matplotlib.axis.YTick at 0x7fd57869ea50>,
#   <matplotlib.axis.YTick at 0x7fd57869ed90>,
#   <matplotlib.axis.YTick at 0x7fd5786968d0>,
#   <matplotlib.axis.YTick at 0x7fd5786679d0>,
#   <matplotlib.axis.YTick at 0x7fd5786a5610>,
#   <matplotlib.axis.YTick at 0x7fd5786a5c50>,
#   <matplotlib.axis.YTick at 0x7fd5786ac2d0>,
#   <matplotlib.axis.YTick at 0x7fd5786ac910>,
#   <matplotlib.axis.YTick at 0x7fd5786ac7d0>,
#   <matplotlib.axis.YTick at 0x7fd5787545d0>,
#   <matplotlib.axis.YTick at 0x7fd578754c10>,
#   <matplotlib.axis.YTick at 0x7fd5786aca90>,
#   <matplotlib.axis.YTick at 0x7fd5786a5150>,
#   <matplotlib.axis.YTick at 0x7fd57875d310>,
#   <matplotlib.axis.YTick at 0x7fd57875d950>,
#   <matplotlib.axis.YTick at 0x7fd57875d810>,
#   <matplotlib.axis.YTick at 0x7fd578760610>,
#   <matplotlib.axis.YTick at 0x7fd578760c50>,
#   <matplotlib.axis.YTick at 0x7fd5787682d0>,
#   <matplotlib.axis.YTick at 0x7fd578768910>,
#   <matplotlib.axis.YTick at 0x7fd5787606d0>,
#   <matplotlib.axis.YTick at 0x7fd578754f50>,
#   <matplotlib.axis.YTick at 0x7fd578768e50>,
#   <matplotlib.axis.YTick at 0x7fd5787704d0>,
#   <matplotlib.axis.YTick at 0x7fd578770b10>,
#   <matplotlib.axis.YTick at 0x7fd5787771d0>,
#   <matplotlib.axis.YTick at 0x7fd5787777d0>,
#   <matplotlib.axis.YTick at 0x7fd578777e10>],
#  <a list of 68 Text yticklabel objects>)

# %% [markdown]
# ## Intraclass Correlation Coefficient: Original Data
# ### A note on ICC
#     - We are also using ICC to analyze this data based on Amicto & Goñi, 2018
#     - They do not explicitely report what flavour of ICC they used, but, based on their description, they are using a consistency ICC (ICC(1, 1) in Shrout and Fleiss, 1979 terms)
#     - This is a one-way random effects model where each item is rated by different raters who are considered as sampled from a larger pool of potential raters
#         - Hence they are treated as random effects
#         - This ICC is interpreted as the ratio between variance between subjects and total variance
#     - We chose this because we are testing for inter-rater reliability (the same subject) and each subjects are their own raters (one way random effects)

# %%
icc = np.zeros(z_target.shape[1])
pca_icc = np.zeros(pca_z_target.shape[1])

n = n_subs
k = n_measurements
df_b = n-1
df_w = n*(k-1)

for i_edge in range(z_target.shape[1]):
    # Original
    x = np.concatenate((np.expand_dims(z_target[:, i_edge], axis = 1), np.expand_dims(z_database[:, i_edge], axis = 1)), axis = 1)
    x_w_mean = x.mean(axis = 1)
    x_g_mean = x.mean()
    ss_t = ((x - x_g_mean) ** 2).sum()
    ss_w = ((x - np.expand_dims(x_w_mean, axis = 1)) ** 2).sum()
    ss_b = ss_t - ss_w
    ms_b = ss_b / df_b
    ms_w = ss_w / df_w
    icc[i_edge] = (ms_b - ms_w) / (ms_b + ((k-1)*ms_w))
    
    # Reconstructed
    pca_x = np.concatenate((np.expand_dims(pca_z_target[:, i_edge], axis = 1), np.expand_dims(pca_z_database[:, i_edge], axis = 1)), axis = 1)
    x_w_mean = pca_x.mean(axis = 1)
    x_g_mean = pca_x.mean()
    ss_t = ((pca_x - x_g_mean) ** 2).sum()
    ss_w = ((pca_x - np.expand_dims(x_w_mean, axis = 1)) ** 2).sum()
    ss_b = ss_t - ss_w
    ms_b = ss_b / df_b
    ms_w = ss_w / df_w
    pca_icc[i_edge] = (ms_b - ms_w) / (ms_b + ((k-1)*ms_w))
    
min_icc = np.min(icc)
max_icc = np.max(icc)
pca_min_icc = np.min(pca_icc)
pca_max_icc = np.max(pca_icc)

# %%
#print(differential_power)

reshaped_icc=np.reshape(icc, (68,-1))
reshaped_icc.shape
reshaped_pca_icc=np.reshape(pca_icc, (68,-1))
reshaped_pca_icc.shape
#print(differential_power)
plt.figure(figsize=(15, 10))
axs = sns.heatmap(reshaped_icc, cmap='Reds', vmin=0.30, vmax=0.7)
plt.xticks(np.arange(0, 300, 5), np.arange(0, 150, 0.5)[range(0,300,5)])
plt.yticks(np.arange(0, 68, 1),atlasdk[atlasdk.columns[0]], rotation=0)
plt.figure(figsize=(15, 10))
axs = sns.heatmap(reshaped_pca_icc, cmap='Reds', vmin=0.30, vmax=0.7)
plt.xticks(np.arange(0, 300, 5), np.arange(0, 150, 0.5)[range(0,300,5)])
plt.yticks(np.arange(0, 68, 1),atlasdk[atlasdk.columns[0]], rotation=0)
# Out:
# ([<matplotlib.axis.YTick at 0x7fd574950b50>,
#   <matplotlib.axis.YTick at 0x7fd5749ab250>,
#   <matplotlib.axis.YTick at 0x7fd5749b9e90>,
#   <matplotlib.axis.YTick at 0x7fd5747e4390>,
#   <matplotlib.axis.YTick at 0x7fd5747e4f10>,
#   <matplotlib.axis.YTick at 0x7fd5b977d310>,
#   <matplotlib.axis.YTick at 0x7fd5747fad90>,
#   <matplotlib.axis.YTick at 0x7fd5747faf90>,
#   <matplotlib.axis.YTick at 0x7fd5b976dcd0>,
#   <matplotlib.axis.YTick at 0x7fd5b976d950>,
#   <matplotlib.axis.YTick at 0x7fd5747fab50>,
#   <matplotlib.axis.YTick at 0x7fd5747e47d0>,
#   <matplotlib.axis.YTick at 0x7fd5747df490>,
#   <matplotlib.axis.YTick at 0x7fd5747d8490>,
#   <matplotlib.axis.YTick at 0x7fd5747d8410>,
#   <matplotlib.axis.YTick at 0x7fd5747d8610>,
#   <matplotlib.axis.YTick at 0x7fd57478f990>,
#   <matplotlib.axis.YTick at 0x7fd57478f950>,
#   <matplotlib.axis.YTick at 0x7fd5747e9390>,
#   <matplotlib.axis.YTick at 0x7fd5747d8750>,
#   <matplotlib.axis.YTick at 0x7fd5747df450>,
#   <matplotlib.axis.YTick at 0x7fd5747e91d0>,
#   <matplotlib.axis.YTick at 0x7fd573b33a10>,
#   <matplotlib.axis.YTick at 0x7fd573b72d50>,
#   <matplotlib.axis.YTick at 0x7fd573b28d50>,
#   <matplotlib.axis.YTick at 0x7fd5747f5610>,
#   <matplotlib.axis.YTick at 0x7fd5747f5290>,
#   <matplotlib.axis.YTick at 0x7fd5b22df910>,
#   <matplotlib.axis.YTick at 0x7fd573b3a350>,
#   <matplotlib.axis.YTick at 0x7fd573b3a890>,
#   <matplotlib.axis.YTick at 0x7fd573b46810>,
#   <matplotlib.axis.YTick at 0x7fd573aec250>,
#   <matplotlib.axis.YTick at 0x7fd573aec8d0>,
#   <matplotlib.axis.YTick at 0x7fd573aecd50>,
#   <matplotlib.axis.YTick at 0x7fd5b9ccbd50>,
#   <matplotlib.axis.YTick at 0x7fd574fd51d0>,
#   <matplotlib.axis.YTick at 0x7fd574fe1ed0>,
#   <matplotlib.axis.YTick at 0x7fd5747cff90>,
#   <matplotlib.axis.YTick at 0x7fd574befed0>,
#   <matplotlib.axis.YTick at 0x7fd574fd5a10>,
#   <matplotlib.axis.YTick at 0x7fd574fd5d50>,
#   <matplotlib.axis.YTick at 0x7fd574fdd6d0>,
#   <matplotlib.axis.YTick at 0x7fd574fddd10>,
#   <matplotlib.axis.YTick at 0x7fd574fef390>,
#   <matplotlib.axis.YTick at 0x7fd574fef9d0>,
#   <matplotlib.axis.YTick at 0x7fd574fef610>,
#   <matplotlib.axis.YTick at 0x7fd574fdd650>,
#   <matplotlib.axis.YTick at 0x7fd574fe1350>,
#   <matplotlib.axis.YTick at 0x7fd574fed690>,
#   <matplotlib.axis.YTick at 0x7fd574fedcd0>,
#   <matplotlib.axis.YTick at 0x7fd574fc7350>,
#   <matplotlib.axis.YTick at 0x7fd574fc7990>,
#   <matplotlib.axis.YTick at 0x7fd574fc7a90>,
#   <matplotlib.axis.YTick at 0x7fd576bc0650>,
#   <matplotlib.axis.YTick at 0x7fd576bc0c90>,
#   <matplotlib.axis.YTick at 0x7fd576bc05d0>,
#   <matplotlib.axis.YTick at 0x7fd57434d6d0>,
#   <matplotlib.axis.YTick at 0x7fd576bc6250>,
#   <matplotlib.axis.YTick at 0x7fd576bc6850>,
#   <matplotlib.axis.YTick at 0x7fd576bc6e90>,
#   <matplotlib.axis.YTick at 0x7fd576bcd510>,
#   <matplotlib.axis.YTick at 0x7fd576bcdb50>,
#   <matplotlib.axis.YTick at 0x7fd576bd4250>,
#   <matplotlib.axis.YTick at 0x7fd576bd4810>,
#   <matplotlib.axis.YTick at 0x7fd576bd4e50>,
#   <matplotlib.axis.YTick at 0x7fd576bcd690>,
#   <matplotlib.axis.YTick at 0x7fd574fedd50>,
#   <matplotlib.axis.YTick at 0x7fd576bda450>],
#  <a list of 68 Text yticklabel objects>)

# %% [markdown]
# ## Relationships between Group Consistency, Differential Power, and Intraclass Correlation Coefficient

# %%
fig, ax = plt.subplots(1,3,figsize=(40,10))
axs = ax.ravel()

# GC vs DP
axs[0].scatter(group_consistency, differential_power, label = 'Original', s = 10)
axs[0].scatter(pca_group_consistency, pca_differential_power, label = 'Reconstructed', s = 10)
axs[0].set_title('Group Consistency vs Differential Power', size = 25)
axs[0].set_xlabel('Group Consistency', fontsize = 15)
axs[0].set_ylabel('Differential Power', fontsize = 15)
axs[0].legend(fontsize = 15)

# DP vs ICC
axs[1].scatter(differential_power, icc, label = 'Original', s = 10)
axs[1].scatter(pca_differential_power, pca_icc, label = 'Reconstructed', s = 10)
axs[1].set_title('Differential Power vs Intraclass Correlation Coefficient', size = 25)
axs[1].set_xlabel('Differential Power', fontsize = 15)
axs[1].set_ylabel('Intraclass Correlation Coefficient', fontsize = 15)
axs[1].legend(fontsize = 15)

# GC vs ICC
axs[2].scatter(group_consistency, icc, label = 'Original', s = 10)
axs[2].scatter(pca_group_consistency, pca_icc, label = 'Reconstructed', s = 10)
axs[2].set_title('Group Consistency vs Intraclass Correlation Coefficient', size = 25)
axs[2].set_xlabel('Group Consistency', fontsize = 15)
axs[2].set_ylabel('Intraclass Correlation Coefficient', fontsize = 15)
axs[2].legend(fontsize = 15)

plt.tight_layout
plt.suptitle('Intraclass Correlation Coefficient (Reconstructed Data)', y=.98, size = 30)
plt.show()

# %% [markdown]
# # IV. Identifiability as a function of subjects' characteristics

# %%
# First we get subject number
def subs_list(sub):
    if sub < 10:
        return 'sub-000' + sub.astype(int).astype(str)
    elif sub >= 10 and sub < 100:
        return 'sub-00' + sub.astype(int).astype(str)
    else: 
        return 'sub-0' + sub.astype(int).astype(str)
    
    
# Get subject data from 
subs_analyzed = list(map(subs_list, sub_target[:, -1]))
subs_omega = pd.read_csv('data/OMEGA_BIDS/participants.csv', sep=',', header=0)
subs_omega = subs_omega[subs_omega['participants_id'].isin(subs_analyzed)]

# Wrangle data to get subjecs' age
sub_age = list(subs_omega['X.session.age.'].values)
for x in range(len(sub_age)):
    if isinstance(sub_age[x], str):
        sub_age[x] = sub_age[x][3:5]
    if (sub_age[x]==""):
        sub_age[x] = np.nan
        
sub_age = np.array(sub_age).astype(float)
age_mean = np.floor(np.nanmean(sub_age))
inds = np.where(np.isnan(sub_age))
sub_age[inds] = age_mean
subs_omega['X.session.age.'] = sub_age
subs_omega = subs_omega.rename(columns={'X.session.age.': 'age'})


# Wrangle data to get subjects' group
sub_group = list(subs_omega['Group'].values)
for x in range(len(sub_group)):
    if isinstance(sub_group[x], str):
        if sub_group[x] != 'Control':
            sub_group[x] = 'Spec'
    else:
        sub_group[x] = 'Control' # The most common label here is 'Control', so I decided to handles NaN's that way
subs_omega['Group'] = sub_group

sub_time= list(subs_omega['time_of_record'].values)
subs_omega['time_of_record']= sub_time

# Do some final wrangling before plotting relationshisp between variables and 
subs_omega['identifiability'] = self_id
subs_omega['pca_identifiability'] = pca_self_id
subs_omega = subs_omega.rename(columns={'Dominant.Hand': 'Dominant Hand'})
subs_omega = subs_omega.drop(['Year.of.birth', 'Questionnaire.Version'], axis = 1)

# %%
# Plot relations between group, age, gender, dominant hand -and- identifiability
fig, axs = plt.subplots(1,4, figsize=(35, 8), sharey=True)
fig.subplots_adjust(hspace = .2, wspace = .2)
axs = axs.ravel()

# Age
axs[0].scatter(subs_omega['age'].values, subs_omega['identifiability'].values)    
axs[0].set_title('Age vs Identifiability', fontsize = 20)
axs[0].set_xlabel('Age', fontsize = 15)
axs[0].set_ylabel('Self Identifiability', fontsize = 15)

# Gender
sns.violinplot(x = 'Gender', y = 'identifiability', data = subs_omega, ax = axs[1])
axs[1].set_xlabel('Gender', fontsize = 15)
axs[1].set_xticklabels(['Male','Female'], fontsize = 15)
axs[1].set_ylabel('')
axs[1].set_title('Gender vs Identifiability', fontsize = 20)


# Dominant hand
sns.violinplot(x = 'Dominant Hand', y = 'identifiability', data = subs_omega, ax = axs[2])
axs[2].set_ylabel('')
axs[2].set_xlabel('Dominant Hand', fontsize = 15)
axs[2].set_xticklabels(['Right','Left', 'Other'], fontsize = 15)
axs[2].set_title('Dominant Hand vs Identifiability', fontsize = 20)

# Group
sns.violinplot(x = 'Group', y = 'identifiability', data = subs_omega, ax = axs[3])
axs[3].set_ylabel('')
axs[3].set_xlabel('Group', fontsize = 15)
axs[3].set_xticklabels(['Control','Other'], fontsize = 15)
axs[3].set_title('Group vs Identifiability', fontsize = 20)

plt.suptitle('Relations between subjects\' characteristics and self identifiability (Original)', y=1.1, size = 30)
plt.tight_layout()
plt.show()

# %%
# Plot relations between group, age, gender, dominant hand -and- identifiability
fig, axs = plt.subplots(1,4, figsize=(35, 8), sharey=True)
fig.subplots_adjust(hspace = .2, wspace = .2)
axs = axs.ravel()

# Age
axs[0].scatter(subs_omega['age'].values, subs_omega['pca_identifiability'].values)    
axs[0].set_title('Age vs Identifiability', fontsize = 20)
axs[0].set_xlabel('Age', fontsize = 15)
axs[0].set_ylabel('Self Identifiability', fontsize = 15)

# Gender
sns.violinplot(x = 'Gender', y = 'pca_identifiability', data = subs_omega, ax = axs[1])
axs[1].set_xlabel('Gender', fontsize = 15)
axs[1].set_xticklabels(['Male','Female'], fontsize = 15)
axs[1].set_ylabel('')
axs[1].set_title('Gender vs Identifiability', fontsize = 20)


# Dominant hand
sns.violinplot(x = 'Dominant Hand', y = 'pca_identifiability', data = subs_omega, ax = axs[2])
axs[2].set_ylabel('')
axs[2].set_xlabel('Dominant Hand', fontsize = 15)
axs[2].set_xticklabels(['Right','Left', 'Other'], fontsize = 15)
axs[2].set_title('Dominant Hand vs Identifiability', fontsize = 20)

# Group
sns.violinplot(x = 'Group', y = 'pca_identifiability', data = subs_omega, ax = axs[3])
axs[3].set_ylabel('')
axs[3].set_xlabel('Group', fontsize = 15)
axs[3].set_xticklabels(['Control','Other'], fontsize = 15)
axs[3].set_title('Group vs Identifiability', fontsize = 20)

plt.suptitle('Relations between subjects\' characteristics and self identifiability (Reconstructed)', y=1.1, size = 30)
plt.tight_layout()
plt.show()

# %% [markdown]
# # V. Sanity checks: Identifiability as a function of summary statistics for motion, cardiac activity, and eye movements

# %%
# First we get a big data frame
sanity_check = pd.read_csv('dependencies/eog_ecg_motion.csv')
sanity_check = sanity_check.head(n_subs)
sanity_check['self_id'] = self_id
sanity_check['pca_self_id'] = pca_self_id

# Plot relations between motion, ecg, eog -and- identifiability
fig, axs = plt.subplots(1,3, figsize=(35, 8))
fig.subplots_adjust(hspace = .2, wspace = .2)
axs = axs.ravel()

# Motion
axs[0].scatter(sanity_check['motion'].values, sanity_check['self_id'].values)    
axs[0].set_title('Motion vs Identifiability', fontsize = 20)
axs[0].set_xlabel('Motion [m]', fontsize = 15)
axs[0].set_ylabel('Self Identifiability', fontsize = 15)

# ECG
axs[1].scatter(sanity_check['ecg'].values, sanity_check['self_id'].values)    
axs[1].set_title('ECG vs Identifiability', fontsize = 20)
axs[1].set_xlabel('ECG [vµ]', fontsize = 15)
axs[1].set_ylabel('Self Identifiability', fontsize = 15)

# EOG
axs[2].scatter(sanity_check['eog'].values, sanity_check['self_id'].values)    
axs[2].set_title('EOG vs Identifiability', fontsize = 20)
axs[2].set_xlabel('EOG [vµ]', fontsize = 15)
axs[2].set_ylabel('Self Identifiability', fontsize = 15)

plt.suptitle('Relations between measured artifacts and self identifiability (Original)', y=1.1, size = 30)
plt.tight_layout()
plt.show()

# %%
# Plot relations between motion, ecg, eog -and- identifiability
fig, axs = plt.subplots(1,3, figsize=(35, 8))
fig.subplots_adjust(hspace = .2, wspace = .2)
axs = axs.ravel()

# Motion
axs[0].scatter(sanity_check['motion'].values, sanity_check['pca_self_id'].values)    
axs[0].set_title('Motion vs Identifiability', fontsize = 20)
axs[0].set_xlabel('Motion [m]', fontsize = 15)
axs[0].set_ylabel('Self Identifiability', fontsize = 15)

# ECG
axs[1].scatter(sanity_check['ecg'].values, sanity_check['pca_self_id'].values)    
axs[1].set_title('ECG vs Identifiability', fontsize = 20)
axs[1].set_xlabel('ECG [vµ]', fontsize = 15)
axs[1].set_ylabel('Self Identifiability', fontsize = 15)

# EOG
axs[2].scatter(sanity_check['eog'].values, sanity_check['pca_self_id'].values)    
axs[2].set_title('EOG vs Identifiability', fontsize = 20)
axs[2].set_xlabel('EOG [vµ]', fontsize = 15)
axs[2].set_ylabel('Self Identifiability', fontsize = 15)

plt.suptitle('Relations between measured artifacts and self identifiability (Reconstructed)', y=1.1, size = 30)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10, 10))
axs = sns.regplot(subs_omega['identifiability'].values, subs_omega['pca_identifiability'].values)
axs.set_title('Self-identifiability: Original and Reconstructed Space', size = 'x-large')
sns.despine()
plt.show()
