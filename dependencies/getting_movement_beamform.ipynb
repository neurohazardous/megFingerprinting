# %% [markdown]
# # Sanity checks: ECG, EOG, Motion

# %%
# First we get the movement index
from glob import glob
import mne as mne
import numpy as np

subs_names = glob('../brainstorm_db/omMachina/data/*/')
subs_names = sorted([x[-9:-1] for x in subs_names])[3:]
sanity_checks = np.zeros((len(subs_names), 4), dtype=object)

for x in range(len(subs_names)):
    filename = 'data/OMEGA_BIDS/' + subs_names[x] + '/ses-0001/meg/' + glob('../brainstorm_db/omMachina/data/' + subs_names[x] + '/*meg/')[0][45:-1] + '.ds'
    raw = mne.io.read_raw_ctf(filename, preload = True)
    raw = raw.pick_channels(['HLC0011-4408','HLC0012-4408','HLC0013-4408', 'HLC0021-4408', 'HLC0022-4408','HLC0023-4408','HLC0031-4408','HLC0032-4408','HLC0033-4408', 'ECG','VEOG','HEOG']).to_data_frame()
    
    # ECG
    if 'ECG' in raw.columns:
        ecg = raw['ECG'].values
        ecg = np.sqrt((ecg.dot(ecg))/(len(ecg)))
    else:
        ecg = np.nan

    # EOG
    if 'VEOG' in raw.columns and 'HEOG' in raw.columns:
        veog = raw['VEOG'].values
        heog = raw['HEOG'].values
        eog = np.sqrt((veog * veog) + (heog * heog))
        eog = np.sqrt((eog.dot(eog))/(len(eog)))
    else:
        eog = np.nan


    # Motion
    if 'HLC0011-4408' in raw.columns and 'HLC0012-4408' in raw.columns and 'HLC0013-4408' in raw.columns and 'HLC0021-4408' in raw.columns and 'HLC0022-4408' in raw.columns and 'HLC0023-4408' in raw.columns and 'HLC0031-4408' in raw.columns and 'HLC0032-4408' in raw.columns and 'HLC0033-4408' in raw.columns:
        coil1 = np.sqrt((raw['HLC0011-4408'].values*raw['HLC0011-4408'].values) + (raw['HLC0012-4408'].values*raw['HLC0012-4408'].values) + (raw['HLC0013-4408'].values*raw['HLC0013-4408'].values))
        coil2 = np.sqrt((raw['HLC0021-4408'].values*raw['HLC0021-4408'].values) + (raw['HLC0022-4408'].values*raw['HLC0022-4408'].values) + (raw['HLC0023-4408'].values*raw['HLC0023-4408'].values))
        coil3 = np.sqrt((raw['HLC0031-4408'].values*raw['HLC0031-4408'].values) + (raw['HLC0032-4408'].values*raw['HLC0032-4408'].values) + (raw['HLC0033-4408'].values*raw['HLC0033-4408'].values))
        coil1 = np.sqrt((coil1.dot(coil1))/(len(coil1)))
        coil2 = np.sqrt((coil2.dot(coil2))/(len(coil2)))
        coil3 = np.sqrt((coil3.dot(coil3))/(len(coil3)))
        motion = np.mean([coil1, coil2, coil3])
    else:
        motion = np.nan

    # Download the things
    sanity_checks[x, :] = [subs_names[x], ecg, eog, motion]
# Out:
# ds directory : data/OMEGA_BIDS/sub-0001/ses-0001/meg/sub-0001_ses-0001_task-baselineresting_acq-AUX_run-01_meg.ds
#     res4 data read.
#     hc data read.
#     Separate EEG position data file not present.
#     Quaternion matching (desired vs. transformed):
#        0.55   83.32    0.00 mm <->    0.55   83.32    0.00 mm (orig :  -61.13   54.75 -252.01 mm) diff =    0.000 mm
#       -0.55  -83.32    0.00 mm <->   -0.55  -83.32    0.00 mm (orig :   62.78  -56.54 -257.39 mm) diff =    0.000 mm
#      105.21    0.00    0.00 mm <->  105.21    0.00    0.00 mm (orig :   70.61   77.45 -246.82 mm) diff =    0.000 mm
#     Coordinate transformations established.
#     Polhemus data for 3 HPI coils added
#     Device coordinate locations for 3 HPI coils added
# Picked positions of 3 EEG channels from channel info
#     3 EEG locations added to Polhemus data.
#     Measurement info composed.
# Finding samples for data/OMEGA_BIDS/sub-0001/ses-0001/meg/sub-0001_ses-0001_task-baselineresting_acq-AUX_run-01_meg.ds/sub-0001_ses-0001_task-baselineresting_acq-AUX_run-01_meg.meg4:
#     System clock channel is available, checking which samples are valid.
#     299 x 2400 = 717600 samples from 330 chs
# Current compensation grade : 3
# Reading 0 ... 717599  =      0.000 ...   299.000 secs...
# Converting time column to int64...
# ds directory : data/OMEGA_BIDS/sub-0002/ses-0001/meg/sub-0002_ses-0001_task-baselineresting_acq-AUX_run-01_meg.ds
#     res4 data read.
#     hc data read.
#     Separate EEG position data file not present.
#     Quaternion matching (desired vs. transformed):
#       -1.00   73.53    0.00 mm <->   -1.00   73.53    0.00 mm (orig :  -45.35   55.95 -262.00 mm) diff =    0.000 mm
#        1.00  -73.53    0.00 mm <->    1.00  -73.53    0.00 mm (orig :   58.47  -47.97 -254.74 mm) diff =    0.000 mm
#      104.31    0.00    0.00 mm <->  104.30    0.00   -0.00 mm (orig :   76.96   74.46 -227.43 mm) diff =    0.000 mm
#     Coordinate transformations established.
#     Polhemus data for 3 HPI coils added
#     Device coordinate locations for 3 HPI coils added
# Picked positions of 2 EEG channels from channel info
#     2 EEG locations added to Polhemus data.
#     Measurement info composed.
# Finding samples for data/OMEGA_BIDS/sub-0002/ses-0001/meg/sub-0002_ses-0001_task-baselineresting_acq-AUX_run-01_meg.ds/sub-0002_ses-0001_task-baselineresting_acq-AUX_run-01_meg.meg4:
#     System clock channel is available, checking which samples are valid.
#     300 x 2400 = 720000 samples from 301 chs
# Current compensation grade : 3
# Reading 0 ... 719999  =      0.000 ...   300.000 secs...
# Converting time column to int64...
# ds directory : data/OMEGA_BIDS/sub-0003/ses-0001/meg/sub-0003_ses-0001_task-restingaftertask_acq-AUX_run-02_meg.ds
#     res4 data read.
#     hc data read.
#     Separate EEG position data file not present.
#     Quaternion matching (desired vs. transformed):
#       -2.91   67.55    0.00 mm <->   -2.91   67.55   -0.00 mm (orig :  -47.90   58.31 -245.76 mm) diff =    0.000 mm
#        2.91  -67.55    0.00 mm <->    2.91  -67.55    0.00 mm (orig :   41.80  -42.65 -252.48 mm) diff =    0.000 mm
#       90.06    0.00    0.00 mm <->   90.06    0.00   -0.00 mm (orig :   63.67   59.88 -218.28 mm) diff =    0.000 mm
#     Coordinate transformations established.
#     Polhemus data for 3 HPI coils added
#     Device coordinate locations for 3 HPI coils added
# Picked positions of 2 EEG channels from channel info
#     2 EEG locations added to Polhemus data.
#     Measurement info composed.
# Finding samples for data/OMEGA_BIDS/sub-0003/ses-0001/meg/sub-0003_ses-0001_task-restingaftertask_acq-AUX_run-02_meg.ds/sub-0003_ses-0001_task-restingaftertask_acq-AUX_run-02_meg.meg4:
#     System clock channel is available, checking which samples are valid.
#     300 x 2400 = 720000 samples from 301 chs
# Current compensation grade : 3
# Reading 0 ... 719999  =      0.000 ...   300.000 secs...
# Converting time column to int64...
# ds directory : data/OMEGA_BIDS/sub-0004/ses-0001/meg/sub-0004_ses-0001_task-baselineresting_acq-AUX_run-01_meg.ds
#     res4 data read.
#     hc data read.
#     Separate EEG position data file not present.
#     Quaternion matching (desired vs. transformed):
#       -1.43   72.02    0.00 mm <->   -1.43   72.02    0.00 mm (orig :  -55.72   47.40 -253.79 mm) diff =    0.000 mm
#        1.43  -72.02    0.00 mm <->    1.43  -72.02   -0.00 mm (orig :   48.20  -52.22 -259.39 mm) diff =    0.000 mm
#       99.63    0.00    0.00 mm <->   99.63    0.00   -0.00 mm (orig :   65.46   65.68 -234.25 mm) diff =    0.000 mm
#     Coordinate transformations established.
#     Polhemus data for 3 HPI coils added
#     Device coordinate locations for 3 HPI coils added
# Picked positions of 3 EEG channels from channel info
#     3 EEG locations added to Polhemus data.
#     Measurement info composed.
# Finding samples for data/OMEGA_BIDS/sub-0004/ses-0001/meg/sub-0004_ses-0001_task-baselineresting_acq-AUX_run-01_meg.ds/sub-0004_ses-0001_task-baselineresting_acq-AUX_run-01_meg.meg4:
#     System clock channel is available, checking which samples are valid.
#     599 x 2400 = 1437600 samples from 330 chs
# Current compensation grade : 3
# Reading 0 ... 1437599  =      0.000 ...   599.000 secs...
# Converting time column to int64...
# ds directory : data/OMEGA_BIDS/sub-0005/ses-0001/meg/sub-0005_ses-0001_task-baselineresting_run-01_meg.ds
#     res4 data read.
#     hc data read.
#     Separate EEG position data file not present.
#     Quaternion matching (desired vs. transformed):
#       -0.90   71.55    0.00 mm <->   -0.90   71.55    0.00 mm (orig :  -58.18   42.75 -250.25 mm) diff =    0.000 mm
#        0.90  -71.55    0.00 mm <->    0.90  -71.55    0.00 mm (orig :   43.31  -57.80 -258.43 mm) diff =    0.000 mm
#      106.65    0.00    0.00 mm <->  106.65   -0.00    0.00 mm (orig :   65.91   61.78 -219.83 mm) diff =    0.000 mm
#     Coordinate transformations established.
#     Polhemus data for 3 HPI coils added
#     Device coordinate locations for 3 HPI coils added
#     Measurement info composed.
# Finding samples for data/OMEGA_BIDS/sub-0005/ses-0001/meg/sub-0005_ses-0001_task-baselineresting_run-01_meg.ds/sub-0005_ses-0001_task-baselineresting_run-01_meg.meg4:
#     System clock channel is available, checking which samples are valid.
#     300 x 2400 = 720000 samples from 328 chs
# Current compensation grade : 3
# Reading 0 ... 719999  =      0.000 ...   300.000 secs...
# Converting time column to int64...
# ds directory : data/OMEGA_BIDS/sub-0006/ses-0001/meg/sub-0006_ses-0001_task-baselineresting_acq-AUX_run-01_meg.ds
#     res4 data read.
#     hc data read.
#     Separate EEG position data file not present.
#     Quaternion matching (desired vs. transformed):
#        2.79   75.94    0.00 mm <->    2.79   75.94   -0.00 mm (orig :  -47.54   61.17 -255.12 mm) diff =    0.000 mm
#       -2.79  -75.94    0.00 mm <->   -2.79  -75.94    0.00 mm (orig :   57.65  -48.51 -253.12 mm) diff =    0.000 mm
#      105.03    0.00    0.00 mm <->  105.03   -0.00   -0.00 mm (orig :   72.96   77.46 -217.24 mm) diff =    0.000 mm
#     Coordinate transformations established.
#     Polhemus data for 3 HPI coils added
#     Device coordinate locations for 3 HPI coils added
# Picked positions of 3 EEG channels from channel info
#     3 EEG locations added to Polhemus data.
#     Measurement info composed.
# Finding samples for data/OMEGA_BIDS/sub-0006/ses-0001/meg/sub-0006_ses-0001_task-baselineresting_acq-AUX_run-01_meg.ds/sub-0006_ses-0001_task-baselineresting_acq-AUX_run-01_meg.meg4:
#     System clock channel is available, checking which samples are valid.
#     299 x 2400 = 717600 samples from 330 chs
# Current compensation grade : 3
# Reading 0 ... 717599  =      0.000 ...   299.000 secs...
# Converting time column to int64...
# ds directory : data/OMEGA_BIDS/sub-0007/ses-0001/meg/sub-0007_ses-0001_task-baselineresting_acq-AUX_run-01_meg.ds
#     res4 data read.
#     hc data read.
#     Separate EEG position data file not present.
#     Quaternion matching (desired vs. transformed):
#        0.53   72.26    0.00 mm <->    0.53   72.26    0.00 mm (orig :  -55.94   47.42 -254.08 mm) diff =    0.000 mm
#       -0.53  -72.26    0.00 mm <->   -0.53  -72.26    0.00 mm (orig :   44.04  -56.77 -259.93 mm) diff =    0.000 mm
#       97.31    0.00    0.00 mm <->   97.31    0.00    0.00 mm (orig :   60.74   58.50 -224.92 mm) diff =    0.000 mm
#     Coordinate transformations established.
#     Polhemus data for 3 HPI coils added
#     Device coordinate locations for 3 HPI coils added
# Picked positions of 3 EEG channels from channel info
#     3 EEG locations added to Polhemus data.
#     Measurement info composed.
# Finding samples for data/OMEGA_BIDS/sub-0007/ses-0001/meg/sub-0007_ses-0001_task-baselineresting_acq-AUX_run-01_meg.ds/sub-0007_ses-0001_task-baselineresting_acq-AUX_run-01_meg.meg4:
#     System clock channel is available, checking which samples are valid.
#     599 x 2400 = 1437600 samples from 330 chs
# Current compensation grade : 3
# Reading 0 ... 1437599  =      0.000 ...   599.000 secs...
# Converting time column to int64...
# ds directory : data/OMEGA_BIDS/sub-0008/ses-0001/meg/sub-0008_ses-0001_task-baselineresting_acq-AUX_run-01_meg.ds
#     res4 data read.
#     hc data read.
#     Separate EEG position data file not present.
#     Quaternion matching (desired vs. transformed):
#       -0.71   68.54    0.00 mm <->   -0.71   68.54    0.00 mm (orig :  -42.65   56.78 -257.93 mm) diff =    0.000 mm
#        0.71  -68.54    0.00 mm <->    0.71  -68.54    0.00 mm (orig :   55.88  -38.26 -250.69 mm) diff =    0.000 mm
#       99.79    0.00    0.00 mm <->   99.79    0.00    0.00 mm (orig :   64.90   72.08 -203.18 mm) diff =    0.000 mm
#     Coordinate transformations established.
#     Polhemus data for 3 HPI coils added
#     Device coordinate locations for 3 HPI coils added
# Picked positions of 2 EEG channels from channel info
#     2 EEG locations added to Polhemus data.
#     Measurement info composed.
# Finding samples for data/OMEGA_BIDS/sub-0008/ses-0001/meg/sub-0008_ses-0001_task-baselineresting_acq-AUX_run-01_meg.ds/sub-0008_ses-0001_task-baselineresting_acq-AUX_run-01_meg.meg4:
#     System clock channel is available, checking which samples are valid.
#     600 x 2400 = 1440000 samples from 301 chs
# Current compensation grade : 3
# Reading 0 ... 1439999  =      0.000 ...   600.000 secs...
# Converting time column to int64...
# ds directory : data/OMEGA_BIDS/sub-0009/ses-0001/meg/sub-0009_ses-0001_task-baselineresting_run-01_meg.ds
#     res4 data read.
#     hc data read.
#     Separate EEG position data file not present.
#     Quaternion matching (desired vs. transformed):
#       -1.98   68.18    0.00 mm <->   -1.98   68.18    0.00 mm (orig :  -48.94   48.09 -254.42 mm) diff =    0.000 mm
#        1.98  -68.18    0.00 mm <->    1.98  -68.18    0.00 mm (orig :   47.97  -47.34 -243.78 mm) diff =    0.000 mm
#      102.00    0.00    0.00 mm <->  102.00    0.00    0.00 mm (orig :   63.53   66.12 -204.55 mm) diff =    0.000 mm
#     Coordinate transformations established.
#     Polhemus data for 3 HPI coils added
#     Device coordinate locations for 3 HPI coils added
# Picked positions of 7 EEG channels from channel info
#     7 EEG locations added to Polhemus data.
#     Measurement info composed.
# Finding samples for data/OMEGA_BIDS/sub-0009/ses-0001/meg/sub-0009_ses-0001_task-baselineresting_run-01_meg.ds/sub-0009_ses-0001_task-baselineresting_run-01_meg.meg4:
#     System clock channel is available, checking which samples are valid.
#     300 x 2400 = 720000 samples from 334 chs
# Current compensation grade : 3
# Reading 0 ... 719999  =      0.000 ...   300.000 secs...
# Converting time column to int64...
# ds directory : data/OMEGA_BIDS/sub-0011/ses-0001/meg/sub-0011_ses-0001_task-baselineresting_acq-AUX_run-01_meg.ds
#     res4 data read.
#     hc data read.
#     Separate EEG position data file not present.
#     Quaternion matching (desired vs. transformed):
#        3.11   82.77    0.00 mm <->    3.11   82.77    0.00 mm (orig :  -60.54   58.97 -265.13 mm) diff =    0.000 mm
#       -3.11  -82.77    0.00 mm <->   -3.11  -82.77    0.00 mm (orig :   56.78  -57.96 -263.47 mm) diff =    0.000 mm
#       98.74    0.00    0.00 mm <->   98.74   -0.00    0.00 mm (orig :   61.92   70.18 -235.58 mm) diff =    0.000 mm
#     Coordinate transformations established.
#     Polhemus data for 3 HPI coils added
#     Device coordinate locations for 3 HPI coils added
# Picked positions of 3 EEG channels from channel info
#     3 EEG locations added to Polhemus data.
#     Measurement info composed.
# Finding samples for data/OMEGA_BIDS/sub-0011/ses-0001/meg/sub-0011_ses-0001_task-baselineresting_acq-AUX_run-01_meg.ds/sub-0011_ses-0001_task-baselineresting_acq-AUX_run-01_meg.meg4:
#     System clock channel is available, checking which samples are valid.
#     299 x 2400 = 717600 samples from 330 chs
# Current compensation grade : 3
# Reading 0 ... 717599  =      0.000 ...   299.000 secs...
# Converting time column to int64...
# ds directory : data/OMEGA_BIDS/sub-0012/ses-0001/meg/sub-0012_ses-0001_task-restingaftertask_run-04_meg.ds
#     res4 data read.
#     hc data read.
#     Separate EEG position data file not present.
#     Quaternion matching (desired vs. transformed):
#       -0.39   70.68    0.00 mm <->   -0.39   70.68    0.00 mm (orig :  -43.82   52.69 -259.66 mm) diff =    0.000 mm
#        0.39  -70.68    0.00 mm <->    0.39  -70.68    0.00 mm (orig :   51.93  -51.28 -258.42 mm) diff =    0.000 mm
#       96.21    0.00    0.00 mm <->   96.21    0.00    0.00 mm (orig :   73.12   63.86 -236.73 mm) diff =    0.000 mm
#     Coordinate transformations established.
#     Polhemus data for 3 HPI coils added
#     Device coordinate locations for 3 HPI coils added
# Picked positions of 3 EEG channels from channel info
#     3 EEG locations added to Polhemus data.
#     Measurement info composed.
# Finding samples for data/OMEGA_BIDS/sub-0012/ses-0001/meg/sub-0012_ses-0001_task-restingaftertask_run-04_meg.ds/sub-0012_ses-0001_task-restingaftertask_run-04_meg.meg4:
#     System clock channel is available, checking which samples are valid.
#     300 x 2400 = 720000 samples from 330 chs
# Current compensation grade : 3
# Reading 0 ... 719999  =      0.000 ...   300.000 secs...
# Converting time column to int64...
# ds directory : data/OMEGA_BIDS/sub-0013/ses-0001/meg/sub-0013_ses-0001_task-baselineresting_run-02_meg.ds
#     res4 data read.
#     hc data read.
#     Separate EEG position data file not present.
#     Quaternion matching (desired vs. transformed):
#       -0.04   75.85    0.00 mm <->   -0.04   75.85    0.00 mm (orig :  -55.97   51.76 -251.17 mm) diff =    0.000 mm
#        0.04  -75.85    0.00 mm <->    0.04  -75.85    0.00 mm (orig :   58.12  -48.03 -257.15 mm) diff =    0.000 mm
#      106.14    0.00    0.00 mm <->  106.14    0.00    0.00 mm (orig :   64.63   71.52 -205.42 mm) diff =    0.000 mm
#     Coordinate transformations established.
#     Polhemus data for 3 HPI coils added
#     Device coordinate locations for 3 HPI coils added
# Picked positions of 11 EEG channels from channel info
#     11 EEG locations added to Polhemus data.
#     Measurement info composed.
# Finding samples for data/OMEGA_BIDS/sub-0013/ses-0001/meg/sub-0013_ses-0001_task-baselineresting_run-02_meg.ds/sub-0013_ses-0001_task-baselineresting_run-02_meg.meg4:
#     System clock channel is available, checking which samples are valid.
#     300 x 2400 = 720000 samples from 336 chs
# Current compensation grade : 3
# Reading 0 ... 719999  =      0.000 ...   300.000 secs...
# Converting time column to int64...
# ds directory : data/OMEGA_BIDS/sub-0014/ses-0001/meg/sub-0014_ses-0001_task-baselineresting_run-01_meg.ds
#     res4 data read.
#     hc data read.
#     Separate EEG position data file not present.
#     Quaternion matching (desired vs. transformed):
#        2.86   74.41    0.00 mm <->    2.85   74.41    0.00 mm (orig :  -58.38   46.83 -295.72 mm) diff =    0.000 mm
#       -2.86  -74.41    0.00 mm <->   -2.86  -74.41    0.00 mm (orig :   51.99  -53.10 -292.36 mm) diff =    0.000 mm
#      101.98    0.00    0.00 mm <->  101.98    0.00    0.00 mm (orig :   61.72   74.75 -283.13 mm) diff =    0.000 mm
#     Coordinate transformations established.
#     Polhemus data for 3 HPI coils added
#     Device coordinate locations for 3 HPI coils added
# Picked positions of 3 EEG channels from channel info
#     3 EEG locations added to Polhemus data.
#     Measurement info composed.
# Finding samples for data/OMEGA_BIDS/sub-0014/ses-0001/meg/sub-0014_ses-0001_task-baselineresting_run-01_meg.ds/sub-0014_ses-0001_task-baselineresting_run-01_meg.meg4:
#     System clock channel is available, checking which samples are valid.
#     300 x 2400 = 720000 samples from 330 chs
# Current compensation grade : 3
# Reading 0 ... 719999  =      0.000 ...   300.000 secs...
# Converting time column to int64...
# ds directory : data/OMEGA_BIDS/sub-0015/ses-0001/meg/sub-0015_ses-0001_task-restingaftertask_run-10_meg.ds
#     res4 data read.
#     hc data read.
#     Separate EEG position data file not present.
#     Quaternion matching (desired vs. transformed):
#        2.18   74.63    0.00 mm <->    2.18   74.63    0.00 mm (orig :  -44.23   58.24 -262.03 mm) diff =    0.000 mm
#       -2.18  -74.63    0.00 mm <->   -2.18  -74.63    0.00 mm (orig :   53.35  -54.35 -252.13 mm) diff =    0.000 mm
#       98.34    0.00    0.00 mm <->   98.34   -0.00    0.00 mm (orig :   76.85   68.59 -255.04 mm) diff =    0.000 mm
#     Coordinate transformations established.
#     Polhemus data for 3 HPI coils added
#     Device coordinate locations for 3 HPI coils added
# Picked positions of 3 EEG channels from channel info
#     3 EEG locations added to Polhemus data.
#     Measurement info composed.
# Finding samples for data/OMEGA_BIDS/sub-0015/ses-0001/meg/sub-0015_ses-0001_task-restingaftertask_run-10_meg.ds/sub-0015_ses-0001_task-restingaftertask_run-10_meg.meg4:
#     System clock channel is available, checking which samples are valid.
#     300 x 2400 = 720000 samples from 330 chs
# Current compensation grade : 3
# Reading 0 ... 719999  =      0.000 ...   300.000 secs...
# Converting time column to int64...
# ds directory : data/OMEGA_BIDS/sub-0016/ses-0001/meg/sub-0016_ses-0001_task-restingaftertask_run-02_meg.ds
#     res4 data read.
#     hc data read.
#     Separate EEG position data file not present.
#     Quaternion matching (desired vs. transformed):
#       -0.12   66.86    0.00 mm <->   -0.12   66.86    0.00 mm (orig :  -47.46   50.40 -256.16 mm) diff =    0.000 mm
#        0.12  -66.86    0.00 mm <->    0.12  -66.86    0.00 mm (orig :   45.62  -45.60 -257.13 mm) diff =    0.000 mm
#      110.06    0.00    0.00 mm <->  110.06    0.00    0.00 mm (orig :   70.86   71.26 -209.54 mm) diff =    0.000 mm
#     Coordinate transformations established.
#     Polhemus data for 3 HPI coils added
#     Device coordinate locations for 3 HPI coils added
# Picked positions of 6 EEG channels from channel info
#     6 EEG locations added to Polhemus data.
#     Measurement info composed.
# Finding samples for data/OMEGA_BIDS/sub-0016/ses-0001/meg/sub-0016_ses-0001_task-restingaftertask_run-02_meg.ds/sub-0016_ses-0001_task-restingaftertask_run-02_meg.meg4:
#     System clock channel is available, checking which samples are valid.
#     600 x 2400 = 1440000 samples from 336 chs
# Current compensation grade : 3
# Reading 0 ... 1439999  =      0.000 ...   600.000 secs...
# Converting time column to int64...
# ds directory : data/OMEGA_BIDS/sub-0018/ses-0001/meg/sub-0018_ses-0001_task-restingaftertask_run-09_meg.ds
#     res4 data read.
#     hc data read.
#     Separate EEG position data file not present.
#     Quaternion matching (desired vs. transformed):
#       -0.88   78.55    0.00 mm <->   -0.88   78.55    0.00 mm (orig :  -50.22   59.40 -254.88 mm) diff =    0.000 mm
#        0.88  -78.55    0.00 mm <->    0.88  -78.55    0.00 mm (orig :   59.14  -53.36 -258.11 mm) diff =    0.000 mm
#      103.44    0.00    0.00 mm <->  103.44    0.00    0.00 mm (orig :   79.15   73.50 -244.15 mm) diff =    0.000 mm
#     Coordinate transformations established.
#     Polhemus data for 3 HPI coils added
#     Device coordinate locations for 3 HPI coils added
# Picked positions of 3 EEG channels from channel info
#     3 EEG locations added to Polhemus data.
#     Measurement info composed.
# Finding samples for data/OMEGA_BIDS/sub-0018/ses-0001/meg/sub-0018_ses-0001_task-restingaftertask_run-09_meg.ds/sub-0018_ses-0001_task-restingaftertask_run-09_meg.meg4:
#     System clock channel is available, checking which samples are valid.
#     300 x 2400 = 720000 samples from 330 chs
# Current compensation grade : 3
# Reading 0 ... 719999  =      0.000 ...   300.000 secs...
# Converting time column to int64...
# ds directory : data/OMEGA_BIDS/sub-0020/ses-0001/meg/sub-0020_ses-0001_task-restingaftertask_run-02_meg.ds
#     res4 data read.
#     hc data read.
#     Separate EEG position data file not present.
#     Quaternion matching (desired vs. transformed):
#        0.34   73.45    0.00 mm <->    0.34   73.45    0.00 mm (orig :  -53.52   48.53 -252.00 mm) diff =    0.000 mm
#       -0.34  -73.45    0.00 mm <->   -0.34  -73.45    0.00 mm (orig :   47.40  -58.20 -253.45 mm) diff =    0.000 mm
#      110.55    0.00    0.00 mm <->  110.55    0.00    0.00 mm (orig :   76.90   71.49 -253.51 mm) diff =    0.000 mm
#     Coordinate transformations established.
#     Polhemus data for 3 HPI coils added
#     Device coordinate locations for 3 HPI coils added
# Picked positions of 2 EEG channels from channel info
#     2 EEG locations added to Polhemus data.
#     Measurement info composed.
# Finding samples for data/OMEGA_BIDS/sub-0020/ses-0001/meg/sub-0020_ses-0001_task-restingaftertask_run-02_meg.ds/sub-0020_ses-0001_task-restingaftertask_run-02_meg.meg4:
#     System clock channel is available, checking which samples are valid.
#     300 x 2400 = 720000 samples from 301 chs
# Current compensation grade : 3
# Reading 0 ... 719999  =      0.000 ...   300.000 secs...
# Converting time column to int64...
# ds directory : data/OMEGA_BIDS/sub-0021/ses-0001/meg/sub-0021_ses-0001_task-baselineresting_acq-AUX_run-01_meg.ds
#     res4 data read.
#     hc data read.
#     Separate EEG position data file not present.
#     Quaternion matching (desired vs. transformed):
#        0.55   65.75    0.00 mm <->    0.55   65.75   -0.00 mm (orig :  -42.08   42.24 -234.41 mm) diff =    0.000 mm
#       -0.55  -65.75    0.00 mm <->   -0.55  -65.75    0.00 mm (orig :   50.39  -51.13 -239.19 mm) diff =    0.000 mm
#       91.46    0.00    0.00 mm <->   91.46   -0.00   -0.00 mm (orig :   67.44   58.24 -216.03 mm) diff =    0.000 mm
#     Coordinate transformations established.
#     Polhemus data for 3 HPI coils added
#     Device coordinate locations for 3 HPI coils added
# Picked positions of 3 EEG channels from channel info
#     3 EEG locations added to Polhemus data.
#     Measurement info composed.
# Finding samples for data/OMEGA_BIDS/sub-0021/ses-0001/meg/sub-0021_ses-0001_task-baselineresting_acq-AUX_run-01_meg.ds/sub-0021_ses-0001_task-baselineresting_acq-AUX_run-01_meg.meg4:
#     System clock channel is available, checking which samples are valid.
#     600 x 2400 = 1440000 samples from 300 chs
# Current compensation grade : 3
# Reading 0 ... 1439999  =      0.000 ...   600.000 secs...
# Converting time column to int64...
# ds directory : data/OMEGA_BIDS/sub-0022/ses-0001/meg/sub-0022_ses-0001_task-baselineresting_run-01_meg.ds
#     res4 data read.
#     hc data read.
#     Separate EEG position data file not present.
#     Quaternion matching (desired vs. transformed):
#        0.72   81.02    0.00 mm <->    0.72   81.02    0.00 mm (orig :  -58.17   57.17 -281.01 mm) diff =    0.000 mm
#       -0.72  -81.02    0.00 mm <->   -0.72  -81.02    0.00 mm (orig :   62.53  -50.96 -282.05 mm) diff =    0.000 mm
#      105.82    0.00    0.00 mm <->  105.82    0.00   -0.00 mm (orig :   62.81   71.70 -228.46 mm) diff =    0.000 mm
#     Coordinate transformations established.
#     Polhemus data for 3 HPI coils added
#     Device coordinate locations for 3 HPI coils added
# Picked positions of 3 EEG channels from channel info
#     3 EEG locations added to Polhemus data.
#     Measurement info composed.
# Finding samples for data/OMEGA_BIDS/sub-0022/ses-0001/meg/sub-0022_ses-0001_task-baselineresting_run-01_meg.ds/sub-0022_ses-0001_task-baselineresting_run-01_meg.meg4:
#     System clock channel is available, checking which samples are valid.
#     397 x 2400 = 954334 samples from 338 chs
#     866 samples omitted at the end
# Current compensation grade : 3
# Reading 0 ... 954333  =      0.000 ...   397.639 secs...
# Converting time column to int64...
# ds directory : data/OMEGA_BIDS/sub-0023/ses-0001/meg/sub-0023_ses-0001_task-restingaftertask_run-03_meg.ds
#     res4 data read.
#     hc data read.
#     Separate EEG position data file not present.
#     Quaternion matching (desired vs. transformed):
#       -0.02   76.32    0.00 mm <->   -0.02   76.32    0.00 mm (orig :  -64.65   44.44 -277.20 mm) diff =    0.000 mm
#        0.02  -76.32    0.00 mm <->    0.02  -76.32    0.00 mm (orig :   38.85  -67.71 -273.76 mm) diff =    0.000 mm
#       98.51    0.00    0.00 mm <->   98.51    0.00    0.00 mm (orig :   54.17   51.31 -240.21 mm) diff =    0.000 mm
#     Coordinate transformations established.
#     Polhemus data for 3 HPI coils added
#     Device coordinate locations for 3 HPI coils added
# Picked positions of 3 EEG channels from channel info
#     3 EEG locations added to Polhemus data.
#     Measurement info composed.
# Finding samples for data/OMEGA_BIDS/sub-0023/ses-0001/meg/sub-0023_ses-0001_task-restingaftertask_run-03_meg.ds/sub-0023_ses-0001_task-restingaftertask_run-03_meg.meg4:
#     System clock channel is available, checking which samples are valid.
#     300 x 2400 = 720000 samples from 330 chs
# Current compensation grade : 3
# Reading 0 ... 719999  =      0.000 ...   300.000 secs...
# Converting time column to int64...
# ds directory : data/OMEGA_BIDS/sub-0024/ses-0001/meg/sub-0024_ses-0001_task-baselineresting_acq-AUX_run-01_meg.ds
#     res4 data read.
#     hc data read.
#     Separate EEG position data file not present.
#     Quaternion matching (desired vs. transformed):
#       -0.24   77.30    0.00 mm <->   -0.24   77.30    0.00 mm (orig :  -50.50   55.08 -260.02 mm) diff =    0.000 mm
#        0.24  -77.30    0.00 mm <->    0.24  -77.30    0.00 mm (orig :   58.93  -54.04 -255.28 mm) diff =    0.000 mm
#       89.51    0.00    0.00 mm <->   89.51   -0.00   -0.00 mm (orig :   62.88   60.33 -226.13 mm) diff =    0.000 mm
#     Coordinate transformations established.
#     Polhemus data for 3 HPI coils added
#     Device coordinate locations for 3 HPI coils added
# Picked positions of 2 EEG channels from channel info
#     2 EEG locations added to Polhemus data.
#     Measurement info composed.
# Finding samples for data/OMEGA_BIDS/sub-0024/ses-0001/meg/sub-0024_ses-0001_task-baselineresting_acq-AUX_run-01_meg.ds/sub-0024_ses-0001_task-baselineresting_acq-AUX_run-01_meg.meg4:
#     System clock channel is available, checking which samples are valid.
#     600 x 2400 = 1440000 samples from 301 chs
# Current compensation grade : 3
# Reading 0 ... 1439999  =      0.000 ...   600.000 secs...
# Converting time column to int64...
# ds directory : data/OMEGA_BIDS/sub-0025/ses-0001/meg/sub-0025_ses-0001_task-baselineresting_acq-AUX_run-01_meg.ds
#     res4 data read.
#     hc data read.
#     Separate EEG position data file not present.
#     Quaternion matching (desired vs. transformed):
#       -4.76   75.77    0.00 mm <->   -4.76   75.77    0.00 mm (orig :  -42.49   60.06 -254.06 mm) diff =    0.000 mm
#        4.76  -75.77    0.00 mm <->    4.76  -75.77   -0.00 mm (orig :   65.09  -47.07 -255.54 mm) diff =    0.000 mm
#       99.37    0.00    0.00 mm <->   99.37   -0.00   -0.00 mm (orig :   80.82   66.97 -217.59 mm) diff =    0.000 mm
#     Coordinate transformations established.
#     Polhemus data for 3 HPI coils added
#     Device coordinate locations for 3 HPI coils added
# Picked positions of 3 EEG channels from channel info
#     3 EEG locations added to Polhemus data.
#     Measurement info composed.
# Finding samples for data/OMEGA_BIDS/sub-0025/ses-0001/meg/sub-0025_ses-0001_task-baselineresting_acq-AUX_run-01_meg.ds/sub-0025_ses-0001_task-baselineresting_acq-AUX_run-01_meg.meg4:
#     System clock channel is available, checking which samples are valid.
#     599 x 2400 = 1437600 samples from 330 chs
# Current compensation grade : 3
# Reading 0 ... 1437599  =      0.000 ...   599.000 secs...
# Converting time column to int64...
# ds directory : data/OMEGA_BIDS/sub-0026/ses-0001/meg/sub-0026_ses-0001_task-baselineresting_run-01_meg.ds
#     res4 data read.
#     hc data read.
#     Separate EEG position data file not present.
#     Quaternion matching (desired vs. transformed):
#       -2.11   71.13    0.00 mm <->   -2.11   71.13    0.00 mm (orig :  -41.96   59.64 -249.19 mm) diff =    0.000 mm
#        2.11  -71.13    0.00 mm <->    2.11  -71.13    0.00 mm (orig :   52.87  -46.49 -250.12 mm) diff =    0.000 mm
#       86.86    0.00    0.00 mm <->   86.86    0.00   -0.00 mm (orig :   70.28   60.86 -229.76 mm) diff =    0.000 mm
#     Coordinate transformations established.
#     Polhemus data for 3 HPI coils added
#     Device coordinate locations for 3 HPI coils added
# Picked positions of 3 EEG channels from channel info
#     3 EEG locations added to Polhemus data.
#     Measurement info composed.
# Finding samples for data/OMEGA_BIDS/sub-0026/ses-0001/meg/sub-0026_ses-0001_task-baselineresting_run-01_meg.ds/sub-0026_ses-0001_task-baselineresting_run-01_meg.meg4:
#     System clock channel is available, checking which samples are valid.
#     300 x 2400 = 720000 samples from 330 chs
# Current compensation grade : 3
# Reading 0 ... 719999  =      0.000 ...   300.000 secs...
# Converting time column to int64...
# ds directory : data/OMEGA_BIDS/sub-0028/ses-0001/meg/sub-0028_ses-0001_task-baselineresting_run-01_meg.ds
#     res4 data read.
#     hc data read.
#     Separate EEG position data file not present.
#     Quaternion matching (desired vs. transformed):
#       -4.04   70.44    0.00 mm <->   -4.04   70.44    0.00 mm (orig :  -46.84   58.11 -254.77 mm) diff =    0.000 mm
#        4.04  -70.44    0.00 mm <->    4.05  -70.44    0.00 mm (orig :   42.39  -51.18 -252.10 mm) diff =    0.000 mm
#      103.94    0.00    0.00 mm <->  103.93   -0.00    0.00 mm (orig :   76.76   61.12 -218.23 mm) diff =    0.000 mm
#     Coordinate transformations established.
#     Polhemus data for 3 HPI coils added
#     Device coordinate locations for 3 HPI coils added
# Picked positions of 3 EEG channels from channel info
#     3 EEG locations added to Polhemus data.
#     Measurement info composed.
# Finding samples for data/OMEGA_BIDS/sub-0028/ses-0001/meg/sub-0028_ses-0001_task-baselineresting_run-01_meg.ds/sub-0028_ses-0001_task-baselineresting_run-01_meg.meg4:
#     System clock channel is available, checking which samples are valid.
#     600 x 2400 = 1440000 samples from 330 chs
# Current compensation grade : 3
# Reading 0 ... 1439999  =      0.000 ...   600.000 secs...
# Converting time column to int64...
# ds directory : data/OMEGA_BIDS/sub-0029/ses-0001/meg/sub-0029_ses-0001_task-baselineresting_run-01_meg.ds
#     res4 data read.
#     hc data read.
#     Separate EEG position data file not present.
#     Quaternion matching (desired vs. transformed):
#       -2.66   64.43    0.00 mm <->   -2.66   64.43    0.00 mm (orig :  -50.56   37.42 -249.22 mm) diff =    0.000 mm
#        2.66  -64.43    0.00 mm <->    2.66  -64.43    0.00 mm (orig :   42.61  -51.74 -247.03 mm) diff =    0.000 mm
#       99.23    0.00    0.00 mm <->   99.23   -0.00   -0.00 mm (orig :   64.65   59.28 -221.25 mm) diff =    0.000 mm
#     Coordinate transformations established.
#     Polhemus data for 3 HPI coils added
#     Device coordinate locations for 3 HPI coils added
# Picked positions of 3 EEG channels from channel info
#     3 EEG locations added to Polhemus data.
#     Measurement info composed.
# Finding samples for data/OMEGA_BIDS/sub-0029/ses-0001/meg/sub-0029_ses-0001_task-baselineresting_run-01_meg.ds/sub-0029_ses-0001_task-baselineresting_run-01_meg.meg4:
#     System clock channel is available, checking which samples are valid.
#     300 x 2400 = 720000 samples from 330 chs
# Current compensation grade : 3
# Reading 0 ... 719999  =      0.000 ...   300.000 secs...
# Converting time column to int64...
# ds directory : data/OMEGA_BIDS/sub-0030/ses-0001/meg/sub-0030_ses-0001_task-baselineresting_run-01_meg.ds
#     res4 data read.
#     hc data read.
#     Separate EEG position data file not present.
#     Quaternion matching (desired vs. transformed):
#       -1.90   71.12    0.00 mm <->   -1.90   71.12    0.00 mm (orig :  -48.25   52.46 -258.49 mm) diff =    0.000 mm
#        1.90  -71.12    0.00 mm <->    1.90  -71.12    0.00 mm (orig :   52.80  -47.70 -260.20 mm) diff =    0.000 mm
#      104.48    0.00    0.00 mm <->  104.48   -0.00    0.00 mm (orig :   75.15   71.44 -230.42 mm) diff =    0.000 mm
#     Coordinate transformations established.
#     Polhemus data for 3 HPI coils added
#     Device coordinate locations for 3 HPI coils added
# Picked positions of 3 EEG channels from channel info
#     3 EEG locations added to Polhemus data.
#     Measurement info composed.
# Finding samples for data/OMEGA_BIDS/sub-0030/ses-0001/meg/sub-0030_ses-0001_task-baselineresting_run-01_meg.ds/sub-0030_ses-0001_task-baselineresting_run-01_meg.meg4:
#     System clock channel is available, checking which samples are valid.
#     300 x 2400 = 720000 samples from 330 chs
# Current compensation grade : 3
# Reading 0 ... 719999  =      0.000 ...   300.000 secs...
# Converting time column to int64...
# ds directory : data/OMEGA_BIDS/sub-0031/ses-0001/meg/sub-0031_ses-0001_task-restingaftertask_run-09_meg.ds
#     res4 data read.
#     hc data read.
#     Separate EEG position data file not present.
#     Quaternion matching (desired vs. transformed):
#       -0.90   73.02    0.00 mm <->   -0.90   73.02    0.00 mm (orig :  -51.85   50.96 -262.39 mm) diff =    0.000 mm
#        0.90  -73.02    0.00 mm <->    0.90  -73.02    0.00 mm (orig :   47.50  -55.56 -251.73 mm) diff =    0.000 mm
#      103.62    0.00    0.00 mm <->  103.62    0.00    0.00 mm (orig :   72.05   67.18 -237.08 mm) diff =    0.000 mm
#     Coordinate transformations established.
#     Polhemus data for 3 HPI coils added
#     Device coordinate locations for 3 HPI coils added
# Picked positions of 3 EEG channels from channel info
#     3 EEG locations added to Polhemus data.
#     Measurement info composed.
# Finding samples for data/OMEGA_BIDS/sub-0031/ses-0001/meg/sub-0031_ses-0001_task-restingaftertask_run-09_meg.ds/sub-0031_ses-0001_task-restingaftertask_run-09_meg.meg4:
#     System clock channel is available, checking which samples are valid.
#     300 x 2400 = 720000 samples from 330 chs
# Current compensation grade : 3
# Reading 0 ... 719999  =      0.000 ...   300.000 secs...
# Converting time column to int64...
# ds directory : data/OMEGA_BIDS/sub-0032/ses-0001/meg/sub-0032_ses-0001_task-restingaftertask_run-02_meg.ds
#     res4 data read.
#     hc data read.
#     Separate EEG position data file not present.
#     Quaternion matching (desired vs. transformed):
#       -0.04   70.65    0.00 mm <->   -0.04   70.65    0.00 mm (orig :  -45.79   47.85 -247.34 mm) diff =    0.000 mm
#        0.04  -70.65    0.00 mm <->    0.04  -70.65    0.00 mm (orig :   53.43  -52.41 -239.01 mm) diff =    0.000 mm
#       89.65    0.00    0.00 mm <->   89.65    0.00    0.00 mm (orig :   65.58   60.24 -225.42 mm) diff =    0.000 mm
#     Coordinate transformations established.
#     Polhemus data for 3 HPI coils added
#     Device coordinate locations for 3 HPI coils added
# Picked positions of 2 EEG channels from channel info
#     2 EEG locations added to Polhemus data.
#     Measurement info composed.
# Finding samples for data/OMEGA_BIDS/sub-0032/ses-0001/meg/sub-0032_ses-0001_task-restingaftertask_run-02_meg.ds/sub-0032_ses-0001_task-restingaftertask_run-02_meg.meg4:
#     System clock channel is available, checking which samples are valid.
#     300 x 2400 = 720000 samples from 301 chs
# Current compensation grade : 3
# Reading 0 ... 719999  =      0.000 ...   300.000 secs...
# Converting time column to int64...
# ds directory : data/OMEGA_BIDS/sub-0033/ses-0001/meg/sub-0033_ses-0001_task-restingaftertask_run-09_meg.ds
#     res4 data read.
#     hc data read.
#     Separate EEG position data file not present.
#     Quaternion matching (desired vs. transformed):
#        2.11   68.43    0.00 mm <->    2.11   68.43    0.00 mm (orig :  -53.77   51.45 -248.28 mm) diff =    0.000 mm
#       -2.11  -68.43    0.00 mm <->   -2.11  -68.43    0.00 mm (orig :   37.38  -50.74 -248.71 mm) diff =    0.000 mm
#       92.18    0.00    0.00 mm <->   92.18   -0.00    0.00 mm (orig :   58.43   63.57 -240.61 mm) diff =    0.000 mm
#     Coordinate transformations established.
#     Polhemus data for 3 HPI coils added
#     Device coordinate locations for 3 HPI coils added
# Picked positions of 3 EEG channels from channel info
#     3 EEG locations added to Polhemus data.
#     Measurement info composed.
# Finding samples for data/OMEGA_BIDS/sub-0033/ses-0001/meg/sub-0033_ses-0001_task-restingaftertask_run-09_meg.ds/sub-0033_ses-0001_task-restingaftertask_run-09_meg.meg4:
#     System clock channel is available, checking which samples are valid.
#     300 x 2400 = 720000 samples from 330 chs
# Current compensation grade : 3
# Reading 0 ... 719999  =      0.000 ...   300.000 secs...
# Converting time column to int64...
# ds directory : data/OMEGA_BIDS/sub-0035/ses-0001/meg/sub-0035_ses-0001_task-baselineresting_run-01_meg.ds
#     res4 data read.
#     hc data read.
#     Separate EEG position data file not present.
#     Quaternion matching (desired vs. transformed):
#       -3.05   70.89    0.00 mm <->   -3.05   70.89    0.00 mm (orig :  -54.95   48.44 -241.65 mm) diff =    0.000 mm
#        3.05  -70.89    0.00 mm <->    3.05  -70.89   -0.00 mm (orig :   42.77  -54.36 -246.40 mm) diff =    0.000 mm
#       97.40    0.00    0.00 mm <->   97.40   -0.00    0.00 mm (orig :   67.35   60.99 -242.32 mm) diff =    0.000 mm
#     Coordinate transformations established.
#     Polhemus data for 3 HPI coils added
#     Device coordinate locations for 3 HPI coils added
# Picked positions of 3 EEG channels from channel info
#     3 EEG locations added to Polhemus data.
#     Measurement info composed.
# Finding samples for data/OMEGA_BIDS/sub-0035/ses-0001/meg/sub-0035_ses-0001_task-baselineresting_run-01_meg.ds/sub-0035_ses-0001_task-baselineresting_run-01_meg.meg4:
#     System clock channel is available, checking which samples are valid.
#     300 x 2400 = 720000 samples from 330 chs
# Current compensation grade : 3
# Reading 0 ... 719999  =      0.000 ...   300.000 secs...
# Converting time column to int64...
# ds directory : data/OMEGA_BIDS/sub-0036/ses-0001/meg/sub-0036_ses-0001_task-baselineresting_acq-AUX_run-01_meg.ds
#     res4 data read.
#     hc data read.
#     Separate EEG position data file not present.
#     Quaternion matching (desired vs. transformed):
#        3.87   70.12    0.00 mm <->    3.87   70.12    0.00 mm (orig :  -48.05   52.04 -262.74 mm) diff =    0.000 mm
#       -3.87  -70.12    0.00 mm <->   -3.87  -70.12    0.00 mm (orig :   56.90  -41.12 -268.45 mm) diff =    0.000 mm
#       96.54    0.00    0.00 mm <->   96.54    0.00    0.00 mm (orig :   59.89   73.52 -225.44 mm) diff =    0.000 mm
#     Coordinate transformations established.
#     Polhemus data for 3 HPI coils added
#     Device coordinate locations for 3 HPI coils added
# Picked positions of 3 EEG channels from channel info
#     3 EEG locations added to Polhemus data.
#     Measurement info composed.
# Finding samples for data/OMEGA_BIDS/sub-0036/ses-0001/meg/sub-0036_ses-0001_task-baselineresting_acq-AUX_run-01_meg.ds/sub-0036_ses-0001_task-baselineresting_acq-AUX_run-01_meg.meg4:
#     System clock channel is available, checking which samples are valid.
#     599 x 2400 = 1437600 samples from 330 chs
# Current compensation grade : 3
# Reading 0 ... 1437599  =      0.000 ...   599.000 secs...
# Converting time column to int64...
# ds directory : data/OMEGA_BIDS/sub-0037/ses-0001/meg/sub-0037_ses-0001_task-restingaftertask_run-07_meg.ds
#     res4 data read.
#     hc data read.
#     Separate EEG position data file not present.
#     Quaternion matching (desired vs. transformed):
#       -1.16   70.83    0.00 mm <->   -1.16   70.83   -0.00 mm (orig :  -48.61   52.61 -244.68 mm) diff =    0.000 mm
#        1.16  -70.83    0.00 mm <->    1.16  -70.83    0.00 mm (orig :   44.41  -54.25 -244.23 mm) diff =    0.000 mm
#       93.55    0.00    0.00 mm <->   93.55    0.00   -0.00 mm (orig :   68.94   59.03 -233.35 mm) diff =    0.000 mm
#     Coordinate transformations established.
#     Polhemus data for 3 HPI coils added
#     Device coordinate locations for 3 HPI coils added
# Picked positions of 3 EEG channels from channel info
#     3 EEG locations added to Polhemus data.
#     Measurement info composed.
# Finding samples for data/OMEGA_BIDS/sub-0037/ses-0001/meg/sub-0037_ses-0001_task-restingaftertask_run-07_meg.ds/sub-0037_ses-0001_task-restingaftertask_run-07_meg.meg4:
#     System clock channel is available, checking which samples are valid.
#     300 x 2400 = 720000 samples from 330 chs
# Current compensation grade : 3
# Reading 0 ... 719999  =      0.000 ...   300.000 secs...
# Converting time column to int64...
# ds directory : data/OMEGA_BIDS/sub-0040/ses-0001/meg/sub-0040_ses-0001_task-baselineresting_acq-AUX_run-01_meg.ds
#     res4 data read.
#     hc data read.
#     Separate EEG position data file not present.
#     Quaternion matching (desired vs. transformed):
#        2.60   72.35    0.00 mm <->    2.60   72.35   -0.00 mm (orig :  -44.09   57.28 -267.25 mm) diff =    0.000 mm
#       -2.60  -72.35    0.00 mm <->   -2.60  -72.35    0.00 mm (orig :   55.42  -47.88 -264.63 mm) diff =    0.000 mm
#      107.51    0.00    0.00 mm <->  107.51    0.00   -0.00 mm (orig :   74.42   76.10 -224.32 mm) diff =    0.000 mm
#     Coordinate transformations established.
#     Polhemus data for 3 HPI coils added
#     Device coordinate locations for 3 HPI coils added
# Picked positions of 3 EEG channels from channel info
#     3 EEG locations added to Polhemus data.
#     Measurement info composed.
# Finding samples for data/OMEGA_BIDS/sub-0040/ses-0001/meg/sub-0040_ses-0001_task-baselineresting_acq-AUX_run-01_meg.ds/sub-0040_ses-0001_task-baselineresting_acq-AUX_run-01_meg.meg4:
#     System clock channel is available, checking which samples are valid.
#     599 x 2400 = 1437600 samples from 330 chs
# Current compensation grade : 3
# Reading 0 ... 1437599  =      0.000 ...   599.000 secs...
# Converting time column to int64...
# ds directory : data/OMEGA_BIDS/sub-0041/ses-0001/meg/sub-0041_ses-0001_task-baselineresting_acq-AUX_run-03_meg.ds
#     res4 data read.
#     hc data read.
#     Separate EEG position data file not present.
#     Quaternion matching (desired vs. transformed):
#       -0.85   76.48    0.00 mm <->   -0.85   76.48    0.00 mm (orig :  -46.14   59.20 -259.00 mm) diff =    0.000 mm
#        0.85  -76.48    0.00 mm <->    0.85  -76.48    0.00 mm (orig :   56.59  -54.14 -259.86 mm) diff =    0.000 mm
#       98.79    0.00    0.00 mm <->   98.79    0.00    0.00 mm (orig :   74.35   63.43 -223.78 mm) diff =    0.000 mm
#     Coordinate transformations established.
#     Polhemus data for 3 HPI coils added
#     Device coordinate locations for 3 HPI coils added
# Picked positions of 3 EEG channels from channel info
#     3 EEG locations added to Polhemus data.
#     Measurement info composed.
# Finding samples for data/OMEGA_BIDS/sub-0041/ses-0001/meg/sub-0041_ses-0001_task-baselineresting_acq-AUX_run-03_meg.ds/sub-0041_ses-0001_task-baselineresting_acq-AUX_run-03_meg.meg4:
#     System clock channel is available, checking which samples are valid.
#     299 x 2400 = 717600 samples from 330 chs
# Current compensation grade : 3
# Reading 0 ... 717599  =      0.000 ...   299.000 secs...
# Converting time column to int64...
# ds directory : data/OMEGA_BIDS/sub-0045/ses-0001/meg/sub-0045_ses-0001_task-baselineresting_acq-AUX_run-01_meg.ds
#     res4 data read.
#     hc data read.
#     Separate EEG position data file not present.
#     Quaternion matching (desired vs. transformed):
#       -0.93   70.35    0.00 mm <->   -0.93   70.35    0.00 mm (orig :  -51.80   44.11 -258.65 mm) diff =    0.000 mm
#        0.93  -70.35    0.00 mm <->    0.93  -70.35    0.00 mm (orig :   52.11  -50.76 -259.46 mm) diff =    0.000 mm
#      101.33    0.00    0.00 mm <->  101.33   -0.00    0.00 mm (orig :   66.01   66.56 -226.70 mm) diff =    0.000 mm
#     Coordinate transformations established.
#     Polhemus data for 3 HPI coils added
#     Device coordinate locations for 3 HPI coils added
# Picked positions of 3 EEG channels from channel info
#     3 EEG locations added to Polhemus data.
#     Measurement info composed.
# Finding samples for data/OMEGA_BIDS/sub-0045/ses-0001/meg/sub-0045_ses-0001_task-baselineresting_acq-AUX_run-01_meg.ds/sub-0045_ses-0001_task-baselineresting_acq-AUX_run-01_meg.meg4:
#     System clock channel is available, checking which samples are valid.
#     599 x 2400 = 1437600 samples from 330 chs
# Current compensation grade : 3
# Reading 0 ... 1437599  =      0.000 ...   599.000 secs...
# Converting time column to int64...
# ds directory : data/OMEGA_BIDS/sub-0046/ses-0001/meg/sub-0046_ses-0001_task-restingaftertask_run-02_meg.ds
#     res4 data read.
#     hc data read.
#     Separate EEG position data file not present.
#     Quaternion matching (desired vs. transformed):
#        3.60   68.80    0.00 mm <->    3.60   68.80    0.00 mm (orig :  -38.12   59.41 -247.05 mm) diff =    0.000 mm
#       -3.60  -68.80    0.00 mm <->   -3.60  -68.80    0.00 mm (orig :   54.04  -42.42 -258.13 mm) diff =    0.000 mm
#       84.58    0.00    0.00 mm <->   84.58   -0.00   -0.00 mm (orig :   65.60   63.57 -224.33 mm) diff =    0.000 mm
#     Coordinate transformations established.
#     Polhemus data for 3 HPI coils added
#     Device coordinate locations for 3 HPI coils added
# Picked positions of 3 EEG channels from channel info
#     3 EEG locations added to Polhemus data.
#     Measurement info composed.
# Finding samples for data/OMEGA_BIDS/sub-0046/ses-0001/meg/sub-0046_ses-0001_task-restingaftertask_run-02_meg.ds/sub-0046_ses-0001_task-restingaftertask_run-02_meg.meg4:
#     System clock channel is available, checking which samples are valid.
#     300 x 2400 = 720000 samples from 334 chs
# Current compensation grade : 3
# Reading 0 ... 719999  =      0.000 ...   300.000 secs...
# Converting time column to int64...
# ds directory : data/OMEGA_BIDS/sub-0047/ses-0001/meg/sub-0047_ses-0001_task-restingaftertask_run-02_meg.ds
#     res4 data read.
#     hc data read.
#     Separate EEG position data file not present.
#     Quaternion matching (desired vs. transformed):
#        2.01   77.57    0.00 mm <->    2.01   77.57    0.00 mm (orig :  -53.03   57.04 -266.54 mm) diff =    0.000 mm
#       -2.01  -77.57    0.00 mm <->   -2.01  -77.57    0.00 mm (orig :   49.05  -59.86 -265.89 mm) diff =    0.000 mm
#      112.46    0.00    0.00 mm <->  112.46   -0.00    0.00 mm (orig :   78.83   73.17 -242.68 mm) diff =    0.000 mm
#     Coordinate transformations established.
#     Polhemus data for 3 HPI coils added
#     Device coordinate locations for 3 HPI coils added
# Picked positions of 2 EEG channels from channel info
#     2 EEG locations added to Polhemus data.
#     Measurement info composed.
# Finding samples for data/OMEGA_BIDS/sub-0047/ses-0001/meg/sub-0047_ses-0001_task-restingaftertask_run-02_meg.ds/sub-0047_ses-0001_task-restingaftertask_run-02_meg.meg4:
#     System clock channel is available, checking which samples are valid.
#     300 x 2400 = 720000 samples from 301 chs
# Current compensation grade : 3
# Reading 0 ... 719999  =      0.000 ...   300.000 secs...
# Converting time column to int64...
# ds directory : data/OMEGA_BIDS/sub-0048/ses-0001/meg/sub-0048_ses-0001_task-baselineresting_acq-AUX_run-01_meg.ds
#     res4 data read.
#     hc data read.
#     Separate EEG position data file not present.
#     Quaternion matching (desired vs. transformed):
#       -3.15   66.94    0.00 mm <->   -3.15   66.94   -0.00 mm (orig :  -51.31   47.41 -239.45 mm) diff =    0.000 mm
#        3.15  -66.94    0.00 mm <->    3.15  -66.94   -0.00 mm (orig :   39.63  -50.65 -248.19 mm) diff =    0.000 mm
#       99.18    0.00    0.00 mm <->   99.18   -0.00   -0.00 mm (orig :   69.38   60.03 -224.38 mm) diff =    0.000 mm
#     Coordinate transformations established.
# ...
#       -4.88  -73.47    0.00 mm <->   -4.88  -73.47    0.00 mm (orig :   50.79  -52.29 -261.47 mm) diff =    0.000 mm
#      100.20    0.00    0.00 mm <->  100.20    0.00   -0.00 mm (orig :   64.52   68.52 -220.79 mm) diff =    0.000 mm
#     Coordinate transformations established.
#     Polhemus data for 3 HPI coils added
#     Device coordinate locations for 3 HPI coils added
#     Measurement info composed.
# Finding samples for data/OMEGA_BIDS/sub-0175/ses-0001/meg/sub-0175_ses-0001_task-baselineresting_run-01_meg.ds/sub-0175_ses-0001_task-baselineresting_run-01_meg.meg4:
#     System clock channel is available, checking which samples are valid.
#     600 x 2400 = 1440000 samples from 331 chs
# Current compensation grade : 3
# Reading 0 ... 1439999  =      0.000 ...   600.000 secs...
# Converting time column to int64...
# ds directory : data/OMEGA_BIDS/sub-0176/ses-0001/meg/sub-0176_ses-0001_task-baselineresting_run-01_meg.ds
#     res4 data read.
#     hc data read.
#     Separate EEG position data file not present.
#     Quaternion matching (desired vs. transformed):
#        3.34   71.54    0.00 mm <->    3.34   71.54    0.00 mm (orig :  -46.98   53.34 -268.88 mm) diff =    0.000 mm
#       -3.34  -71.54    0.00 mm <->   -3.34  -71.54    0.00 mm (orig :   50.34  -51.73 -271.83 mm) diff =    0.000 mm
#      113.47    0.00    0.00 mm <->  113.46   -0.00    0.00 mm (orig :   74.30   73.94 -222.91 mm) diff =    0.000 mm
#     Coordinate transformations established.
#     Polhemus data for 3 HPI coils added
#     Device coordinate locations for 3 HPI coils added
#     Measurement info composed.
# Finding samples for data/OMEGA_BIDS/sub-0176/ses-0001/meg/sub-0176_ses-0001_task-baselineresting_run-01_meg.ds/sub-0176_ses-0001_task-baselineresting_run-01_meg.meg4:
#     System clock channel is available, checking which samples are valid.
#     453 x 2400 = 1088425 samples from 331 chs
#     1175 samples omitted at the end
# Current compensation grade : 3
# Reading 0 ... 1088424  =      0.000 ...   453.510 secs...
# Converting time column to int64...
# ds directory : data/OMEGA_BIDS/sub-0177/ses-0001/meg/sub-0177_ses-0001_task-baselineresting_run-01_meg.ds
#     res4 data read.
#     hc data read.
#     Separate EEG position data file not present.
#     Quaternion matching (desired vs. transformed):
#        3.87   71.29    0.00 mm <->    3.87   71.29    0.00 mm (orig :  -52.01   52.22 -247.59 mm) diff =    0.000 mm
#       -3.87  -71.29    0.00 mm <->   -3.87  -71.29   -0.00 mm (orig :   47.91  -49.65 -252.59 mm) diff =    0.000 mm
#      103.36    0.00    0.00 mm <->  103.36    0.00   -0.00 mm (orig :   59.79   67.33 -200.11 mm) diff =    0.000 mm
#     Coordinate transformations established.
#     Polhemus data for 3 HPI coils added
#     Device coordinate locations for 3 HPI coils added
#     Measurement info composed.
# Finding samples for data/OMEGA_BIDS/sub-0177/ses-0001/meg/sub-0177_ses-0001_task-baselineresting_run-01_meg.ds/sub-0177_ses-0001_task-baselineresting_run-01_meg.meg4:
#     System clock channel is available, checking which samples are valid.
#     600 x 2400 = 1440000 samples from 331 chs
# Current compensation grade : 3
# Reading 0 ... 1439999  =      0.000 ...   600.000 secs...
# Converting time column to int64...
# ds directory : data/OMEGA_BIDS/sub-0179/ses-0001/meg/sub-0179_ses-0001_task-baselineresting_run-02_meg.ds
#     res4 data read.
#     hc data read.
#     Separate EEG position data file not present.
#     Quaternion matching (desired vs. transformed):
#        4.40   67.45    0.00 mm <->    4.40   67.45    0.00 mm (orig :  -54.39   41.47 -249.89 mm) diff =    0.000 mm
#       -4.40  -67.45    0.00 mm <->   -4.40  -67.45    0.00 mm (orig :   45.36  -49.78 -249.81 mm) diff =    0.000 mm
#      105.91    0.00    0.00 mm <->  105.91    0.00   -0.00 mm (orig :   57.48   73.85 -213.95 mm) diff =    0.000 mm
#     Coordinate transformations established.
#     Polhemus data for 3 HPI coils added
#     Device coordinate locations for 3 HPI coils added
# Picked positions of 7 EEG channels from channel info
#     7 EEG locations added to Polhemus data.
#     Measurement info composed.
# Finding samples for data/OMEGA_BIDS/sub-0179/ses-0001/meg/sub-0179_ses-0001_task-baselineresting_run-02_meg.ds/sub-0179_ses-0001_task-baselineresting_run-02_meg.meg4:
#     System clock channel is available, checking which samples are valid.
#     300 x 2400 = 720000 samples from 334 chs
# Current compensation grade : 3
# Reading 0 ... 719999  =      0.000 ...   300.000 secs...
# Converting time column to int64...
# ds directory : data/OMEGA_BIDS/sub-0181/ses-0001/meg/sub-0181_ses-0001_task-baselineresting_run-01_meg.ds
#     res4 data read.
#     hc data read.
#     Separate EEG position data file not present.
#     Quaternion matching (desired vs. transformed):
#       -0.87   74.99    0.00 mm <->   -0.87   74.99    0.00 mm (orig :  -51.81   56.90 -245.61 mm) diff =    0.000 mm
#        0.87  -74.99    0.00 mm <->    0.87  -74.99    0.00 mm (orig :   47.96  -54.87 -252.50 mm) diff =    0.000 mm
#      111.20    0.00    0.00 mm <->  111.20    0.00   -0.00 mm (orig :   79.03   69.48 -215.54 mm) diff =    0.000 mm
#     Coordinate transformations established.
#     Polhemus data for 3 HPI coils added
#     Device coordinate locations for 3 HPI coils added
# Picked positions of 7 EEG channels from channel info
#     7 EEG locations added to Polhemus data.
#     Measurement info composed.
# Finding samples for data/OMEGA_BIDS/sub-0181/ses-0001/meg/sub-0181_ses-0001_task-baselineresting_run-01_meg.ds/sub-0181_ses-0001_task-baselineresting_run-01_meg.meg4:
#     System clock channel is available, checking which samples are valid.
#     300 x 2400 = 720000 samples from 334 chs
# Current compensation grade : 3
# Reading 0 ... 719999  =      0.000 ...   300.000 secs...
# Converting time column to int64...
# ds directory : data/OMEGA_BIDS/sub-0183/ses-0001/meg/sub-0183_ses-0001_task-baselineresting_run-01_meg.ds
#     res4 data read.
#     hc data read.
#     Separate EEG position data file not present.
#     Quaternion matching (desired vs. transformed):
#       -2.97   66.74    0.00 mm <->   -2.97   66.74   -0.00 mm (orig :  -44.84   48.05 -255.09 mm) diff =    0.000 mm
#        2.97  -66.74    0.00 mm <->    2.97  -66.74    0.00 mm (orig :   44.98  -50.85 -253.19 mm) diff =    0.000 mm
#      100.53    0.00    0.00 mm <->  100.53   -0.00   -0.00 mm (orig :   62.52   50.42 -194.79 mm) diff =    0.000 mm
#     Coordinate transformations established.
#     Polhemus data for 3 HPI coils added
#     Device coordinate locations for 3 HPI coils added
# Picked positions of 7 EEG channels from channel info
#     7 EEG locations added to Polhemus data.
#     Measurement info composed.
# Finding samples for data/OMEGA_BIDS/sub-0183/ses-0001/meg/sub-0183_ses-0001_task-baselineresting_run-01_meg.ds/sub-0183_ses-0001_task-baselineresting_run-01_meg.meg4:
#     System clock channel is available, checking which samples are valid.
#     300 x 2400 = 720000 samples from 334 chs
# Current compensation grade : 3
# Reading 0 ... 719999  =      0.000 ...   300.000 secs...
# Converting time column to int64...
# ds directory : data/OMEGA_BIDS/sub-0184/ses-0001/meg/sub-0184_ses-0001_task-baselineresting_run-01_meg.ds
#     res4 data read.
#     hc data read.
#     Separate EEG position data file not present.
#     Quaternion matching (desired vs. transformed):
#        2.32   69.24    0.00 mm <->    2.32   69.24    0.00 mm (orig :  -43.32   53.48 -258.48 mm) diff =    0.000 mm
#       -2.32  -69.24    0.00 mm <->   -2.32  -69.24    0.00 mm (orig :   55.55  -43.52 -261.96 mm) diff =    0.000 mm
#      109.59    0.00    0.00 mm <->  109.59    0.00    0.00 mm (orig :   72.72   76.33 -210.38 mm) diff =    0.000 mm
#     Coordinate transformations established.
#     Polhemus data for 3 HPI coils added
#     Device coordinate locations for 3 HPI coils added
# Picked positions of 36 EEG channels from channel info
#     36 EEG locations added to Polhemus data.
#     Measurement info composed.
# Finding samples for data/OMEGA_BIDS/sub-0184/ses-0001/meg/sub-0184_ses-0001_task-baselineresting_run-01_meg.ds/sub-0184_ses-0001_task-baselineresting_run-01_meg.meg4:
#     System clock channel is available, checking which samples are valid.
#     300 x 2400 = 720000 samples from 364 chs
# Current compensation grade : 3
# Reading 0 ... 719999  =      0.000 ...   300.000 secs...
# Converting time column to int64...
# ds directory : data/OMEGA_BIDS/sub-0185/ses-0001/meg/sub-0185_ses-0001_task-baselineresting_run-01_meg.ds
#     res4 data read.
#     hc data read.
#     Separate EEG position data file not present.
#     Quaternion matching (desired vs. transformed):
#       -9.62   75.03    0.00 mm <->   -9.62   75.03    0.00 mm (orig :  -53.51   57.95 -268.10 mm) diff =    0.000 mm
#        9.62  -75.03    0.00 mm <->    9.62  -75.03    0.00 mm (orig :   49.69  -52.67 -267.45 mm) diff =    0.000 mm
#      113.41    0.00    0.00 mm <->  113.41    0.00   -0.00 mm (orig :   83.28   62.67 -223.05 mm) diff =    0.000 mm
#     Coordinate transformations established.
#     Polhemus data for 3 HPI coils added
#     Device coordinate locations for 3 HPI coils added
# Picked positions of 36 EEG channels from channel info
#     36 EEG locations added to Polhemus data.
#     Measurement info composed.
# Finding samples for data/OMEGA_BIDS/sub-0185/ses-0001/meg/sub-0185_ses-0001_task-baselineresting_run-01_meg.ds/sub-0185_ses-0001_task-baselineresting_run-01_meg.meg4:
#     System clock channel is available, checking which samples are valid.
#     300 x 2400 = 720000 samples from 363 chs
# Current compensation grade : 3
# Reading 0 ... 719999  =      0.000 ...   300.000 secs...
# Converting time column to int64...
# ds directory : data/OMEGA_BIDS/sub-0186/ses-0001/meg/sub-0186_ses-0001_task-baselineresting_run-03_meg.ds
#     res4 data read.
#     hc data read.
#     Separate EEG position data file not present.
#     Quaternion matching (desired vs. transformed):
#       -0.73   69.12    0.00 mm <->   -0.73   69.12    0.00 mm (orig :  -38.86   59.97 -244.31 mm) diff =    0.000 mm
#        0.73  -69.12    0.00 mm <->    0.73  -69.12    0.00 mm (orig :   52.00  -44.18 -246.60 mm) diff =    0.000 mm
#       95.72    0.00    0.00 mm <->   95.72    0.00   -0.00 mm (orig :   69.05   59.95 -194.97 mm) diff =    0.000 mm
#     Coordinate transformations established.
#     Polhemus data for 3 HPI coils added
#     Device coordinate locations for 3 HPI coils added
# Picked positions of 7 EEG channels from channel info
#     7 EEG locations added to Polhemus data.
#     Measurement info composed.
# Finding samples for data/OMEGA_BIDS/sub-0186/ses-0001/meg/sub-0186_ses-0001_task-baselineresting_run-03_meg.ds/sub-0186_ses-0001_task-baselineresting_run-03_meg.meg4:
#     System clock channel is available, checking which samples are valid.
#     300 x 2400 = 720000 samples from 334 chs
# Current compensation grade : 3
# Reading 0 ... 719999  =      0.000 ...   300.000 secs...
# Converting time column to int64...
# ds directory : data/OMEGA_BIDS/sub-0187/ses-0001/meg/sub-0187_ses-0001_task-baselineresting_run-01_meg.ds
#     res4 data read.
#     hc data read.
#     Separate EEG position data file not present.
#     Quaternion matching (desired vs. transformed):
#        3.71   76.31    0.00 mm <->    3.71   76.31    0.00 mm (orig :  -54.06   54.93 -253.34 mm) diff =    0.000 mm
#       -3.71  -76.31    0.00 mm <->   -3.71  -76.31    0.00 mm (orig :   53.20  -53.89 -251.45 mm) diff =    0.000 mm
#      112.41    0.00    0.00 mm <->  112.41    0.00    0.00 mm (orig :   60.18   69.06 -187.10 mm) diff =    0.000 mm
#     Coordinate transformations established.
#     Polhemus data for 3 HPI coils added
#     Device coordinate locations for 3 HPI coils added
# Picked positions of 7 EEG channels from channel info
#     7 EEG locations added to Polhemus data.
#     Measurement info composed.
# Finding samples for data/OMEGA_BIDS/sub-0187/ses-0001/meg/sub-0187_ses-0001_task-baselineresting_run-01_meg.ds/sub-0187_ses-0001_task-baselineresting_run-01_meg.meg4:
#     System clock channel is available, checking which samples are valid.
#     300 x 2400 = 720000 samples from 334 chs
# Current compensation grade : 3
# Reading 0 ... 719999  =      0.000 ...   300.000 secs...
# Converting time column to int64...
# ds directory : data/OMEGA_BIDS/sub-0188/ses-0001/meg/sub-0188_ses-0001_task-baselineresting_run-01_meg.ds
#     res4 data read.
#     hc data read.
#     Separate EEG position data file not present.
#     Quaternion matching (desired vs. transformed):
#       -1.55   66.95    0.00 mm <->   -1.55   66.95    0.00 mm (orig :  -54.39   40.97 -252.49 mm) diff =    0.000 mm
#        1.55  -66.95    0.00 mm <->    1.55  -66.95    0.00 mm (orig :   43.26  -50.35 -244.62 mm) diff =    0.000 mm
#      105.42    0.00    0.00 mm <->  105.42    0.00    0.00 mm (orig :   59.16   64.90 -202.93 mm) diff =    0.000 mm
#     Coordinate transformations established.
#     Polhemus data for 3 HPI coils added
#     Device coordinate locations for 3 HPI coils added
# Picked positions of 7 EEG channels from channel info
#     7 EEG locations added to Polhemus data.
#     Measurement info composed.
# Finding samples for data/OMEGA_BIDS/sub-0188/ses-0001/meg/sub-0188_ses-0001_task-baselineresting_run-01_meg.ds/sub-0188_ses-0001_task-baselineresting_run-01_meg.meg4:
#     System clock channel is available, checking which samples are valid.
#     300 x 2400 = 720000 samples from 334 chs
# Current compensation grade : 3
# Reading 0 ... 719999  =      0.000 ...   300.000 secs...
# Converting time column to int64...
# ds directory : data/OMEGA_BIDS/sub-0189/ses-0001/meg/sub-0189_ses-0001_task-baselineresting_run-01_meg.ds
#     res4 data read.
#     hc data read.
#     Separate EEG position data file not present.
#     Quaternion matching (desired vs. transformed):
#        0.06   72.08    0.00 mm <->    0.06   72.08   -0.00 mm (orig :  -56.61   46.85 -255.78 mm) diff =    0.000 mm
#       -0.06  -72.08    0.00 mm <->   -0.06  -72.08    0.00 mm (orig :   50.54  -49.42 -261.44 mm) diff =    0.000 mm
#      103.65    0.00    0.00 mm <->  103.65    0.00   -0.00 mm (orig :   60.93   67.45 -214.70 mm) diff =    0.000 mm
#     Coordinate transformations established.
#     Polhemus data for 3 HPI coils added
#     Device coordinate locations for 3 HPI coils added
# Picked positions of 7 EEG channels from channel info
#     7 EEG locations added to Polhemus data.
#     Measurement info composed.
# Finding samples for data/OMEGA_BIDS/sub-0189/ses-0001/meg/sub-0189_ses-0001_task-baselineresting_run-01_meg.ds/sub-0189_ses-0001_task-baselineresting_run-01_meg.meg4:
#     System clock channel is available, checking which samples are valid.
#     300 x 2400 = 720000 samples from 334 chs
# Current compensation grade : 3
# Reading 0 ... 719999  =      0.000 ...   300.000 secs...
# Converting time column to int64...
# ds directory : data/OMEGA_BIDS/sub-0190/ses-0001/meg/sub-0190_ses-0001_task-baselineresting_run-01_meg.ds
#     res4 data read.
#     hc data read.
#     Separate EEG position data file not present.
#     Quaternion matching (desired vs. transformed):
#        2.11   74.98    0.00 mm <->    2.11   74.98    0.00 mm (orig :  -47.34   54.97 -258.89 mm) diff =    0.000 mm
#       -2.11  -74.98    0.00 mm <->   -2.11  -74.98    0.00 mm (orig :   52.09  -57.28 -254.86 mm) diff =    0.000 mm
#      117.74    0.00    0.00 mm <->  117.74   -0.00   -0.00 mm (orig :   67.24   63.39 -182.78 mm) diff =    0.000 mm
#     Coordinate transformations established.
#     Polhemus data for 3 HPI coils added
#     Device coordinate locations for 3 HPI coils added
# Picked positions of 7 EEG channels from channel info
#     7 EEG locations added to Polhemus data.
#     Measurement info composed.
# Finding samples for data/OMEGA_BIDS/sub-0190/ses-0001/meg/sub-0190_ses-0001_task-baselineresting_run-01_meg.ds/sub-0190_ses-0001_task-baselineresting_run-01_meg.meg4:
#     System clock channel is available, checking which samples are valid.
#     300 x 2400 = 720000 samples from 334 chs
# Current compensation grade : 3
# Reading 0 ... 719999  =      0.000 ...   300.000 secs...
# Converting time column to int64...

# %%
subs_names = ['sub-0055']
x = 0
filename = 'data/OMEGA_BIDS/sub-0055/ses-0001/meg/sub-0055_ses-0001_task-baselineresting_run-01_meg.ds'
raw = mne.io.read_raw_ctf(filename, preload = True)
raw = raw.pick_channels(['HLC0011-4408','HLC0012-4408','HLC0013-4408', 'HLC0021-4408', 'HLC0022-4408','HLC0023-4408','HLC0031-4408','HLC0032-4408','HLC0033-4408', 'ECG','VEOG','HEOG']).to_data_frame()
# Out:
# ds directory : data/OMEGA_BIDS/sub-0055/ses-0001/meg/sub-0055_ses-0001_task-baselineresting_run-01_meg.ds
#     res4 data read.
#     hc data read.
#     Separate EEG position data file not present.
#     Quaternion matching (desired vs. transformed):
#        4.76   69.82    0.00 mm <->    4.76   69.82    0.00 mm (orig :  -39.92   58.81 -242.19 mm) diff =    0.000 mm
#       -4.76  -69.82    0.00 mm <->   -4.76  -69.82    0.00 mm (orig :   61.25  -37.45 -251.50 mm) diff =    0.000 mm
#       95.77    0.00    0.00 mm <->   95.77    0.00    0.00 mm (orig :   70.14   79.83 -217.63 mm) diff =    0.000 mm
#     Coordinate transformations established.
#     Polhemus data for 3 HPI coils added
#     Device coordinate locations for 3 HPI coils added
# Picked positions of 3 EEG channels from channel info
#     3 EEG locations added to Polhemus data.
#     Measurement info composed.
# Finding samples for data/OMEGA_BIDS/sub-0055/ses-0001/meg/sub-0055_ses-0001_task-baselineresting_run-01_meg.ds/sub-0055_ses-0001_task-baselineresting_run-01_meg.meg4:
#     System clock channel is available, checking which samples are valid.
#     300 x 2400 = 720000 samples from 330 chs
# Current compensation grade : 3
# Reading 0 ... 719999  =      0.000 ...   300.000 secs...
# Converting time column to int64...

# %%
# ECG
if 'ECG' in raw.columns:
    ecg = raw['ECG'].values
    ecg = np.sqrt((ecg.dot(ecg))/(len(ecg)))
else:
    ecg = np.nan

# EOG
if 'VEOG' in raw.columns and 'HEOG' in raw.columns:
    veog = raw['VEOG'].values
    heog = raw['HEOG'].values
    eog = np.sqrt((veog * veog) + (heog * heog))
    eog = np.sqrt((eog.dot(eog))/(len(eog)))
else:
    eog = np.nan


# Motion
if 'HLC0011-4408' in raw.columns and 'HLC0012-4408' in raw.columns and 'HLC0013-4408' in raw.columns and 'HLC0021-4408' in raw.columns and 'HLC0022-4408' in raw.columns and 'HLC0023-4408' in raw.columns and 'HLC0031-4408' in raw.columns and 'HLC0032-4408' in raw.columns and 'HLC0033-4408' in raw.columns:
    coil1 = np.sqrt((raw['HLC0011-4408'].values*raw['HLC0011-4408'].values) + (raw['HLC0012-4408'].values*raw['HLC0012-4408'].values) + (raw['HLC0013-4408'].values*raw['HLC0013-4408'].values))
    coil2 = np.sqrt((raw['HLC0021-4408'].values*raw['HLC0021-4408'].values) + (raw['HLC0022-4408'].values*raw['HLC0022-4408'].values) + (raw['HLC0023-4408'].values*raw['HLC0023-4408'].values))
    coil3 = np.sqrt((raw['HLC0031-4408'].values*raw['HLC0031-4408'].values) + (raw['HLC0032-4408'].values*raw['HLC0032-4408'].values) + (raw['HLC0033-4408'].values*raw['HLC0033-4408'].values))
    coil1 = np.sqrt((coil1.dot(coil1))/(len(coil1)))
    coil2 = np.sqrt((coil2.dot(coil2))/(len(coil2)))
    coil3 = np.sqrt((coil3.dot(coil3))/(len(coil3)))
    motion = np.mean([coil1, coil2, coil3])
else:
    motion = np.nan

print(ecg)
print(eog)
print(motion)
# Out:
# 11568.593625682868
# 56825.66344998488
# 0.25104672522407845

# %%
import pandas as pd
pd_sanity_checks = pd.DataFrame(data = sanity_checks, columns = ['sub', 'ecg', 'eog', 'motion'])
pd_sanity_checks.to_csv('output/eog_ecg_motion')

# %%
from glob import glob
import mne as mne
import numpy as np
subs_names = glob('../brainstorm_db/omMachina/data/*/')
subs_names = sorted([x[-9:-1] for x in subs_names])[3:]
subs_names
# Out:
# ['sub-0001',
#  'sub-0002',
#  'sub-0003',
#  'sub-0004',
#  'sub-0005',
#  'sub-0006',
#  'sub-0007',
#  'sub-0008',
#  'sub-0009',
#  'sub-0011',
#  'sub-0012',
#  'sub-0013',
#  'sub-0014',
#  'sub-0015',
#  'sub-0016',
#  'sub-0018',
#  'sub-0020',
#  'sub-0021',
#  'sub-0022',
#  'sub-0023',
#  'sub-0024',
#  'sub-0025',
#  'sub-0026',
#  'sub-0028',
#  'sub-0029',
#  'sub-0030',
#  'sub-0031',
#  'sub-0032',
#  'sub-0033',
#  'sub-0035',
#  'sub-0036',
#  'sub-0037',
#  'sub-0040',
#  'sub-0041',
#  'sub-0045',
#  'sub-0046',
#  'sub-0047',
#  'sub-0048',
#  'sub-0049',
#  'sub-0050',
#  'sub-0051',
#  'sub-0052',
#  'sub-0053',
#  'sub-0054',
#  'sub-0056',
#  'sub-0058',
#  'sub-0060',
#  'sub-0061',
#  'sub-0062',
#  'sub-0063',
#  'sub-0064',
#  'sub-0065',
#  'sub-0066',
#  'sub-0067',
#  'sub-0068',
#  'sub-0069',
#  'sub-0070',
#  'sub-0071',
#  'sub-0074',
#  'sub-0075',
#  'sub-0076',
#  'sub-0077',
#  'sub-0078',
#  'sub-0079',
#  'sub-0080',
#  'sub-0082',
#  'sub-0083',
#  'sub-0084',
#  'sub-0085',
#  'sub-0086',
#  'sub-0087',
#  'sub-0088',
#  'sub-0089',
#  'sub-0090',
#  'sub-0091',
#  'sub-0093',
#  'sub-0094',
#  'sub-0095',
#  'sub-0096',
#  'sub-0097',
#  'sub-0098',
#  'sub-0099',
#  'sub-0101',
#  'sub-0102',
#  'sub-0103',
#  'sub-0105',
#  'sub-0106',
#  'sub-0108',
#  'sub-0109',
#  'sub-0110',
#  'sub-0111',
#  'sub-0112',
#  'sub-0114',
#  'sub-0116',
#  'sub-0117',
#  'sub-0118',
#  'sub-0119',
#  'sub-0120',
#  'sub-0121',
#  'sub-0123',
#  'sub-0125',
#  'sub-0126',
#  'sub-0127',
#  'sub-0128',
#  'sub-0129',
#  'sub-0130',
#  'sub-0131',
#  'sub-0132',
#  'sub-0133',
#  'sub-0134',
#  'sub-0135',
#  'sub-0136',
#  'sub-0139',
#  'sub-0140',
#  'sub-0141',
#  'sub-0142',
#  'sub-0143',
#  'sub-0144',
#  'sub-0145',
#  'sub-0146',
#  'sub-0147',
#  'sub-0148',
#  'sub-0149',
#  'sub-0150',
#  'sub-0151',
#  'sub-0152',
#  'sub-0153',
#  'sub-0154',
#  'sub-0155',
#  'sub-0156',
#  'sub-0157',
#  'sub-0158',
#  'sub-0159',
#  'sub-0160',
#  'sub-0161',
#  'sub-0162',
#  'sub-0164',
#  'sub-0165',
#  'sub-0166',
#  'sub-0167',
#  'sub-0168',
#  'sub-0169',
#  'sub-0170',
#  'sub-0171',
#  'sub-0172',
#  'sub-0174',
#  'sub-0175',
#  'sub-0176',
#  'sub-0177',
#  'sub-0179',
#  'sub-0181',
#  'sub-0183',
#  'sub-0184',
#  'sub-0185',
#  'sub-0186',
#  'sub-0187',
#  'sub-0188',
#  'sub-0189',
#  'sub-0190']

# %% [markdown]
# # Sanity checks: Beamformer weights

# %%
# For now we gonna do it all the way to 125 -. Index 100
import scipy.io as sio

n_subs = 100
subs_names = glob('../brainstorm_db/omMachina/data/*/')
subs_names = sorted([x[-9:-1] for x in subs_names])[3:]
freqs = ['delta', 'theta', 'alpha', 'beta', 'gamma', 'hgamma']
weights_grand_matrix = np.zeros([n_subs, 15002*270*6])

for i_sub in range(n_subs):
    print('No getting %s' % subs_names[i_sub])
    mat_file_delta = sio.loadmat('output/beamformer_weights/' + subs_names[i_sub] + '_beamformer_weights_' + freqs[i_freq])
    weights_grand_matrix[ifreq: , i_sub] = mat_file['ImagingKernel'].
# Out:
# (15002, 270)

# %%
i_sub = 0
mat_file_delta = sio.loadmat('output/beamformer_weights/' + subs_names[i_sub] + '_beamformer_weights_delta')['ImagingKernel']
mat_file_theta = sio.loadmat('output/beamformer_weights/' + subs_names[i_sub] + '_beamformer_weights_theta')['ImagingKernel']
mat_file_alpha = sio.loadmat('output/beamformer_weights/' + subs_names[i_sub] + '_beamformer_weights_alpha')['ImagingKernel']
mat_file_beta = sio.loadmat('output/beamformer_weights/' + subs_names[i_sub] + '_beamformer_weights_beta')['ImagingKernel']
mat_file_gamma = sio.loadmat('output/beamformer_weights/' + subs_names[i_sub] + '_beamformer_weights_gamma')['ImagingKernel']
mat_file_hgamma = sio.loadmat('output/beamformer_weights/' + subs_names[i_sub] + '_beamformer_weights_hgamma')['ImagingKernel']
weights_grand_matrix[i_sub, :] = np.concatenate((mat_file_delta, mat_file_theta, mat_file_alpha, mat_file_beta, mat_file_gamma, mat_file_hgamma), axis = 0).reshape((24303240))

# %%
sio.loadmat('output/beamformer_weights/' + subs_names[i_sub] + '_beamformer_weights_delta')
# Out:
# (15002, 270)

# %%
print(weights_grand_matrix[24303240-2, 0])
print(weights_grand_matrix[24303240-1, 0])
print(weights_grand_matrix[24303240, 0])
# Out:
# 236749233789.32666
# 64258264811.88864
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-187-4fac43e45c70> in <module>()
#       1 print(weights_grand_matrix[24303240-2, 0])
#       2 print(weights_grand_matrix[24303240-1, 0])
# ----> 3 print(weights_grand_matrix[24303240, 0])
#
# IndexError: index 24303240 is out of bounds for axis 0 with size 24303240

# %%
# Out:
# No getting sub-0001
