# %% [markdown]
# ## License
# This file is part of the project megFingerprinting. All of megFingerprinting code is free software: you can redistribute it and/or modify it under the terms of the GNU General Public License as published by the Free Software Foundation, either version 3 of the License, or (at your option) any later version. megFingerprinting is distributed in the hope that it will be useful, but WITHOUT ANY WARRANTY; without even the implied warranty of MERCHANTABILITY or FITNESS FOR A PARTICULAR PURPOSE. See the GNU General Public License for more details. You should have received a copy of the GNU General Public License along with megFingerprinting. If not, see https://www.gnu.org/licenses/.

# %%
import difflib
from fuzzywuzzy import fuzz
import matplotlib.pyplot as plt
from mpl_toolkits.axes_grid1 import make_axes_locatable
import numpy as np
from os import listdir
from os.path import isfile, join
import pandas as pd
import re
import seaborn as sns
import scipy as sp
import scipy.io as sio
from sklearn.decomposition import PCA
from sklearn.metrics import accuracy_score
sns.set()
sns.set_style("whitegrid")
sns.set_palette(sns.color_palette("husl", 8))
# Out:
# /Users/jasondsc/opt/anaconda3/lib/python3.7/site-packages/fuzzywuzzy/fuzz.py:11: UserWarning: Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning
#   warnings.warn('Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning')

# %% [markdown]
# # I. Subject Identifiability: Original Feature Space vs PCA Reconstructed
#
# ## Select appropriate folder for Training 1, 2, or valdiation
# ## Select appropriate folder for frequency bands as well as array size

# %%
# Parameters
n_subs = 158 # Change here to get number of participants! 
nfreq= 201
n_feats = int(68*nfreq) # 201 hgamma   40 gamma  34 beta  10 alpha    8 theta   8 delta  
n_measurements = 2

# %%
# Warangle data set into two big feature matrices
## FIRST AND LAST WINDOW
def prune_subject_csv(filename):
    '''
    This function takes in the subject's csv file from MATLAB, takes out the 
    doubled correlations (because of symmetry) and outputs a numpy array ready to be concatenated
    in the grand feature matrix
    Args:
        filename (string): Name of the csv matrix
    Returns: 
        sub_feat (np.array): Subject's features 
    '''
    #print(filename)
    print(filename[37:41])
    n_feats = int(68*nfreq)
    sub_feat = np.zeros([1, (n_feats)+1]) # Number of unique values in corr matrix + subject label
    psd_matrix = pd.read_csv(filename, header=None)
    mat=np.asmatrix(psd_matrix)
    sub_feat[0, :-1]=mat.flatten()
    sub_feat[0, -1] = int(filename[37:41])    
    return sub_feat


# Get n subjects: both training and testing datasets
onlyfiles = [f for f in listdir('output/Short_PSD_source_1/hgamma/') if isfile(join('output/Short_PSD_source_1/hgamma/', f))]
sub_target = np.zeros([n_subs, (n_feats)+1])
sub_database = np.zeros([n_subs, (n_feats)+1])
iv = 0
it = 0
for iFile in sorted(onlyfiles)[0:(n_subs*2)]: 
    sub = 'output/Short_PSD_source_1/hgamma/' + iFile
    print(sub)
    # [50] == 'v'
    # [59] == '2'
    if sub[48] == 'v':
        sub_target[iv, :] = prune_subject_csv(sub)
        iv += 1
    else:
        sub_database[it, :] = prune_subject_csv(sub)
        it += 1
# Out:
# output/Short_PSD_source_1/hgamma/sub_0001_hgam__training_1.csv
# 0001
# output/Short_PSD_source_1/hgamma/sub_0001_hgam__validation.csv
# 0001
# output/Short_PSD_source_1/hgamma/sub_0002_hgam__training_1.csv
# 0002
# output/Short_PSD_source_1/hgamma/sub_0002_hgam__validation.csv
# 0002
# output/Short_PSD_source_1/hgamma/sub_0003_hgam__training_1.csv
# 0003
# output/Short_PSD_source_1/hgamma/sub_0003_hgam__validation.csv
# 0003
# output/Short_PSD_source_1/hgamma/sub_0004_hgam__training_1.csv
# 0004
# output/Short_PSD_source_1/hgamma/sub_0004_hgam__validation.csv
# 0004
# output/Short_PSD_source_1/hgamma/sub_0005_hgam__training_1.csv
# 0005
# output/Short_PSD_source_1/hgamma/sub_0005_hgam__validation.csv
# 0005
# output/Short_PSD_source_1/hgamma/sub_0006_hgam__training_1.csv
# 0006
# output/Short_PSD_source_1/hgamma/sub_0006_hgam__validation.csv
# 0006
# output/Short_PSD_source_1/hgamma/sub_0007_hgam__training_1.csv
# 0007
# output/Short_PSD_source_1/hgamma/sub_0007_hgam__validation.csv
# 0007
# output/Short_PSD_source_1/hgamma/sub_0008_hgam__training_1.csv
# 0008
# output/Short_PSD_source_1/hgamma/sub_0008_hgam__validation.csv
# 0008
# output/Short_PSD_source_1/hgamma/sub_0009_hgam__training_1.csv
# 0009
# output/Short_PSD_source_1/hgamma/sub_0009_hgam__validation.csv
# 0009
# output/Short_PSD_source_1/hgamma/sub_0011_hgam__training_1.csv
# 0011
# output/Short_PSD_source_1/hgamma/sub_0011_hgam__validation.csv
# 0011
# output/Short_PSD_source_1/hgamma/sub_0012_hgam__training_1.csv
# 0012
# output/Short_PSD_source_1/hgamma/sub_0012_hgam__validation.csv
# 0012
# output/Short_PSD_source_1/hgamma/sub_0013_hgam__training_1.csv
# 0013
# output/Short_PSD_source_1/hgamma/sub_0013_hgam__validation.csv
# 0013
# output/Short_PSD_source_1/hgamma/sub_0014_hgam__training_1.csv
# 0014
# output/Short_PSD_source_1/hgamma/sub_0014_hgam__validation.csv
# 0014
# output/Short_PSD_source_1/hgamma/sub_0015_hgam__training_1.csv
# 0015
# output/Short_PSD_source_1/hgamma/sub_0015_hgam__validation.csv
# 0015
# output/Short_PSD_source_1/hgamma/sub_0016_hgam__training_1.csv
# 0016
# output/Short_PSD_source_1/hgamma/sub_0016_hgam__validation.csv
# 0016
# output/Short_PSD_source_1/hgamma/sub_0018_hgam__training_1.csv
# 0018
# output/Short_PSD_source_1/hgamma/sub_0018_hgam__validation.csv
# 0018
# output/Short_PSD_source_1/hgamma/sub_0020_hgam__training_1.csv
# 0020
# output/Short_PSD_source_1/hgamma/sub_0020_hgam__validation.csv
# 0020
# output/Short_PSD_source_1/hgamma/sub_0021_hgam__training_1.csv
# 0021
# output/Short_PSD_source_1/hgamma/sub_0021_hgam__validation.csv
# 0021
# output/Short_PSD_source_1/hgamma/sub_0022_hgam__training_1.csv
# 0022
# output/Short_PSD_source_1/hgamma/sub_0022_hgam__validation.csv
# 0022
# output/Short_PSD_source_1/hgamma/sub_0023_hgam__training_1.csv
# 0023
# output/Short_PSD_source_1/hgamma/sub_0023_hgam__validation.csv
# 0023
# output/Short_PSD_source_1/hgamma/sub_0024_hgam__training_1.csv
# 0024
# output/Short_PSD_source_1/hgamma/sub_0024_hgam__validation.csv
# 0024
# output/Short_PSD_source_1/hgamma/sub_0025_hgam__training_1.csv
# 0025
# output/Short_PSD_source_1/hgamma/sub_0025_hgam__validation.csv
# 0025
# output/Short_PSD_source_1/hgamma/sub_0026_hgam__training_1.csv
# 0026
# output/Short_PSD_source_1/hgamma/sub_0026_hgam__validation.csv
# 0026
# output/Short_PSD_source_1/hgamma/sub_0028_hgam__training_1.csv
# 0028
# output/Short_PSD_source_1/hgamma/sub_0028_hgam__validation.csv
# 0028
# output/Short_PSD_source_1/hgamma/sub_0029_hgam__training_1.csv
# 0029
# output/Short_PSD_source_1/hgamma/sub_0029_hgam__validation.csv
# 0029
# output/Short_PSD_source_1/hgamma/sub_0030_hgam__training_1.csv
# 0030
# output/Short_PSD_source_1/hgamma/sub_0030_hgam__validation.csv
# 0030
# output/Short_PSD_source_1/hgamma/sub_0031_hgam__training_1.csv
# 0031
# output/Short_PSD_source_1/hgamma/sub_0031_hgam__validation.csv
# 0031
# output/Short_PSD_source_1/hgamma/sub_0032_hgam__training_1.csv
# 0032
# output/Short_PSD_source_1/hgamma/sub_0032_hgam__validation.csv
# 0032
# output/Short_PSD_source_1/hgamma/sub_0033_hgam__training_1.csv
# 0033
# output/Short_PSD_source_1/hgamma/sub_0033_hgam__validation.csv
# 0033
# output/Short_PSD_source_1/hgamma/sub_0035_hgam__training_1.csv
# 0035
# output/Short_PSD_source_1/hgamma/sub_0035_hgam__validation.csv
# 0035
# output/Short_PSD_source_1/hgamma/sub_0036_hgam__training_1.csv
# 0036
# output/Short_PSD_source_1/hgamma/sub_0036_hgam__validation.csv
# 0036
# output/Short_PSD_source_1/hgamma/sub_0037_hgam__training_1.csv
# 0037
# output/Short_PSD_source_1/hgamma/sub_0037_hgam__validation.csv
# 0037
# output/Short_PSD_source_1/hgamma/sub_0040_hgam__training_1.csv
# 0040
# output/Short_PSD_source_1/hgamma/sub_0040_hgam__validation.csv
# 0040
# output/Short_PSD_source_1/hgamma/sub_0041_hgam__training_1.csv
# 0041
# output/Short_PSD_source_1/hgamma/sub_0041_hgam__validation.csv
# 0041
# output/Short_PSD_source_1/hgamma/sub_0045_hgam__training_1.csv
# 0045
# output/Short_PSD_source_1/hgamma/sub_0045_hgam__validation.csv
# 0045
# output/Short_PSD_source_1/hgamma/sub_0046_hgam__training_1.csv
# 0046
# output/Short_PSD_source_1/hgamma/sub_0046_hgam__validation.csv
# 0046
# output/Short_PSD_source_1/hgamma/sub_0047_hgam__training_1.csv
# 0047
# output/Short_PSD_source_1/hgamma/sub_0047_hgam__validation.csv
# 0047
# output/Short_PSD_source_1/hgamma/sub_0048_hgam__training_1.csv
# 0048
# output/Short_PSD_source_1/hgamma/sub_0048_hgam__validation.csv
# 0048
# output/Short_PSD_source_1/hgamma/sub_0049_hgam__training_1.csv
# 0049
# output/Short_PSD_source_1/hgamma/sub_0049_hgam__validation.csv
# 0049
# output/Short_PSD_source_1/hgamma/sub_0050_hgam__training_1.csv
# 0050
# output/Short_PSD_source_1/hgamma/sub_0050_hgam__validation.csv
# 0050
# output/Short_PSD_source_1/hgamma/sub_0051_hgam__training_1.csv
# 0051
# output/Short_PSD_source_1/hgamma/sub_0051_hgam__validation.csv
# 0051
# output/Short_PSD_source_1/hgamma/sub_0052_hgam__training_1.csv
# 0052
# output/Short_PSD_source_1/hgamma/sub_0052_hgam__validation.csv
# 0052
# output/Short_PSD_source_1/hgamma/sub_0053_hgam__training_1.csv
# 0053
# output/Short_PSD_source_1/hgamma/sub_0053_hgam__validation.csv
# 0053
# output/Short_PSD_source_1/hgamma/sub_0054_hgam__training_1.csv
# 0054
# output/Short_PSD_source_1/hgamma/sub_0054_hgam__validation.csv
# 0054
# output/Short_PSD_source_1/hgamma/sub_0055_hgam__training_1.csv
# 0055
# output/Short_PSD_source_1/hgamma/sub_0055_hgam__validation.csv
# 0055
# output/Short_PSD_source_1/hgamma/sub_0056_hgam__training_1.csv
# 0056
# output/Short_PSD_source_1/hgamma/sub_0056_hgam__validation.csv
# 0056
# output/Short_PSD_source_1/hgamma/sub_0058_hgam__training_1.csv
# 0058
# output/Short_PSD_source_1/hgamma/sub_0058_hgam__validation.csv
# 0058
# output/Short_PSD_source_1/hgamma/sub_0059_hgam__training_1.csv
# 0059
# output/Short_PSD_source_1/hgamma/sub_0059_hgam__validation.csv
# 0059
# output/Short_PSD_source_1/hgamma/sub_0060_hgam__training_1.csv
# 0060
# output/Short_PSD_source_1/hgamma/sub_0060_hgam__validation.csv
# 0060
# output/Short_PSD_source_1/hgamma/sub_0061_hgam__training_1.csv
# 0061
# output/Short_PSD_source_1/hgamma/sub_0061_hgam__validation.csv
# 0061
# output/Short_PSD_source_1/hgamma/sub_0062_hgam__training_1.csv
# 0062
# output/Short_PSD_source_1/hgamma/sub_0062_hgam__validation.csv
# 0062
# output/Short_PSD_source_1/hgamma/sub_0063_hgam__training_1.csv
# 0063
# output/Short_PSD_source_1/hgamma/sub_0063_hgam__validation.csv
# 0063
# output/Short_PSD_source_1/hgamma/sub_0064_hgam__training_1.csv
# 0064
# output/Short_PSD_source_1/hgamma/sub_0064_hgam__validation.csv
# 0064
# output/Short_PSD_source_1/hgamma/sub_0065_hgam__training_1.csv
# 0065
# output/Short_PSD_source_1/hgamma/sub_0065_hgam__validation.csv
# 0065
# output/Short_PSD_source_1/hgamma/sub_0066_hgam__training_1.csv
# 0066
# output/Short_PSD_source_1/hgamma/sub_0066_hgam__validation.csv
# 0066
# output/Short_PSD_source_1/hgamma/sub_0068_hgam__training_1.csv
# 0068
# output/Short_PSD_source_1/hgamma/sub_0068_hgam__validation.csv
# 0068
# output/Short_PSD_source_1/hgamma/sub_0069_hgam__training_1.csv
# 0069
# output/Short_PSD_source_1/hgamma/sub_0069_hgam__validation.csv
# 0069
# output/Short_PSD_source_1/hgamma/sub_0070_hgam__training_1.csv
# 0070
# output/Short_PSD_source_1/hgamma/sub_0070_hgam__validation.csv
# 0070
# output/Short_PSD_source_1/hgamma/sub_0071_hgam__training_1.csv
# 0071
# output/Short_PSD_source_1/hgamma/sub_0071_hgam__validation.csv
# 0071
# output/Short_PSD_source_1/hgamma/sub_0074_hgam__training_1.csv
# 0074
# output/Short_PSD_source_1/hgamma/sub_0074_hgam__validation.csv
# 0074
# output/Short_PSD_source_1/hgamma/sub_0075_hgam__training_1.csv
# 0075
# output/Short_PSD_source_1/hgamma/sub_0075_hgam__validation.csv
# 0075
# output/Short_PSD_source_1/hgamma/sub_0076_hgam__training_1.csv
# 0076
# output/Short_PSD_source_1/hgamma/sub_0076_hgam__validation.csv
# 0076
# output/Short_PSD_source_1/hgamma/sub_0077_hgam__training_1.csv
# 0077
# output/Short_PSD_source_1/hgamma/sub_0077_hgam__validation.csv
# 0077
# output/Short_PSD_source_1/hgamma/sub_0078_hgam__training_1.csv
# 0078
# output/Short_PSD_source_1/hgamma/sub_0078_hgam__validation.csv
# 0078
# output/Short_PSD_source_1/hgamma/sub_0079_hgam__training_1.csv
# 0079
# output/Short_PSD_source_1/hgamma/sub_0079_hgam__validation.csv
# 0079
# output/Short_PSD_source_1/hgamma/sub_0080_hgam__training_1.csv
# 0080
# output/Short_PSD_source_1/hgamma/sub_0080_hgam__validation.csv
# 0080
# output/Short_PSD_source_1/hgamma/sub_0082_hgam__training_1.csv
# 0082
# output/Short_PSD_source_1/hgamma/sub_0082_hgam__validation.csv
# 0082
# output/Short_PSD_source_1/hgamma/sub_0083_hgam__training_1.csv
# 0083
# output/Short_PSD_source_1/hgamma/sub_0083_hgam__validation.csv
# 0083
# output/Short_PSD_source_1/hgamma/sub_0084_hgam__training_1.csv
# 0084
# output/Short_PSD_source_1/hgamma/sub_0084_hgam__validation.csv
# 0084
# output/Short_PSD_source_1/hgamma/sub_0085_hgam__training_1.csv
# 0085
# output/Short_PSD_source_1/hgamma/sub_0085_hgam__validation.csv
# 0085
# output/Short_PSD_source_1/hgamma/sub_0086_hgam__training_1.csv
# 0086
# output/Short_PSD_source_1/hgamma/sub_0086_hgam__validation.csv
# 0086
# output/Short_PSD_source_1/hgamma/sub_0087_hgam__training_1.csv
# 0087
# output/Short_PSD_source_1/hgamma/sub_0087_hgam__validation.csv
# 0087
# output/Short_PSD_source_1/hgamma/sub_0088_hgam__training_1.csv
# 0088
# output/Short_PSD_source_1/hgamma/sub_0088_hgam__validation.csv
# 0088
# output/Short_PSD_source_1/hgamma/sub_0089_hgam__training_1.csv
# 0089
# output/Short_PSD_source_1/hgamma/sub_0089_hgam__validation.csv
# 0089
# output/Short_PSD_source_1/hgamma/sub_0090_hgam__training_1.csv
# 0090
# output/Short_PSD_source_1/hgamma/sub_0090_hgam__validation.csv
# 0090
# output/Short_PSD_source_1/hgamma/sub_0091_hgam__training_1.csv
# 0091
# output/Short_PSD_source_1/hgamma/sub_0091_hgam__validation.csv
# 0091
# output/Short_PSD_source_1/hgamma/sub_0093_hgam__training_1.csv
# 0093
# output/Short_PSD_source_1/hgamma/sub_0093_hgam__validation.csv
# 0093
# output/Short_PSD_source_1/hgamma/sub_0094_hgam__training_1.csv
# 0094
# output/Short_PSD_source_1/hgamma/sub_0094_hgam__validation.csv
# 0094
# output/Short_PSD_source_1/hgamma/sub_0095_hgam__training_1.csv
# 0095
# output/Short_PSD_source_1/hgamma/sub_0095_hgam__validation.csv
# 0095
# output/Short_PSD_source_1/hgamma/sub_0096_hgam__training_1.csv
# 0096
# output/Short_PSD_source_1/hgamma/sub_0096_hgam__validation.csv
# 0096
# output/Short_PSD_source_1/hgamma/sub_0097_hgam__training_1.csv
# 0097
# output/Short_PSD_source_1/hgamma/sub_0097_hgam__validation.csv
# 0097
# output/Short_PSD_source_1/hgamma/sub_0098_hgam__training_1.csv
# 0098
# output/Short_PSD_source_1/hgamma/sub_0098_hgam__validation.csv
# 0098
# output/Short_PSD_source_1/hgamma/sub_0099_hgam__training_1.csv
# 0099
# output/Short_PSD_source_1/hgamma/sub_0099_hgam__validation.csv
# 0099
# output/Short_PSD_source_1/hgamma/sub_0101_hgam__training_1.csv
# 0101
# output/Short_PSD_source_1/hgamma/sub_0101_hgam__validation.csv
# 0101
# output/Short_PSD_source_1/hgamma/sub_0102_hgam__training_1.csv
# 0102
# output/Short_PSD_source_1/hgamma/sub_0102_hgam__validation.csv
# 0102
# output/Short_PSD_source_1/hgamma/sub_0103_hgam__training_1.csv
# 0103
# output/Short_PSD_source_1/hgamma/sub_0103_hgam__validation.csv
# 0103
# output/Short_PSD_source_1/hgamma/sub_0105_hgam__training_1.csv
# 0105
# output/Short_PSD_source_1/hgamma/sub_0105_hgam__validation.csv
# 0105
# output/Short_PSD_source_1/hgamma/sub_0106_hgam__training_1.csv
# 0106
# output/Short_PSD_source_1/hgamma/sub_0106_hgam__validation.csv
# 0106
# output/Short_PSD_source_1/hgamma/sub_0108_hgam__training_1.csv
# 0108
# output/Short_PSD_source_1/hgamma/sub_0108_hgam__validation.csv
# 0108
# output/Short_PSD_source_1/hgamma/sub_0109_hgam__training_1.csv
# 0109
# output/Short_PSD_source_1/hgamma/sub_0109_hgam__validation.csv
# 0109
# output/Short_PSD_source_1/hgamma/sub_0110_hgam__training_1.csv
# 0110
# output/Short_PSD_source_1/hgamma/sub_0110_hgam__validation.csv
# 0110
# output/Short_PSD_source_1/hgamma/sub_0111_hgam__training_1.csv
# 0111
# output/Short_PSD_source_1/hgamma/sub_0111_hgam__validation.csv
# 0111
# output/Short_PSD_source_1/hgamma/sub_0112_hgam__training_1.csv
# 0112
# output/Short_PSD_source_1/hgamma/sub_0112_hgam__validation.csv
# 0112
# output/Short_PSD_source_1/hgamma/sub_0114_hgam__training_1.csv
# 0114
# output/Short_PSD_source_1/hgamma/sub_0114_hgam__validation.csv
# 0114
# output/Short_PSD_source_1/hgamma/sub_0116_hgam__training_1.csv
# 0116
# output/Short_PSD_source_1/hgamma/sub_0116_hgam__validation.csv
# 0116
# output/Short_PSD_source_1/hgamma/sub_0117_hgam__training_1.csv
# 0117
# output/Short_PSD_source_1/hgamma/sub_0117_hgam__validation.csv
# 0117
# output/Short_PSD_source_1/hgamma/sub_0118_hgam__training_1.csv
# 0118
# output/Short_PSD_source_1/hgamma/sub_0118_hgam__validation.csv
# 0118
# output/Short_PSD_source_1/hgamma/sub_0119_hgam__training_1.csv
# 0119
# output/Short_PSD_source_1/hgamma/sub_0119_hgam__validation.csv
# 0119
# output/Short_PSD_source_1/hgamma/sub_0120_hgam__training_1.csv
# 0120
# output/Short_PSD_source_1/hgamma/sub_0120_hgam__validation.csv
# 0120
# output/Short_PSD_source_1/hgamma/sub_0121_hgam__training_1.csv
# 0121
# output/Short_PSD_source_1/hgamma/sub_0121_hgam__validation.csv
# 0121
# output/Short_PSD_source_1/hgamma/sub_0123_hgam__training_1.csv
# 0123
# output/Short_PSD_source_1/hgamma/sub_0123_hgam__validation.csv
# 0123
# output/Short_PSD_source_1/hgamma/sub_0125_hgam__training_1.csv
# 0125
# output/Short_PSD_source_1/hgamma/sub_0125_hgam__validation.csv
# 0125
# output/Short_PSD_source_1/hgamma/sub_0126_hgam__training_1.csv
# 0126
# output/Short_PSD_source_1/hgamma/sub_0126_hgam__validation.csv
# 0126
# output/Short_PSD_source_1/hgamma/sub_0127_hgam__training_1.csv
# 0127
# output/Short_PSD_source_1/hgamma/sub_0127_hgam__validation.csv
# 0127
# output/Short_PSD_source_1/hgamma/sub_0128_hgam__training_1.csv
# 0128
# output/Short_PSD_source_1/hgamma/sub_0128_hgam__validation.csv
# 0128
# output/Short_PSD_source_1/hgamma/sub_0129_hgam__training_1.csv
# 0129
# output/Short_PSD_source_1/hgamma/sub_0129_hgam__validation.csv
# 0129
# output/Short_PSD_source_1/hgamma/sub_0130_hgam__training_1.csv
# 0130
# output/Short_PSD_source_1/hgamma/sub_0130_hgam__validation.csv
# 0130
# output/Short_PSD_source_1/hgamma/sub_0131_hgam__training_1.csv
# 0131
# output/Short_PSD_source_1/hgamma/sub_0131_hgam__validation.csv
# 0131
# output/Short_PSD_source_1/hgamma/sub_0132_hgam__training_1.csv
# 0132
# output/Short_PSD_source_1/hgamma/sub_0132_hgam__validation.csv
# 0132
# output/Short_PSD_source_1/hgamma/sub_0133_hgam__training_1.csv
# 0133
# output/Short_PSD_source_1/hgamma/sub_0133_hgam__validation.csv
# 0133
# output/Short_PSD_source_1/hgamma/sub_0134_hgam__training_1.csv
# 0134
# output/Short_PSD_source_1/hgamma/sub_0134_hgam__validation.csv
# 0134
# output/Short_PSD_source_1/hgamma/sub_0135_hgam__training_1.csv
# 0135
# output/Short_PSD_source_1/hgamma/sub_0135_hgam__validation.csv
# 0135
# output/Short_PSD_source_1/hgamma/sub_0136_hgam__training_1.csv
# 0136
# output/Short_PSD_source_1/hgamma/sub_0136_hgam__validation.csv
# 0136
# output/Short_PSD_source_1/hgamma/sub_0139_hgam__training_1.csv
# 0139
# output/Short_PSD_source_1/hgamma/sub_0139_hgam__validation.csv
# 0139
# output/Short_PSD_source_1/hgamma/sub_0140_hgam__training_1.csv
# 0140
# output/Short_PSD_source_1/hgamma/sub_0140_hgam__validation.csv
# 0140
# output/Short_PSD_source_1/hgamma/sub_0141_hgam__training_1.csv
# 0141
# output/Short_PSD_source_1/hgamma/sub_0141_hgam__validation.csv
# 0141
# output/Short_PSD_source_1/hgamma/sub_0142_hgam__training_1.csv
# 0142
# output/Short_PSD_source_1/hgamma/sub_0142_hgam__validation.csv
# 0142
# output/Short_PSD_source_1/hgamma/sub_0143_hgam__training_1.csv
# 0143
# output/Short_PSD_source_1/hgamma/sub_0143_hgam__validation.csv
# 0143
# output/Short_PSD_source_1/hgamma/sub_0144_hgam__training_1.csv
# 0144
# output/Short_PSD_source_1/hgamma/sub_0144_hgam__validation.csv
# 0144
# output/Short_PSD_source_1/hgamma/sub_0145_hgam__training_1.csv
# 0145
# output/Short_PSD_source_1/hgamma/sub_0145_hgam__validation.csv
# 0145
# output/Short_PSD_source_1/hgamma/sub_0146_hgam__training_1.csv
# 0146
# output/Short_PSD_source_1/hgamma/sub_0146_hgam__validation.csv
# 0146
# output/Short_PSD_source_1/hgamma/sub_0147_hgam__training_1.csv
# 0147
# output/Short_PSD_source_1/hgamma/sub_0147_hgam__validation.csv
# 0147
# output/Short_PSD_source_1/hgamma/sub_0148_hgam__training_1.csv
# 0148
# output/Short_PSD_source_1/hgamma/sub_0148_hgam__validation.csv
# 0148
# output/Short_PSD_source_1/hgamma/sub_0149_hgam__training_1.csv
# 0149
# output/Short_PSD_source_1/hgamma/sub_0149_hgam__validation.csv
# 0149
# output/Short_PSD_source_1/hgamma/sub_0150_hgam__training_1.csv
# 0150
# output/Short_PSD_source_1/hgamma/sub_0150_hgam__validation.csv
# 0150
# output/Short_PSD_source_1/hgamma/sub_0151_hgam__training_1.csv
# 0151
# output/Short_PSD_source_1/hgamma/sub_0151_hgam__validation.csv
# 0151
# output/Short_PSD_source_1/hgamma/sub_0152_hgam__training_1.csv
# 0152
# output/Short_PSD_source_1/hgamma/sub_0152_hgam__validation.csv
# 0152
# output/Short_PSD_source_1/hgamma/sub_0154_hgam__training_1.csv
# 0154
# output/Short_PSD_source_1/hgamma/sub_0154_hgam__validation.csv
# 0154
# output/Short_PSD_source_1/hgamma/sub_0155_hgam__training_1.csv
# 0155
# output/Short_PSD_source_1/hgamma/sub_0155_hgam__validation.csv
# 0155
# output/Short_PSD_source_1/hgamma/sub_0156_hgam__training_1.csv
# 0156
# output/Short_PSD_source_1/hgamma/sub_0156_hgam__validation.csv
# 0156
# output/Short_PSD_source_1/hgamma/sub_0157_hgam__training_1.csv
# 0157
# output/Short_PSD_source_1/hgamma/sub_0157_hgam__validation.csv
# 0157
# output/Short_PSD_source_1/hgamma/sub_0158_hgam__training_1.csv
# 0158
# output/Short_PSD_source_1/hgamma/sub_0158_hgam__validation.csv
# 0158
# output/Short_PSD_source_1/hgamma/sub_0159_hgam__training_1.csv
# 0159
# output/Short_PSD_source_1/hgamma/sub_0159_hgam__validation.csv
# 0159
# output/Short_PSD_source_1/hgamma/sub_0160_hgam__training_1.csv
# 0160
# output/Short_PSD_source_1/hgamma/sub_0160_hgam__validation.csv
# 0160
# output/Short_PSD_source_1/hgamma/sub_0161_hgam__training_1.csv
# 0161
# output/Short_PSD_source_1/hgamma/sub_0161_hgam__validation.csv
# 0161
# output/Short_PSD_source_1/hgamma/sub_0162_hgam__training_1.csv
# 0162
# output/Short_PSD_source_1/hgamma/sub_0162_hgam__validation.csv
# 0162
# output/Short_PSD_source_1/hgamma/sub_0164_hgam__training_1.csv
# 0164
# output/Short_PSD_source_1/hgamma/sub_0164_hgam__validation.csv
# 0164
# output/Short_PSD_source_1/hgamma/sub_0165_hgam__training_1.csv
# 0165
# output/Short_PSD_source_1/hgamma/sub_0165_hgam__validation.csv
# 0165
# output/Short_PSD_source_1/hgamma/sub_0166_hgam__training_1.csv
# 0166
# output/Short_PSD_source_1/hgamma/sub_0166_hgam__validation.csv
# 0166
# output/Short_PSD_source_1/hgamma/sub_0167_hgam__training_1.csv
# 0167
# output/Short_PSD_source_1/hgamma/sub_0167_hgam__validation.csv
# 0167
# output/Short_PSD_source_1/hgamma/sub_0168_hgam__training_1.csv
# 0168
# output/Short_PSD_source_1/hgamma/sub_0168_hgam__validation.csv
# 0168
# output/Short_PSD_source_1/hgamma/sub_0169_hgam__training_1.csv
# 0169
# output/Short_PSD_source_1/hgamma/sub_0169_hgam__validation.csv
# 0169
# output/Short_PSD_source_1/hgamma/sub_0170_hgam__training_1.csv
# 0170
# output/Short_PSD_source_1/hgamma/sub_0170_hgam__validation.csv
# 0170
# output/Short_PSD_source_1/hgamma/sub_0172_hgam__training_1.csv
# 0172
# output/Short_PSD_source_1/hgamma/sub_0172_hgam__validation.csv
# 0172
# output/Short_PSD_source_1/hgamma/sub_0174_hgam__training_1.csv
# 0174
# output/Short_PSD_source_1/hgamma/sub_0174_hgam__validation.csv
# 0174
# output/Short_PSD_source_1/hgamma/sub_0175_hgam__training_1.csv
# 0175
# output/Short_PSD_source_1/hgamma/sub_0175_hgam__validation.csv
# 0175
# output/Short_PSD_source_1/hgamma/sub_0176_hgam__training_1.csv
# 0176
# output/Short_PSD_source_1/hgamma/sub_0176_hgam__validation.csv
# 0176
# output/Short_PSD_source_1/hgamma/sub_0177_hgam__training_1.csv
# 0177
# output/Short_PSD_source_1/hgamma/sub_0177_hgam__validation.csv
# 0177
# output/Short_PSD_source_1/hgamma/sub_0179_hgam__training_1.csv
# 0179
# output/Short_PSD_source_1/hgamma/sub_0179_hgam__validation.csv
# 0179
# output/Short_PSD_source_1/hgamma/sub_0181_hgam__training_1.csv
# 0181
# output/Short_PSD_source_1/hgamma/sub_0181_hgam__validation.csv
# 0181
# output/Short_PSD_source_1/hgamma/sub_0183_hgam__training_1.csv
# 0183
# output/Short_PSD_source_1/hgamma/sub_0183_hgam__validation.csv
# 0183
# output/Short_PSD_source_1/hgamma/sub_0184_hgam__training_1.csv
# 0184
# output/Short_PSD_source_1/hgamma/sub_0184_hgam__validation.csv
# 0184
# output/Short_PSD_source_1/hgamma/sub_0185_hgam__training_1.csv
# 0185
# output/Short_PSD_source_1/hgamma/sub_0185_hgam__validation.csv
# 0185
# output/Short_PSD_source_1/hgamma/sub_0186_hgam__training_1.csv
# 0186
# output/Short_PSD_source_1/hgamma/sub_0186_hgam__validation.csv
# 0186
# output/Short_PSD_source_1/hgamma/sub_0187_hgam__training_1.csv
# 0187
# output/Short_PSD_source_1/hgamma/sub_0187_hgam__validation.csv
# 0187
# output/Short_PSD_source_1/hgamma/sub_0188_hgam__training_1.csv
# 0188
# output/Short_PSD_source_1/hgamma/sub_0188_hgam__validation.csv
# 0188
# output/Short_PSD_source_1/hgamma/sub_0189_hgam__training_1.csv
# 0189
# output/Short_PSD_source_1/hgamma/sub_0189_hgam__validation.csv
# 0189
# output/Short_PSD_source_1/hgamma/sub_0190_hgam__training_1.csv
# 0190
# output/Short_PSD_source_1/hgamma/sub_0190_hgam__validation.csv
# 0190

# %%
# Warangle data set into two big feature matrices
## SECOND AND LAST WINDOW
def prune_subject_csv(filename):
    '''
    This function takes in the subject's csv file from MATLAB, takes out the 
    doubled correlations (because of symmetry) and outputs a numpy array ready to be concatenated
    in the grand feature matrix
    Args:
        filename (string): Name of the csv matrix
    Returns: 
        sub_feat (np.array): Subject's features 
    '''
    #print(filename)
    print(filename[37:41])
    n_feats = int(68*nfreq)
    sub_feat = np.zeros([1, (n_feats)+1]) # Number of unique values in corr matrix + subject label
    psd_matrix = pd.read_csv(filename, header=None)
    mat=np.asmatrix(psd_matrix)
    sub_feat[0, :-1]=mat.flatten()
    sub_feat[0, -1] = int(filename[37:41])    
    return sub_feat


# Get n subjects: both training and testing datasets
onlyfiles = [f for f in listdir('output/Short_PSD_source_2/hgamma/') if isfile(join('output/Short_PSD_source_2/hgamma/', f))]
sub_target = np.zeros([n_subs, (n_feats)+1])
sub_database = np.zeros([n_subs, (n_feats)+1])
iv = 0
it = 0
for iFile in sorted(onlyfiles)[0:(n_subs*2)]: 
    sub = 'output/Short_PSD_source_2/hgamma/' + iFile
    print(sub)
    # [50] == 'v'
    # [59] == '2'
    if sub[48] == 'v':
        sub_target[iv, :] = prune_subject_csv(sub)
        iv += 1
    else:
        sub_database[it, :] = prune_subject_csv(sub)
        it += 1
# Out:
# output/Short_PSD_source_2/hgamma/sub_0001_hgam__training_2.csv
# 0001
# output/Short_PSD_source_2/hgamma/sub_0001_hgam__validation.csv
# 0001
# output/Short_PSD_source_2/hgamma/sub_0002_hgam__training_2.csv
# 0002
# output/Short_PSD_source_2/hgamma/sub_0002_hgam__validation.csv
# 0002
# output/Short_PSD_source_2/hgamma/sub_0003_hgam__training_2.csv
# 0003
# output/Short_PSD_source_2/hgamma/sub_0003_hgam__validation.csv
# 0003
# output/Short_PSD_source_2/hgamma/sub_0004_hgam__training_2.csv
# 0004
# output/Short_PSD_source_2/hgamma/sub_0004_hgam__validation.csv
# 0004
# output/Short_PSD_source_2/hgamma/sub_0005_hgam__training_2.csv
# 0005
# output/Short_PSD_source_2/hgamma/sub_0005_hgam__validation.csv
# 0005
# output/Short_PSD_source_2/hgamma/sub_0006_hgam__training_2.csv
# 0006
# output/Short_PSD_source_2/hgamma/sub_0006_hgam__validation.csv
# 0006
# output/Short_PSD_source_2/hgamma/sub_0007_hgam__training_2.csv
# 0007
# output/Short_PSD_source_2/hgamma/sub_0007_hgam__validation.csv
# 0007
# output/Short_PSD_source_2/hgamma/sub_0008_hgam__training_2.csv
# 0008
# output/Short_PSD_source_2/hgamma/sub_0008_hgam__validation.csv
# 0008
# output/Short_PSD_source_2/hgamma/sub_0009_hgam__training_2.csv
# 0009
# output/Short_PSD_source_2/hgamma/sub_0009_hgam__validation.csv
# 0009
# output/Short_PSD_source_2/hgamma/sub_0011_hgam__training_2.csv
# 0011
# output/Short_PSD_source_2/hgamma/sub_0011_hgam__validation.csv
# 0011
# output/Short_PSD_source_2/hgamma/sub_0012_hgam__training_2.csv
# 0012
# output/Short_PSD_source_2/hgamma/sub_0012_hgam__validation.csv
# 0012
# output/Short_PSD_source_2/hgamma/sub_0013_hgam__training_2.csv
# 0013
# output/Short_PSD_source_2/hgamma/sub_0013_hgam__validation.csv
# 0013
# output/Short_PSD_source_2/hgamma/sub_0014_hgam__training_2.csv
# 0014
# output/Short_PSD_source_2/hgamma/sub_0014_hgam__validation.csv
# 0014
# output/Short_PSD_source_2/hgamma/sub_0015_hgam__training_2.csv
# 0015
# output/Short_PSD_source_2/hgamma/sub_0015_hgam__validation.csv
# 0015
# output/Short_PSD_source_2/hgamma/sub_0016_hgam__training_2.csv
# 0016
# output/Short_PSD_source_2/hgamma/sub_0016_hgam__validation.csv
# 0016
# output/Short_PSD_source_2/hgamma/sub_0018_hgam__training_2.csv
# 0018
# output/Short_PSD_source_2/hgamma/sub_0018_hgam__validation.csv
# 0018
# output/Short_PSD_source_2/hgamma/sub_0020_hgam__training_2.csv
# 0020
# output/Short_PSD_source_2/hgamma/sub_0020_hgam__validation.csv
# 0020
# output/Short_PSD_source_2/hgamma/sub_0021_hgam__training_2.csv
# 0021
# output/Short_PSD_source_2/hgamma/sub_0021_hgam__validation.csv
# 0021
# output/Short_PSD_source_2/hgamma/sub_0022_hgam__training_2.csv
# 0022
# output/Short_PSD_source_2/hgamma/sub_0022_hgam__validation.csv
# 0022
# output/Short_PSD_source_2/hgamma/sub_0023_hgam__training_2.csv
# 0023
# output/Short_PSD_source_2/hgamma/sub_0023_hgam__validation.csv
# 0023
# output/Short_PSD_source_2/hgamma/sub_0024_hgam__training_2.csv
# 0024
# output/Short_PSD_source_2/hgamma/sub_0024_hgam__validation.csv
# 0024
# output/Short_PSD_source_2/hgamma/sub_0025_hgam__training_2.csv
# 0025
# output/Short_PSD_source_2/hgamma/sub_0025_hgam__validation.csv
# 0025
# output/Short_PSD_source_2/hgamma/sub_0026_hgam__training_2.csv
# 0026
# output/Short_PSD_source_2/hgamma/sub_0026_hgam__validation.csv
# 0026
# output/Short_PSD_source_2/hgamma/sub_0028_hgam__training_2.csv
# 0028
# output/Short_PSD_source_2/hgamma/sub_0028_hgam__validation.csv
# 0028
# output/Short_PSD_source_2/hgamma/sub_0029_hgam__training_2.csv
# 0029
# output/Short_PSD_source_2/hgamma/sub_0029_hgam__validation.csv
# 0029
# output/Short_PSD_source_2/hgamma/sub_0030_hgam__training_2.csv
# 0030
# output/Short_PSD_source_2/hgamma/sub_0030_hgam__validation.csv
# 0030
# output/Short_PSD_source_2/hgamma/sub_0031_hgam__training_2.csv
# 0031
# output/Short_PSD_source_2/hgamma/sub_0031_hgam__validation.csv
# 0031
# output/Short_PSD_source_2/hgamma/sub_0032_hgam__training_2.csv
# 0032
# output/Short_PSD_source_2/hgamma/sub_0032_hgam__validation.csv
# 0032
# output/Short_PSD_source_2/hgamma/sub_0033_hgam__training_2.csv
# 0033
# output/Short_PSD_source_2/hgamma/sub_0033_hgam__validation.csv
# 0033
# output/Short_PSD_source_2/hgamma/sub_0035_hgam__training_2.csv
# 0035
# output/Short_PSD_source_2/hgamma/sub_0035_hgam__validation.csv
# 0035
# output/Short_PSD_source_2/hgamma/sub_0036_hgam__training_2.csv
# 0036
# output/Short_PSD_source_2/hgamma/sub_0036_hgam__validation.csv
# 0036
# output/Short_PSD_source_2/hgamma/sub_0037_hgam__training_2.csv
# 0037
# output/Short_PSD_source_2/hgamma/sub_0037_hgam__validation.csv
# 0037
# output/Short_PSD_source_2/hgamma/sub_0040_hgam__training_2.csv
# 0040
# output/Short_PSD_source_2/hgamma/sub_0040_hgam__validation.csv
# 0040
# output/Short_PSD_source_2/hgamma/sub_0041_hgam__training_2.csv
# 0041
# output/Short_PSD_source_2/hgamma/sub_0041_hgam__validation.csv
# 0041
# output/Short_PSD_source_2/hgamma/sub_0045_hgam__training_2.csv
# 0045
# output/Short_PSD_source_2/hgamma/sub_0045_hgam__validation.csv
# 0045
# output/Short_PSD_source_2/hgamma/sub_0046_hgam__training_2.csv
# 0046
# output/Short_PSD_source_2/hgamma/sub_0046_hgam__validation.csv
# 0046
# output/Short_PSD_source_2/hgamma/sub_0047_hgam__training_2.csv
# 0047
# output/Short_PSD_source_2/hgamma/sub_0047_hgam__validation.csv
# 0047
# output/Short_PSD_source_2/hgamma/sub_0048_hgam__training_2.csv
# 0048
# output/Short_PSD_source_2/hgamma/sub_0048_hgam__validation.csv
# 0048
# output/Short_PSD_source_2/hgamma/sub_0049_hgam__training_2.csv
# 0049
# output/Short_PSD_source_2/hgamma/sub_0049_hgam__validation.csv
# 0049
# output/Short_PSD_source_2/hgamma/sub_0050_hgam__training_2.csv
# 0050
# output/Short_PSD_source_2/hgamma/sub_0050_hgam__validation.csv
# 0050
# output/Short_PSD_source_2/hgamma/sub_0051_hgam__training_2.csv
# 0051
# output/Short_PSD_source_2/hgamma/sub_0051_hgam__validation.csv
# 0051
# output/Short_PSD_source_2/hgamma/sub_0052_hgam__training_2.csv
# 0052
# output/Short_PSD_source_2/hgamma/sub_0052_hgam__validation.csv
# 0052
# output/Short_PSD_source_2/hgamma/sub_0053_hgam__training_2.csv
# 0053
# output/Short_PSD_source_2/hgamma/sub_0053_hgam__validation.csv
# 0053
# output/Short_PSD_source_2/hgamma/sub_0054_hgam__training_2.csv
# 0054
# output/Short_PSD_source_2/hgamma/sub_0054_hgam__validation.csv
# 0054
# output/Short_PSD_source_2/hgamma/sub_0055_hgam__training_2.csv
# 0055
# output/Short_PSD_source_2/hgamma/sub_0055_hgam__validation.csv
# 0055
# output/Short_PSD_source_2/hgamma/sub_0056_hgam__training_2.csv
# 0056
# output/Short_PSD_source_2/hgamma/sub_0056_hgam__validation.csv
# 0056
# output/Short_PSD_source_2/hgamma/sub_0058_hgam__training_2.csv
# 0058
# output/Short_PSD_source_2/hgamma/sub_0058_hgam__validation.csv
# 0058
# output/Short_PSD_source_2/hgamma/sub_0059_hgam__training_2.csv
# 0059
# output/Short_PSD_source_2/hgamma/sub_0059_hgam__validation.csv
# 0059
# output/Short_PSD_source_2/hgamma/sub_0060_hgam__training_2.csv
# 0060
# output/Short_PSD_source_2/hgamma/sub_0060_hgam__validation.csv
# 0060
# output/Short_PSD_source_2/hgamma/sub_0061_hgam__training_2.csv
# 0061
# output/Short_PSD_source_2/hgamma/sub_0061_hgam__validation.csv
# 0061
# output/Short_PSD_source_2/hgamma/sub_0062_hgam__training_2.csv
# 0062
# output/Short_PSD_source_2/hgamma/sub_0062_hgam__validation.csv
# 0062
# output/Short_PSD_source_2/hgamma/sub_0063_hgam__training_2.csv
# 0063
# output/Short_PSD_source_2/hgamma/sub_0063_hgam__validation.csv
# 0063
# output/Short_PSD_source_2/hgamma/sub_0064_hgam__training_2.csv
# 0064
# output/Short_PSD_source_2/hgamma/sub_0064_hgam__validation.csv
# 0064
# output/Short_PSD_source_2/hgamma/sub_0065_hgam__training_2.csv
# 0065
# output/Short_PSD_source_2/hgamma/sub_0065_hgam__validation.csv
# 0065
# output/Short_PSD_source_2/hgamma/sub_0066_hgam__training_2.csv
# 0066
# output/Short_PSD_source_2/hgamma/sub_0066_hgam__validation.csv
# 0066
# output/Short_PSD_source_2/hgamma/sub_0068_hgam__training_2.csv
# 0068
# output/Short_PSD_source_2/hgamma/sub_0068_hgam__validation.csv
# 0068
# output/Short_PSD_source_2/hgamma/sub_0069_hgam__training_2.csv
# 0069
# output/Short_PSD_source_2/hgamma/sub_0069_hgam__validation.csv
# 0069
# output/Short_PSD_source_2/hgamma/sub_0070_hgam__training_2.csv
# 0070
# output/Short_PSD_source_2/hgamma/sub_0070_hgam__validation.csv
# 0070
# output/Short_PSD_source_2/hgamma/sub_0071_hgam__training_2.csv
# 0071
# output/Short_PSD_source_2/hgamma/sub_0071_hgam__validation.csv
# 0071
# output/Short_PSD_source_2/hgamma/sub_0074_hgam__training_2.csv
# 0074
# output/Short_PSD_source_2/hgamma/sub_0074_hgam__validation.csv
# 0074
# output/Short_PSD_source_2/hgamma/sub_0075_hgam__training_2.csv
# 0075
# output/Short_PSD_source_2/hgamma/sub_0075_hgam__validation.csv
# 0075
# output/Short_PSD_source_2/hgamma/sub_0076_hgam__training_2.csv
# 0076
# output/Short_PSD_source_2/hgamma/sub_0076_hgam__validation.csv
# 0076
# output/Short_PSD_source_2/hgamma/sub_0077_hgam__training_2.csv
# 0077
# output/Short_PSD_source_2/hgamma/sub_0077_hgam__validation.csv
# 0077
# output/Short_PSD_source_2/hgamma/sub_0078_hgam__training_2.csv
# 0078
# output/Short_PSD_source_2/hgamma/sub_0078_hgam__validation.csv
# 0078
# output/Short_PSD_source_2/hgamma/sub_0079_hgam__training_2.csv
# 0079
# output/Short_PSD_source_2/hgamma/sub_0079_hgam__validation.csv
# 0079
# output/Short_PSD_source_2/hgamma/sub_0080_hgam__training_2.csv
# 0080
# output/Short_PSD_source_2/hgamma/sub_0080_hgam__validation.csv
# 0080
# output/Short_PSD_source_2/hgamma/sub_0082_hgam__training_2.csv
# 0082
# output/Short_PSD_source_2/hgamma/sub_0082_hgam__validation.csv
# 0082
# output/Short_PSD_source_2/hgamma/sub_0083_hgam__training_2.csv
# 0083
# output/Short_PSD_source_2/hgamma/sub_0083_hgam__validation.csv
# 0083
# output/Short_PSD_source_2/hgamma/sub_0084_hgam__training_2.csv
# 0084
# output/Short_PSD_source_2/hgamma/sub_0084_hgam__validation.csv
# 0084
# output/Short_PSD_source_2/hgamma/sub_0085_hgam__training_2.csv
# 0085
# output/Short_PSD_source_2/hgamma/sub_0085_hgam__validation.csv
# 0085
# output/Short_PSD_source_2/hgamma/sub_0086_hgam__training_2.csv
# 0086
# output/Short_PSD_source_2/hgamma/sub_0086_hgam__validation.csv
# 0086
# output/Short_PSD_source_2/hgamma/sub_0087_hgam__training_2.csv
# 0087
# output/Short_PSD_source_2/hgamma/sub_0087_hgam__validation.csv
# 0087
# output/Short_PSD_source_2/hgamma/sub_0088_hgam__training_2.csv
# 0088
# output/Short_PSD_source_2/hgamma/sub_0088_hgam__validation.csv
# 0088
# output/Short_PSD_source_2/hgamma/sub_0089_hgam__training_2.csv
# 0089
# output/Short_PSD_source_2/hgamma/sub_0089_hgam__validation.csv
# 0089
# output/Short_PSD_source_2/hgamma/sub_0090_hgam__training_2.csv
# 0090
# output/Short_PSD_source_2/hgamma/sub_0090_hgam__validation.csv
# 0090
# output/Short_PSD_source_2/hgamma/sub_0091_hgam__training_2.csv
# 0091
# output/Short_PSD_source_2/hgamma/sub_0091_hgam__validation.csv
# 0091
# output/Short_PSD_source_2/hgamma/sub_0093_hgam__training_2.csv
# 0093
# output/Short_PSD_source_2/hgamma/sub_0093_hgam__validation.csv
# 0093
# output/Short_PSD_source_2/hgamma/sub_0094_hgam__training_2.csv
# 0094
# output/Short_PSD_source_2/hgamma/sub_0094_hgam__validation.csv
# 0094
# output/Short_PSD_source_2/hgamma/sub_0095_hgam__training_2.csv
# 0095
# output/Short_PSD_source_2/hgamma/sub_0095_hgam__validation.csv
# 0095
# output/Short_PSD_source_2/hgamma/sub_0096_hgam__training_2.csv
# 0096
# output/Short_PSD_source_2/hgamma/sub_0096_hgam__validation.csv
# 0096
# output/Short_PSD_source_2/hgamma/sub_0097_hgam__training_2.csv
# 0097
# output/Short_PSD_source_2/hgamma/sub_0097_hgam__validation.csv
# 0097
# output/Short_PSD_source_2/hgamma/sub_0098_hgam__training_2.csv
# 0098
# output/Short_PSD_source_2/hgamma/sub_0098_hgam__validation.csv
# 0098
# output/Short_PSD_source_2/hgamma/sub_0099_hgam__training_2.csv
# 0099
# output/Short_PSD_source_2/hgamma/sub_0099_hgam__validation.csv
# 0099
# output/Short_PSD_source_2/hgamma/sub_0101_hgam__training_2.csv
# 0101
# output/Short_PSD_source_2/hgamma/sub_0101_hgam__validation.csv
# 0101
# output/Short_PSD_source_2/hgamma/sub_0102_hgam__training_2.csv
# 0102
# output/Short_PSD_source_2/hgamma/sub_0102_hgam__validation.csv
# 0102
# output/Short_PSD_source_2/hgamma/sub_0103_hgam__training_2.csv
# 0103
# output/Short_PSD_source_2/hgamma/sub_0103_hgam__validation.csv
# 0103
# output/Short_PSD_source_2/hgamma/sub_0105_hgam__training_2.csv
# 0105
# output/Short_PSD_source_2/hgamma/sub_0105_hgam__validation.csv
# 0105
# output/Short_PSD_source_2/hgamma/sub_0106_hgam__training_2.csv
# 0106
# output/Short_PSD_source_2/hgamma/sub_0106_hgam__validation.csv
# 0106
# output/Short_PSD_source_2/hgamma/sub_0108_hgam__training_2.csv
# 0108
# output/Short_PSD_source_2/hgamma/sub_0108_hgam__validation.csv
# 0108
# output/Short_PSD_source_2/hgamma/sub_0109_hgam__training_2.csv
# 0109
# output/Short_PSD_source_2/hgamma/sub_0109_hgam__validation.csv
# 0109
# output/Short_PSD_source_2/hgamma/sub_0110_hgam__training_2.csv
# 0110
# output/Short_PSD_source_2/hgamma/sub_0110_hgam__validation.csv
# 0110
# output/Short_PSD_source_2/hgamma/sub_0111_hgam__training_2.csv
# 0111
# output/Short_PSD_source_2/hgamma/sub_0111_hgam__validation.csv
# 0111
# output/Short_PSD_source_2/hgamma/sub_0112_hgam__training_2.csv
# 0112
# output/Short_PSD_source_2/hgamma/sub_0112_hgam__validation.csv
# 0112
# output/Short_PSD_source_2/hgamma/sub_0114_hgam__training_2.csv
# 0114
# output/Short_PSD_source_2/hgamma/sub_0114_hgam__validation.csv
# 0114
# output/Short_PSD_source_2/hgamma/sub_0116_hgam__training_2.csv
# 0116
# output/Short_PSD_source_2/hgamma/sub_0116_hgam__validation.csv
# 0116
# output/Short_PSD_source_2/hgamma/sub_0117_hgam__training_2.csv
# 0117
# output/Short_PSD_source_2/hgamma/sub_0117_hgam__validation.csv
# 0117
# output/Short_PSD_source_2/hgamma/sub_0118_hgam__training_2.csv
# 0118
# output/Short_PSD_source_2/hgamma/sub_0118_hgam__validation.csv
# 0118
# output/Short_PSD_source_2/hgamma/sub_0119_hgam__training_2.csv
# 0119
# output/Short_PSD_source_2/hgamma/sub_0119_hgam__validation.csv
# 0119
# output/Short_PSD_source_2/hgamma/sub_0120_hgam__training_2.csv
# 0120
# output/Short_PSD_source_2/hgamma/sub_0120_hgam__validation.csv
# 0120
# output/Short_PSD_source_2/hgamma/sub_0121_hgam__training_2.csv
# 0121
# output/Short_PSD_source_2/hgamma/sub_0121_hgam__validation.csv
# 0121
# output/Short_PSD_source_2/hgamma/sub_0123_hgam__training_2.csv
# 0123
# output/Short_PSD_source_2/hgamma/sub_0123_hgam__validation.csv
# 0123
# output/Short_PSD_source_2/hgamma/sub_0125_hgam__training_2.csv
# 0125
# output/Short_PSD_source_2/hgamma/sub_0125_hgam__validation.csv
# 0125
# output/Short_PSD_source_2/hgamma/sub_0126_hgam__training_2.csv
# 0126
# output/Short_PSD_source_2/hgamma/sub_0126_hgam__validation.csv
# 0126
# output/Short_PSD_source_2/hgamma/sub_0127_hgam__training_2.csv
# 0127
# output/Short_PSD_source_2/hgamma/sub_0127_hgam__validation.csv
# 0127
# output/Short_PSD_source_2/hgamma/sub_0128_hgam__training_2.csv
# 0128
# output/Short_PSD_source_2/hgamma/sub_0128_hgam__validation.csv
# 0128
# output/Short_PSD_source_2/hgamma/sub_0129_hgam__training_2.csv
# 0129
# output/Short_PSD_source_2/hgamma/sub_0129_hgam__validation.csv
# 0129
# output/Short_PSD_source_2/hgamma/sub_0130_hgam__training_2.csv
# 0130
# output/Short_PSD_source_2/hgamma/sub_0130_hgam__validation.csv
# 0130
# output/Short_PSD_source_2/hgamma/sub_0131_hgam__training_2.csv
# 0131
# output/Short_PSD_source_2/hgamma/sub_0131_hgam__validation.csv
# 0131
# output/Short_PSD_source_2/hgamma/sub_0132_hgam__training_2.csv
# 0132
# output/Short_PSD_source_2/hgamma/sub_0132_hgam__validation.csv
# 0132
# output/Short_PSD_source_2/hgamma/sub_0133_hgam__training_2.csv
# 0133
# output/Short_PSD_source_2/hgamma/sub_0133_hgam__validation.csv
# 0133
# output/Short_PSD_source_2/hgamma/sub_0134_hgam__training_2.csv
# 0134
# output/Short_PSD_source_2/hgamma/sub_0134_hgam__validation.csv
# 0134
# output/Short_PSD_source_2/hgamma/sub_0135_hgam__training_2.csv
# 0135
# output/Short_PSD_source_2/hgamma/sub_0135_hgam__validation.csv
# 0135
# output/Short_PSD_source_2/hgamma/sub_0136_hgam__training_2.csv
# 0136
# output/Short_PSD_source_2/hgamma/sub_0136_hgam__validation.csv
# 0136
# output/Short_PSD_source_2/hgamma/sub_0139_hgam__training_2.csv
# 0139
# output/Short_PSD_source_2/hgamma/sub_0139_hgam__validation.csv
# 0139
# output/Short_PSD_source_2/hgamma/sub_0140_hgam__training_2.csv
# 0140
# output/Short_PSD_source_2/hgamma/sub_0140_hgam__validation.csv
# 0140
# output/Short_PSD_source_2/hgamma/sub_0141_hgam__training_2.csv
# 0141
# output/Short_PSD_source_2/hgamma/sub_0141_hgam__validation.csv
# 0141
# output/Short_PSD_source_2/hgamma/sub_0142_hgam__training_2.csv
# 0142
# output/Short_PSD_source_2/hgamma/sub_0142_hgam__validation.csv
# 0142
# output/Short_PSD_source_2/hgamma/sub_0143_hgam__training_2.csv
# 0143
# output/Short_PSD_source_2/hgamma/sub_0143_hgam__validation.csv
# 0143
# output/Short_PSD_source_2/hgamma/sub_0144_hgam__training_2.csv
# 0144
# output/Short_PSD_source_2/hgamma/sub_0144_hgam__validation.csv
# 0144
# output/Short_PSD_source_2/hgamma/sub_0145_hgam__training_2.csv
# 0145
# output/Short_PSD_source_2/hgamma/sub_0145_hgam__validation.csv
# 0145
# output/Short_PSD_source_2/hgamma/sub_0146_hgam__training_2.csv
# 0146
# output/Short_PSD_source_2/hgamma/sub_0146_hgam__validation.csv
# 0146
# output/Short_PSD_source_2/hgamma/sub_0147_hgam__training_2.csv
# 0147
# output/Short_PSD_source_2/hgamma/sub_0147_hgam__validation.csv
# 0147
# output/Short_PSD_source_2/hgamma/sub_0148_hgam__training_2.csv
# 0148
# output/Short_PSD_source_2/hgamma/sub_0148_hgam__validation.csv
# 0148
# output/Short_PSD_source_2/hgamma/sub_0149_hgam__training_2.csv
# 0149
# output/Short_PSD_source_2/hgamma/sub_0149_hgam__validation.csv
# 0149
# output/Short_PSD_source_2/hgamma/sub_0150_hgam__training_2.csv
# 0150
# output/Short_PSD_source_2/hgamma/sub_0150_hgam__validation.csv
# 0150
# output/Short_PSD_source_2/hgamma/sub_0151_hgam__training_2.csv
# 0151
# output/Short_PSD_source_2/hgamma/sub_0151_hgam__validation.csv
# 0151
# output/Short_PSD_source_2/hgamma/sub_0152_hgam__training_2.csv
# 0152
# output/Short_PSD_source_2/hgamma/sub_0152_hgam__validation.csv
# 0152
# output/Short_PSD_source_2/hgamma/sub_0154_hgam__training_2.csv
# 0154
# output/Short_PSD_source_2/hgamma/sub_0154_hgam__validation.csv
# 0154
# output/Short_PSD_source_2/hgamma/sub_0155_hgam__training_2.csv
# 0155
# output/Short_PSD_source_2/hgamma/sub_0155_hgam__validation.csv
# 0155
# output/Short_PSD_source_2/hgamma/sub_0156_hgam__training_2.csv
# 0156
# output/Short_PSD_source_2/hgamma/sub_0156_hgam__validation.csv
# 0156
# output/Short_PSD_source_2/hgamma/sub_0157_hgam__training_2.csv
# 0157
# output/Short_PSD_source_2/hgamma/sub_0157_hgam__validation.csv
# 0157
# output/Short_PSD_source_2/hgamma/sub_0158_hgam__training_2.csv
# 0158
# output/Short_PSD_source_2/hgamma/sub_0158_hgam__validation.csv
# 0158
# output/Short_PSD_source_2/hgamma/sub_0159_hgam__training_2.csv
# 0159
# output/Short_PSD_source_2/hgamma/sub_0159_hgam__validation.csv
# 0159
# output/Short_PSD_source_2/hgamma/sub_0160_hgam__training_2.csv
# 0160
# output/Short_PSD_source_2/hgamma/sub_0160_hgam__validation.csv
# 0160
# output/Short_PSD_source_2/hgamma/sub_0161_hgam__training_2.csv
# 0161
# output/Short_PSD_source_2/hgamma/sub_0161_hgam__validation.csv
# 0161
# output/Short_PSD_source_2/hgamma/sub_0162_hgam__training_2.csv
# 0162
# output/Short_PSD_source_2/hgamma/sub_0162_hgam__validation.csv
# 0162
# output/Short_PSD_source_2/hgamma/sub_0164_hgam__training_2.csv
# 0164
# output/Short_PSD_source_2/hgamma/sub_0164_hgam__validation.csv
# 0164
# output/Short_PSD_source_2/hgamma/sub_0165_hgam__training_2.csv
# 0165
# output/Short_PSD_source_2/hgamma/sub_0165_hgam__validation.csv
# 0165
# output/Short_PSD_source_2/hgamma/sub_0166_hgam__training_2.csv
# 0166
# output/Short_PSD_source_2/hgamma/sub_0166_hgam__validation.csv
# 0166
# output/Short_PSD_source_2/hgamma/sub_0167_hgam__training_2.csv
# 0167
# output/Short_PSD_source_2/hgamma/sub_0167_hgam__validation.csv
# 0167
# output/Short_PSD_source_2/hgamma/sub_0168_hgam__training_2.csv
# 0168
# output/Short_PSD_source_2/hgamma/sub_0168_hgam__validation.csv
# 0168
# output/Short_PSD_source_2/hgamma/sub_0169_hgam__training_2.csv
# 0169
# output/Short_PSD_source_2/hgamma/sub_0169_hgam__validation.csv
# 0169
# output/Short_PSD_source_2/hgamma/sub_0170_hgam__training_2.csv
# 0170
# output/Short_PSD_source_2/hgamma/sub_0170_hgam__validation.csv
# 0170
# output/Short_PSD_source_2/hgamma/sub_0172_hgam__training_2.csv
# 0172
# output/Short_PSD_source_2/hgamma/sub_0172_hgam__validation.csv
# 0172
# output/Short_PSD_source_2/hgamma/sub_0174_hgam__training_2.csv
# 0174
# output/Short_PSD_source_2/hgamma/sub_0174_hgam__validation.csv
# 0174
# output/Short_PSD_source_2/hgamma/sub_0175_hgam__training_2.csv
# 0175
# output/Short_PSD_source_2/hgamma/sub_0175_hgam__validation.csv
# 0175
# output/Short_PSD_source_2/hgamma/sub_0176_hgam__training_2.csv
# 0176
# output/Short_PSD_source_2/hgamma/sub_0176_hgam__validation.csv
# 0176
# output/Short_PSD_source_2/hgamma/sub_0177_hgam__training_2.csv
# 0177
# output/Short_PSD_source_2/hgamma/sub_0177_hgam__validation.csv
# 0177
# output/Short_PSD_source_2/hgamma/sub_0179_hgam__training_2.csv
# 0179
# output/Short_PSD_source_2/hgamma/sub_0179_hgam__validation.csv
# 0179
# output/Short_PSD_source_2/hgamma/sub_0181_hgam__training_2.csv
# 0181
# output/Short_PSD_source_2/hgamma/sub_0181_hgam__validation.csv
# 0181
# output/Short_PSD_source_2/hgamma/sub_0183_hgam__training_2.csv
# 0183
# output/Short_PSD_source_2/hgamma/sub_0183_hgam__validation.csv
# 0183
# output/Short_PSD_source_2/hgamma/sub_0184_hgam__training_2.csv
# 0184
# output/Short_PSD_source_2/hgamma/sub_0184_hgam__validation.csv
# 0184
# output/Short_PSD_source_2/hgamma/sub_0185_hgam__training_2.csv
# 0185
# output/Short_PSD_source_2/hgamma/sub_0185_hgam__validation.csv
# 0185
# output/Short_PSD_source_2/hgamma/sub_0186_hgam__training_2.csv
# 0186
# output/Short_PSD_source_2/hgamma/sub_0186_hgam__validation.csv
# 0186
# output/Short_PSD_source_2/hgamma/sub_0187_hgam__training_2.csv
# 0187
# output/Short_PSD_source_2/hgamma/sub_0187_hgam__validation.csv
# 0187
# output/Short_PSD_source_2/hgamma/sub_0188_hgam__training_2.csv
# 0188
# output/Short_PSD_source_2/hgamma/sub_0188_hgam__validation.csv
# 0188
# output/Short_PSD_source_2/hgamma/sub_0189_hgam__training_2.csv
# 0189
# output/Short_PSD_source_2/hgamma/sub_0189_hgam__validation.csv
# 0189
# output/Short_PSD_source_2/hgamma/sub_0190_hgam__training_2.csv
# 0190
# output/Short_PSD_source_2/hgamma/sub_0190_hgam__validation.csv
# 0190

# %%
# Warangle data set into two big feature matrices
## FIRST AND SECOND WINDOW
def prune_subject_csv(filename):
    '''
    This function takes in the subject's csv file from MATLAB, takes out the 
    doubled correlations (because of symmetry) and outputs a numpy array ready to be concatenated
    in the grand feature matrix
    Args:
        filename (string): Name of the csv matrix
    Returns: 
        sub_feat (np.array): Subject's features 
    '''
    #print(filename)
    print(filename[37:41])
    n_feats = int(68*nfreq)
    sub_feat = np.zeros([1, (n_feats)+1]) # Number of unique values in corr matrix + subject label
    psd_matrix = pd.read_csv(filename, header=None)
    mat=np.asmatrix(psd_matrix)
    sub_feat[0, :-1]=mat.flatten()
    sub_feat[0, -1] = int(filename[37:41])    
    return sub_feat


# Get n subjects: both training and testing datasets
onlyfiles = [f for f in listdir('output/Short_PSD_source_3/hgamma/') if isfile(join('output/Short_PSD_source_3/hgamma/', f))]
sub_target = np.zeros([n_subs, (n_feats)+1])
sub_database = np.zeros([n_subs, (n_feats)+1])
iv = 0
it = 0
for iFile in sorted(onlyfiles)[0:(n_subs*2)]: 
    sub = 'output/Short_PSD_source_3/hgamma/' + iFile
    print(sub)
    # [50] == 'v'
    # [59] == '2'
    if sub[57] == '2':
        sub_target[iv, :] = prune_subject_csv(sub)
        iv += 1
    else:
        sub_database[it, :] = prune_subject_csv(sub)
        it += 1
# Out:
# output/Short_PSD_source_3/hgamma/sub_0001_hgam__training_1.csv
# 0001
# output/Short_PSD_source_3/hgamma/sub_0001_hgam__training_2.csv
# 0001
# output/Short_PSD_source_3/hgamma/sub_0002_hgam__training_1.csv
# 0002
# output/Short_PSD_source_3/hgamma/sub_0002_hgam__training_2.csv
# 0002
# output/Short_PSD_source_3/hgamma/sub_0003_hgam__training_1.csv
# 0003
# output/Short_PSD_source_3/hgamma/sub_0003_hgam__training_2.csv
# 0003
# output/Short_PSD_source_3/hgamma/sub_0004_hgam__training_1.csv
# 0004
# output/Short_PSD_source_3/hgamma/sub_0004_hgam__training_2.csv
# 0004
# output/Short_PSD_source_3/hgamma/sub_0005_hgam__training_1.csv
# 0005
# output/Short_PSD_source_3/hgamma/sub_0005_hgam__training_2.csv
# 0005
# output/Short_PSD_source_3/hgamma/sub_0006_hgam__training_1.csv
# 0006
# output/Short_PSD_source_3/hgamma/sub_0006_hgam__training_2.csv
# 0006
# output/Short_PSD_source_3/hgamma/sub_0007_hgam__training_1.csv
# 0007
# output/Short_PSD_source_3/hgamma/sub_0007_hgam__training_2.csv
# 0007
# output/Short_PSD_source_3/hgamma/sub_0008_hgam__training_1.csv
# 0008
# output/Short_PSD_source_3/hgamma/sub_0008_hgam__training_2.csv
# 0008
# output/Short_PSD_source_3/hgamma/sub_0009_hgam__training_1.csv
# 0009
# output/Short_PSD_source_3/hgamma/sub_0009_hgam__training_2.csv
# 0009
# output/Short_PSD_source_3/hgamma/sub_0011_hgam__training_1.csv
# 0011
# output/Short_PSD_source_3/hgamma/sub_0011_hgam__training_2.csv
# 0011
# output/Short_PSD_source_3/hgamma/sub_0012_hgam__training_1.csv
# 0012
# output/Short_PSD_source_3/hgamma/sub_0012_hgam__training_2.csv
# 0012
# output/Short_PSD_source_3/hgamma/sub_0013_hgam__training_1.csv
# 0013
# output/Short_PSD_source_3/hgamma/sub_0013_hgam__training_2.csv
# 0013
# output/Short_PSD_source_3/hgamma/sub_0014_hgam__training_1.csv
# 0014
# output/Short_PSD_source_3/hgamma/sub_0014_hgam__training_2.csv
# 0014
# output/Short_PSD_source_3/hgamma/sub_0015_hgam__training_1.csv
# 0015
# output/Short_PSD_source_3/hgamma/sub_0015_hgam__training_2.csv
# 0015
# output/Short_PSD_source_3/hgamma/sub_0016_hgam__training_1.csv
# 0016
# output/Short_PSD_source_3/hgamma/sub_0016_hgam__training_2.csv
# 0016
# output/Short_PSD_source_3/hgamma/sub_0018_hgam__training_1.csv
# 0018
# output/Short_PSD_source_3/hgamma/sub_0018_hgam__training_2.csv
# 0018
# output/Short_PSD_source_3/hgamma/sub_0020_hgam__training_1.csv
# 0020
# output/Short_PSD_source_3/hgamma/sub_0020_hgam__training_2.csv
# 0020
# output/Short_PSD_source_3/hgamma/sub_0021_hgam__training_1.csv
# 0021
# output/Short_PSD_source_3/hgamma/sub_0021_hgam__training_2.csv
# 0021
# output/Short_PSD_source_3/hgamma/sub_0022_hgam__training_1.csv
# 0022
# output/Short_PSD_source_3/hgamma/sub_0022_hgam__training_2.csv
# 0022
# output/Short_PSD_source_3/hgamma/sub_0023_hgam__training_1.csv
# 0023
# output/Short_PSD_source_3/hgamma/sub_0023_hgam__training_2.csv
# 0023
# output/Short_PSD_source_3/hgamma/sub_0024_hgam__training_1.csv
# 0024
# output/Short_PSD_source_3/hgamma/sub_0024_hgam__training_2.csv
# 0024
# output/Short_PSD_source_3/hgamma/sub_0025_hgam__training_1.csv
# 0025
# output/Short_PSD_source_3/hgamma/sub_0025_hgam__training_2.csv
# 0025
# output/Short_PSD_source_3/hgamma/sub_0026_hgam__training_1.csv
# 0026
# output/Short_PSD_source_3/hgamma/sub_0026_hgam__training_2.csv
# 0026
# output/Short_PSD_source_3/hgamma/sub_0028_hgam__training_1.csv
# 0028
# output/Short_PSD_source_3/hgamma/sub_0028_hgam__training_2.csv
# 0028
# output/Short_PSD_source_3/hgamma/sub_0029_hgam__training_1.csv
# 0029
# output/Short_PSD_source_3/hgamma/sub_0029_hgam__training_2.csv
# 0029
# output/Short_PSD_source_3/hgamma/sub_0030_hgam__training_1.csv
# 0030
# output/Short_PSD_source_3/hgamma/sub_0030_hgam__training_2.csv
# 0030
# output/Short_PSD_source_3/hgamma/sub_0031_hgam__training_1.csv
# 0031
# output/Short_PSD_source_3/hgamma/sub_0031_hgam__training_2.csv
# 0031
# output/Short_PSD_source_3/hgamma/sub_0032_hgam__training_1.csv
# 0032
# output/Short_PSD_source_3/hgamma/sub_0032_hgam__training_2.csv
# 0032
# output/Short_PSD_source_3/hgamma/sub_0033_hgam__training_1.csv
# 0033
# output/Short_PSD_source_3/hgamma/sub_0033_hgam__training_2.csv
# 0033
# output/Short_PSD_source_3/hgamma/sub_0035_hgam__training_1.csv
# 0035
# output/Short_PSD_source_3/hgamma/sub_0035_hgam__training_2.csv
# 0035
# output/Short_PSD_source_3/hgamma/sub_0036_hgam__training_1.csv
# 0036
# output/Short_PSD_source_3/hgamma/sub_0036_hgam__training_2.csv
# 0036
# output/Short_PSD_source_3/hgamma/sub_0037_hgam__training_1.csv
# 0037
# output/Short_PSD_source_3/hgamma/sub_0037_hgam__training_2.csv
# 0037
# output/Short_PSD_source_3/hgamma/sub_0040_hgam__training_1.csv
# 0040
# output/Short_PSD_source_3/hgamma/sub_0040_hgam__training_2.csv
# 0040
# output/Short_PSD_source_3/hgamma/sub_0041_hgam__training_1.csv
# 0041
# output/Short_PSD_source_3/hgamma/sub_0041_hgam__training_2.csv
# 0041
# output/Short_PSD_source_3/hgamma/sub_0045_hgam__training_1.csv
# 0045
# output/Short_PSD_source_3/hgamma/sub_0045_hgam__training_2.csv
# 0045
# output/Short_PSD_source_3/hgamma/sub_0046_hgam__training_1.csv
# 0046
# output/Short_PSD_source_3/hgamma/sub_0046_hgam__training_2.csv
# 0046
# output/Short_PSD_source_3/hgamma/sub_0047_hgam__training_1.csv
# 0047
# output/Short_PSD_source_3/hgamma/sub_0047_hgam__training_2.csv
# 0047
# output/Short_PSD_source_3/hgamma/sub_0048_hgam__training_1.csv
# 0048
# output/Short_PSD_source_3/hgamma/sub_0048_hgam__training_2.csv
# 0048
# output/Short_PSD_source_3/hgamma/sub_0049_hgam__training_1.csv
# 0049
# output/Short_PSD_source_3/hgamma/sub_0049_hgam__training_2.csv
# 0049
# output/Short_PSD_source_3/hgamma/sub_0050_hgam__training_1.csv
# 0050
# output/Short_PSD_source_3/hgamma/sub_0050_hgam__training_2.csv
# 0050
# output/Short_PSD_source_3/hgamma/sub_0051_hgam__training_1.csv
# 0051
# output/Short_PSD_source_3/hgamma/sub_0051_hgam__training_2.csv
# 0051
# output/Short_PSD_source_3/hgamma/sub_0052_hgam__training_1.csv
# 0052
# output/Short_PSD_source_3/hgamma/sub_0052_hgam__training_2.csv
# 0052
# output/Short_PSD_source_3/hgamma/sub_0053_hgam__training_1.csv
# 0053
# output/Short_PSD_source_3/hgamma/sub_0053_hgam__training_2.csv
# 0053
# output/Short_PSD_source_3/hgamma/sub_0054_hgam__training_1.csv
# 0054
# output/Short_PSD_source_3/hgamma/sub_0054_hgam__training_2.csv
# 0054
# output/Short_PSD_source_3/hgamma/sub_0055_hgam__training_1.csv
# 0055
# output/Short_PSD_source_3/hgamma/sub_0055_hgam__training_2.csv
# 0055
# output/Short_PSD_source_3/hgamma/sub_0056_hgam__training_1.csv
# 0056
# output/Short_PSD_source_3/hgamma/sub_0056_hgam__training_2.csv
# 0056
# output/Short_PSD_source_3/hgamma/sub_0058_hgam__training_1.csv
# 0058
# output/Short_PSD_source_3/hgamma/sub_0058_hgam__training_2.csv
# 0058
# output/Short_PSD_source_3/hgamma/sub_0059_hgam__training_1.csv
# 0059
# output/Short_PSD_source_3/hgamma/sub_0059_hgam__training_2.csv
# 0059
# output/Short_PSD_source_3/hgamma/sub_0060_hgam__training_1.csv
# 0060
# output/Short_PSD_source_3/hgamma/sub_0060_hgam__training_2.csv
# 0060
# output/Short_PSD_source_3/hgamma/sub_0061_hgam__training_1.csv
# 0061
# output/Short_PSD_source_3/hgamma/sub_0061_hgam__training_2.csv
# 0061
# output/Short_PSD_source_3/hgamma/sub_0062_hgam__training_1.csv
# 0062
# output/Short_PSD_source_3/hgamma/sub_0062_hgam__training_2.csv
# 0062
# output/Short_PSD_source_3/hgamma/sub_0063_hgam__training_1.csv
# 0063
# output/Short_PSD_source_3/hgamma/sub_0063_hgam__training_2.csv
# 0063
# output/Short_PSD_source_3/hgamma/sub_0064_hgam__training_1.csv
# 0064
# output/Short_PSD_source_3/hgamma/sub_0064_hgam__training_2.csv
# 0064
# output/Short_PSD_source_3/hgamma/sub_0065_hgam__training_1.csv
# 0065
# output/Short_PSD_source_3/hgamma/sub_0065_hgam__training_2.csv
# 0065
# output/Short_PSD_source_3/hgamma/sub_0066_hgam__training_1.csv
# 0066
# output/Short_PSD_source_3/hgamma/sub_0066_hgam__training_2.csv
# 0066
# output/Short_PSD_source_3/hgamma/sub_0068_hgam__training_1.csv
# 0068
# output/Short_PSD_source_3/hgamma/sub_0068_hgam__training_2.csv
# 0068
# output/Short_PSD_source_3/hgamma/sub_0069_hgam__training_1.csv
# 0069
# output/Short_PSD_source_3/hgamma/sub_0069_hgam__training_2.csv
# 0069
# output/Short_PSD_source_3/hgamma/sub_0070_hgam__training_1.csv
# 0070
# output/Short_PSD_source_3/hgamma/sub_0070_hgam__training_2.csv
# 0070
# output/Short_PSD_source_3/hgamma/sub_0071_hgam__training_1.csv
# 0071
# output/Short_PSD_source_3/hgamma/sub_0071_hgam__training_2.csv
# 0071
# output/Short_PSD_source_3/hgamma/sub_0074_hgam__training_1.csv
# 0074
# output/Short_PSD_source_3/hgamma/sub_0074_hgam__training_2.csv
# 0074
# output/Short_PSD_source_3/hgamma/sub_0075_hgam__training_1.csv
# 0075
# output/Short_PSD_source_3/hgamma/sub_0075_hgam__training_2.csv
# 0075
# output/Short_PSD_source_3/hgamma/sub_0076_hgam__training_1.csv
# 0076
# output/Short_PSD_source_3/hgamma/sub_0076_hgam__training_2.csv
# 0076
# output/Short_PSD_source_3/hgamma/sub_0077_hgam__training_1.csv
# 0077
# output/Short_PSD_source_3/hgamma/sub_0077_hgam__training_2.csv
# 0077
# output/Short_PSD_source_3/hgamma/sub_0078_hgam__training_1.csv
# 0078
# output/Short_PSD_source_3/hgamma/sub_0078_hgam__training_2.csv
# 0078
# output/Short_PSD_source_3/hgamma/sub_0079_hgam__training_1.csv
# 0079
# output/Short_PSD_source_3/hgamma/sub_0079_hgam__training_2.csv
# 0079
# output/Short_PSD_source_3/hgamma/sub_0080_hgam__training_1.csv
# 0080
# output/Short_PSD_source_3/hgamma/sub_0080_hgam__training_2.csv
# 0080
# output/Short_PSD_source_3/hgamma/sub_0082_hgam__training_1.csv
# 0082
# output/Short_PSD_source_3/hgamma/sub_0082_hgam__training_2.csv
# 0082
# output/Short_PSD_source_3/hgamma/sub_0083_hgam__training_1.csv
# 0083
# output/Short_PSD_source_3/hgamma/sub_0083_hgam__training_2.csv
# 0083
# output/Short_PSD_source_3/hgamma/sub_0084_hgam__training_1.csv
# 0084
# output/Short_PSD_source_3/hgamma/sub_0084_hgam__training_2.csv
# 0084
# output/Short_PSD_source_3/hgamma/sub_0085_hgam__training_1.csv
# 0085
# output/Short_PSD_source_3/hgamma/sub_0085_hgam__training_2.csv
# 0085
# output/Short_PSD_source_3/hgamma/sub_0086_hgam__training_1.csv
# 0086
# output/Short_PSD_source_3/hgamma/sub_0086_hgam__training_2.csv
# 0086
# output/Short_PSD_source_3/hgamma/sub_0087_hgam__training_1.csv
# 0087
# output/Short_PSD_source_3/hgamma/sub_0087_hgam__training_2.csv
# 0087
# output/Short_PSD_source_3/hgamma/sub_0088_hgam__training_1.csv
# 0088
# output/Short_PSD_source_3/hgamma/sub_0088_hgam__training_2.csv
# 0088
# output/Short_PSD_source_3/hgamma/sub_0089_hgam__training_1.csv
# 0089
# output/Short_PSD_source_3/hgamma/sub_0089_hgam__training_2.csv
# 0089
# output/Short_PSD_source_3/hgamma/sub_0090_hgam__training_1.csv
# 0090
# output/Short_PSD_source_3/hgamma/sub_0090_hgam__training_2.csv
# 0090
# output/Short_PSD_source_3/hgamma/sub_0091_hgam__training_1.csv
# 0091
# output/Short_PSD_source_3/hgamma/sub_0091_hgam__training_2.csv
# 0091
# output/Short_PSD_source_3/hgamma/sub_0093_hgam__training_1.csv
# 0093
# output/Short_PSD_source_3/hgamma/sub_0093_hgam__training_2.csv
# 0093
# output/Short_PSD_source_3/hgamma/sub_0094_hgam__training_1.csv
# 0094
# output/Short_PSD_source_3/hgamma/sub_0094_hgam__training_2.csv
# 0094
# output/Short_PSD_source_3/hgamma/sub_0095_hgam__training_1.csv
# 0095
# output/Short_PSD_source_3/hgamma/sub_0095_hgam__training_2.csv
# 0095
# output/Short_PSD_source_3/hgamma/sub_0096_hgam__training_1.csv
# 0096
# output/Short_PSD_source_3/hgamma/sub_0096_hgam__training_2.csv
# 0096
# output/Short_PSD_source_3/hgamma/sub_0097_hgam__training_1.csv
# 0097
# output/Short_PSD_source_3/hgamma/sub_0097_hgam__training_2.csv
# 0097
# output/Short_PSD_source_3/hgamma/sub_0098_hgam__training_1.csv
# 0098
# output/Short_PSD_source_3/hgamma/sub_0098_hgam__training_2.csv
# 0098
# output/Short_PSD_source_3/hgamma/sub_0099_hgam__training_1.csv
# 0099
# output/Short_PSD_source_3/hgamma/sub_0099_hgam__training_2.csv
# 0099
# output/Short_PSD_source_3/hgamma/sub_0101_hgam__training_1.csv
# 0101
# output/Short_PSD_source_3/hgamma/sub_0101_hgam__training_2.csv
# 0101
# output/Short_PSD_source_3/hgamma/sub_0102_hgam__training_1.csv
# 0102
# output/Short_PSD_source_3/hgamma/sub_0102_hgam__training_2.csv
# 0102
# output/Short_PSD_source_3/hgamma/sub_0103_hgam__training_1.csv
# 0103
# output/Short_PSD_source_3/hgamma/sub_0103_hgam__training_2.csv
# 0103
# output/Short_PSD_source_3/hgamma/sub_0105_hgam__training_1.csv
# 0105
# output/Short_PSD_source_3/hgamma/sub_0105_hgam__training_2.csv
# 0105
# output/Short_PSD_source_3/hgamma/sub_0106_hgam__training_1.csv
# 0106
# output/Short_PSD_source_3/hgamma/sub_0106_hgam__training_2.csv
# 0106
# output/Short_PSD_source_3/hgamma/sub_0108_hgam__training_1.csv
# 0108
# output/Short_PSD_source_3/hgamma/sub_0108_hgam__training_2.csv
# 0108
# output/Short_PSD_source_3/hgamma/sub_0109_hgam__training_1.csv
# 0109
# output/Short_PSD_source_3/hgamma/sub_0109_hgam__training_2.csv
# 0109
# output/Short_PSD_source_3/hgamma/sub_0110_hgam__training_1.csv
# 0110
# output/Short_PSD_source_3/hgamma/sub_0110_hgam__training_2.csv
# 0110
# output/Short_PSD_source_3/hgamma/sub_0111_hgam__training_1.csv
# 0111
# output/Short_PSD_source_3/hgamma/sub_0111_hgam__training_2.csv
# 0111
# output/Short_PSD_source_3/hgamma/sub_0112_hgam__training_1.csv
# 0112
# output/Short_PSD_source_3/hgamma/sub_0112_hgam__training_2.csv
# 0112
# output/Short_PSD_source_3/hgamma/sub_0114_hgam__training_1.csv
# 0114
# output/Short_PSD_source_3/hgamma/sub_0114_hgam__training_2.csv
# 0114
# output/Short_PSD_source_3/hgamma/sub_0116_hgam__training_1.csv
# 0116
# output/Short_PSD_source_3/hgamma/sub_0116_hgam__training_2.csv
# 0116
# output/Short_PSD_source_3/hgamma/sub_0117_hgam__training_1.csv
# 0117
# output/Short_PSD_source_3/hgamma/sub_0117_hgam__training_2.csv
# 0117
# output/Short_PSD_source_3/hgamma/sub_0118_hgam__training_1.csv
# 0118
# output/Short_PSD_source_3/hgamma/sub_0118_hgam__training_2.csv
# 0118
# output/Short_PSD_source_3/hgamma/sub_0119_hgam__training_1.csv
# 0119
# output/Short_PSD_source_3/hgamma/sub_0119_hgam__training_2.csv
# 0119
# output/Short_PSD_source_3/hgamma/sub_0120_hgam__training_1.csv
# 0120
# output/Short_PSD_source_3/hgamma/sub_0120_hgam__training_2.csv
# 0120
# output/Short_PSD_source_3/hgamma/sub_0121_hgam__training_1.csv
# 0121
# output/Short_PSD_source_3/hgamma/sub_0121_hgam__training_2.csv
# 0121
# output/Short_PSD_source_3/hgamma/sub_0123_hgam__training_1.csv
# 0123
# output/Short_PSD_source_3/hgamma/sub_0123_hgam__training_2.csv
# 0123
# output/Short_PSD_source_3/hgamma/sub_0125_hgam__training_1.csv
# 0125
# output/Short_PSD_source_3/hgamma/sub_0125_hgam__training_2.csv
# 0125
# output/Short_PSD_source_3/hgamma/sub_0126_hgam__training_1.csv
# 0126
# output/Short_PSD_source_3/hgamma/sub_0126_hgam__training_2.csv
# 0126
# output/Short_PSD_source_3/hgamma/sub_0127_hgam__training_1.csv
# 0127
# output/Short_PSD_source_3/hgamma/sub_0127_hgam__training_2.csv
# 0127
# output/Short_PSD_source_3/hgamma/sub_0128_hgam__training_1.csv
# 0128
# output/Short_PSD_source_3/hgamma/sub_0128_hgam__training_2.csv
# 0128
# output/Short_PSD_source_3/hgamma/sub_0129_hgam__training_1.csv
# 0129
# output/Short_PSD_source_3/hgamma/sub_0129_hgam__training_2.csv
# 0129
# output/Short_PSD_source_3/hgamma/sub_0130_hgam__training_1.csv
# 0130
# output/Short_PSD_source_3/hgamma/sub_0130_hgam__training_2.csv
# 0130
# output/Short_PSD_source_3/hgamma/sub_0131_hgam__training_1.csv
# 0131
# output/Short_PSD_source_3/hgamma/sub_0131_hgam__training_2.csv
# 0131
# output/Short_PSD_source_3/hgamma/sub_0132_hgam__training_1.csv
# 0132
# output/Short_PSD_source_3/hgamma/sub_0132_hgam__training_2.csv
# 0132
# output/Short_PSD_source_3/hgamma/sub_0133_hgam__training_1.csv
# 0133
# output/Short_PSD_source_3/hgamma/sub_0133_hgam__training_2.csv
# 0133
# output/Short_PSD_source_3/hgamma/sub_0134_hgam__training_1.csv
# 0134
# output/Short_PSD_source_3/hgamma/sub_0134_hgam__training_2.csv
# 0134
# output/Short_PSD_source_3/hgamma/sub_0135_hgam__training_1.csv
# 0135
# output/Short_PSD_source_3/hgamma/sub_0135_hgam__training_2.csv
# 0135
# output/Short_PSD_source_3/hgamma/sub_0136_hgam__training_1.csv
# 0136
# output/Short_PSD_source_3/hgamma/sub_0136_hgam__training_2.csv
# 0136
# output/Short_PSD_source_3/hgamma/sub_0139_hgam__training_1.csv
# 0139
# output/Short_PSD_source_3/hgamma/sub_0139_hgam__training_2.csv
# 0139
# output/Short_PSD_source_3/hgamma/sub_0140_hgam__training_1.csv
# 0140
# output/Short_PSD_source_3/hgamma/sub_0140_hgam__training_2.csv
# 0140
# output/Short_PSD_source_3/hgamma/sub_0141_hgam__training_1.csv
# 0141
# output/Short_PSD_source_3/hgamma/sub_0141_hgam__training_2.csv
# 0141
# output/Short_PSD_source_3/hgamma/sub_0142_hgam__training_1.csv
# 0142
# output/Short_PSD_source_3/hgamma/sub_0142_hgam__training_2.csv
# 0142
# output/Short_PSD_source_3/hgamma/sub_0143_hgam__training_1.csv
# 0143
# output/Short_PSD_source_3/hgamma/sub_0143_hgam__training_2.csv
# 0143
# output/Short_PSD_source_3/hgamma/sub_0144_hgam__training_1.csv
# 0144
# output/Short_PSD_source_3/hgamma/sub_0144_hgam__training_2.csv
# 0144
# output/Short_PSD_source_3/hgamma/sub_0145_hgam__training_1.csv
# 0145
# output/Short_PSD_source_3/hgamma/sub_0145_hgam__training_2.csv
# 0145
# output/Short_PSD_source_3/hgamma/sub_0146_hgam__training_1.csv
# 0146
# output/Short_PSD_source_3/hgamma/sub_0146_hgam__training_2.csv
# 0146
# output/Short_PSD_source_3/hgamma/sub_0147_hgam__training_1.csv
# 0147
# output/Short_PSD_source_3/hgamma/sub_0147_hgam__training_2.csv
# 0147
# output/Short_PSD_source_3/hgamma/sub_0148_hgam__training_1.csv
# 0148
# output/Short_PSD_source_3/hgamma/sub_0148_hgam__training_2.csv
# 0148
# output/Short_PSD_source_3/hgamma/sub_0149_hgam__training_1.csv
# 0149
# output/Short_PSD_source_3/hgamma/sub_0149_hgam__training_2.csv
# 0149
# output/Short_PSD_source_3/hgamma/sub_0150_hgam__training_1.csv
# 0150
# output/Short_PSD_source_3/hgamma/sub_0150_hgam__training_2.csv
# 0150
# output/Short_PSD_source_3/hgamma/sub_0151_hgam__training_1.csv
# 0151
# output/Short_PSD_source_3/hgamma/sub_0151_hgam__training_2.csv
# 0151
# output/Short_PSD_source_3/hgamma/sub_0152_hgam__training_1.csv
# 0152
# output/Short_PSD_source_3/hgamma/sub_0152_hgam__training_2.csv
# 0152
# output/Short_PSD_source_3/hgamma/sub_0154_hgam__training_1.csv
# 0154
# output/Short_PSD_source_3/hgamma/sub_0154_hgam__training_2.csv
# 0154
# output/Short_PSD_source_3/hgamma/sub_0155_hgam__training_1.csv
# 0155
# output/Short_PSD_source_3/hgamma/sub_0155_hgam__training_2.csv
# 0155
# output/Short_PSD_source_3/hgamma/sub_0156_hgam__training_1.csv
# 0156
# output/Short_PSD_source_3/hgamma/sub_0156_hgam__training_2.csv
# 0156
# output/Short_PSD_source_3/hgamma/sub_0157_hgam__training_1.csv
# 0157
# output/Short_PSD_source_3/hgamma/sub_0157_hgam__training_2.csv
# 0157
# output/Short_PSD_source_3/hgamma/sub_0158_hgam__training_1.csv
# 0158
# output/Short_PSD_source_3/hgamma/sub_0158_hgam__training_2.csv
# 0158
# output/Short_PSD_source_3/hgamma/sub_0159_hgam__training_1.csv
# 0159
# output/Short_PSD_source_3/hgamma/sub_0159_hgam__training_2.csv
# 0159
# output/Short_PSD_source_3/hgamma/sub_0160_hgam__training_1.csv
# 0160
# output/Short_PSD_source_3/hgamma/sub_0160_hgam__training_2.csv
# 0160
# output/Short_PSD_source_3/hgamma/sub_0161_hgam__training_1.csv
# 0161
# output/Short_PSD_source_3/hgamma/sub_0161_hgam__training_2.csv
# 0161
# output/Short_PSD_source_3/hgamma/sub_0162_hgam__training_1.csv
# 0162
# output/Short_PSD_source_3/hgamma/sub_0162_hgam__training_2.csv
# 0162
# output/Short_PSD_source_3/hgamma/sub_0164_hgam__training_1.csv
# 0164
# output/Short_PSD_source_3/hgamma/sub_0164_hgam__training_2.csv
# 0164
# output/Short_PSD_source_3/hgamma/sub_0165_hgam__training_1.csv
# 0165
# output/Short_PSD_source_3/hgamma/sub_0165_hgam__training_2.csv
# 0165
# output/Short_PSD_source_3/hgamma/sub_0166_hgam__training_1.csv
# 0166
# output/Short_PSD_source_3/hgamma/sub_0166_hgam__training_2.csv
# 0166
# output/Short_PSD_source_3/hgamma/sub_0167_hgam__training_1.csv
# 0167
# output/Short_PSD_source_3/hgamma/sub_0167_hgam__training_2.csv
# 0167
# output/Short_PSD_source_3/hgamma/sub_0168_hgam__training_1.csv
# 0168
# output/Short_PSD_source_3/hgamma/sub_0168_hgam__training_2.csv
# 0168
# output/Short_PSD_source_3/hgamma/sub_0169_hgam__training_1.csv
# 0169
# output/Short_PSD_source_3/hgamma/sub_0169_hgam__training_2.csv
# 0169
# output/Short_PSD_source_3/hgamma/sub_0170_hgam__training_1.csv
# 0170
# output/Short_PSD_source_3/hgamma/sub_0170_hgam__training_2.csv
# 0170
# output/Short_PSD_source_3/hgamma/sub_0172_hgam__training_1.csv
# 0172
# output/Short_PSD_source_3/hgamma/sub_0172_hgam__training_2.csv
# 0172
# output/Short_PSD_source_3/hgamma/sub_0174_hgam__training_1.csv
# 0174
# output/Short_PSD_source_3/hgamma/sub_0174_hgam__training_2.csv
# 0174
# output/Short_PSD_source_3/hgamma/sub_0175_hgam__training_1.csv
# 0175
# output/Short_PSD_source_3/hgamma/sub_0175_hgam__training_2.csv
# 0175
# output/Short_PSD_source_3/hgamma/sub_0176_hgam__training_1.csv
# 0176
# output/Short_PSD_source_3/hgamma/sub_0176_hgam__training_2.csv
# 0176
# output/Short_PSD_source_3/hgamma/sub_0177_hgam__training_1.csv
# 0177
# output/Short_PSD_source_3/hgamma/sub_0177_hgam__training_2.csv
# 0177
# output/Short_PSD_source_3/hgamma/sub_0179_hgam__training_1.csv
# 0179
# output/Short_PSD_source_3/hgamma/sub_0179_hgam__training_2.csv
# 0179
# output/Short_PSD_source_3/hgamma/sub_0181_hgam__training_1.csv
# 0181
# output/Short_PSD_source_3/hgamma/sub_0181_hgam__training_2.csv
# 0181
# output/Short_PSD_source_3/hgamma/sub_0183_hgam__training_1.csv
# 0183
# output/Short_PSD_source_3/hgamma/sub_0183_hgam__training_2.csv
# 0183
# output/Short_PSD_source_3/hgamma/sub_0184_hgam__training_1.csv
# 0184
# output/Short_PSD_source_3/hgamma/sub_0184_hgam__training_2.csv
# 0184
# output/Short_PSD_source_3/hgamma/sub_0185_hgam__training_1.csv
# 0185
# output/Short_PSD_source_3/hgamma/sub_0185_hgam__training_2.csv
# 0185
# output/Short_PSD_source_3/hgamma/sub_0186_hgam__training_1.csv
# 0186
# output/Short_PSD_source_3/hgamma/sub_0186_hgam__training_2.csv
# 0186
# output/Short_PSD_source_3/hgamma/sub_0187_hgam__training_1.csv
# 0187
# output/Short_PSD_source_3/hgamma/sub_0187_hgam__training_2.csv
# 0187
# output/Short_PSD_source_3/hgamma/sub_0188_hgam__training_1.csv
# 0188
# output/Short_PSD_source_3/hgamma/sub_0188_hgam__training_2.csv
# 0188
# output/Short_PSD_source_3/hgamma/sub_0189_hgam__training_1.csv
# 0189
# output/Short_PSD_source_3/hgamma/sub_0189_hgam__training_2.csv
# 0189
# output/Short_PSD_source_3/hgamma/sub_0190_hgam__training_1.csv
# 0190
# output/Short_PSD_source_3/hgamma/sub_0190_hgam__training_2.csv
# 0190

# %%
# Correlations can be computed as the dot product between two z-scored vectors
z_target = sp.stats.zscore(sub_target[:, :-1], axis = 1)
z_database = sp.stats.zscore(sub_database[:,:-1], axis = 1)
predictions = z_target.dot(z_database.transpose()) / (sub_database.shape[1] - 1) # target, database
target_from_database = accuracy_score(range(n_subs), predictions.argmax(axis = 1))
database_from_target = accuracy_score(range(n_subs), predictions.argmax(axis = 0))

print('When predicting the target from the database, we get a ' + str(target_from_database*100)[0:5] + '% accuracy')
print('When predicting the database from the target, we get a ' + str(database_from_target*100)[0:5] + '% accuracy')
# Out:
# When predicting the target from the database, we get a 90.50% accuracy
# When predicting the database from the target, we get a 93.03% accuracy

# %% [markdown]
# # We get pretty high raw accuracy scores (similar to what Finn et al., 2015). Now we look at the influence of using a PCA reconstruction (i.e. the framework Amico & Goni suggested) on the feature space

# %%
# Take feature matrix of each subject and put it in one, big matrix (n_subs * 2, features)
fc = np.concatenate((sub_target[:, :-1], sub_database[:, :-1]), axis = 0)
labels = np.concatenate((sub_target[:, -1], sub_database[:, -1]), axis = 0)
steps = np.concatenate((np.array([2, 5]), np.arange(10, (n_subs*2) ,10)), axis = 0) # 2, 5, 10 - n_subs*2 in 10 
pca_target_from_database = np.zeros(len(steps))
pca_database_from_target = np.zeros(len(steps))
pca_self_id = np.zeros((len(steps), n_subs))
# Get the PCA decomposition in an iterative manner and calculate raw accuracy at each step of the way 
for i in range(len(steps)):
    # PCA reconstruction usin i components
    pca = PCA(n_components = steps[i]) 
    pca.fit(fc) # Estimate the components (using an SVD on the centered fc)
    fc_pca = pca.transform(fc) # Calculate the loadings
    fc_recon = pca.inverse_transform(fc_pca) # Get projection onto components in signal space and add back means
    
    # Accuracy and self-identifiability
    pca_sub_target = fc_recon[:n_subs, :]
    pca_sub_database = fc_recon[n_subs:, :]
    pca_z_target = sp.stats.zscore(pca_sub_target, axis = 1)
    pca_z_database = sp.stats.zscore(pca_sub_database, axis = 1)
    pca_predictions = pca_z_target.dot(pca_z_database.transpose()) / (sub_database.shape[1] - 1) # target, database
    pca_target_from_database[i] = accuracy_score(range(n_subs), pca_predictions.argmax(axis = 1))
    pca_database_from_target[i] = accuracy_score(range(n_subs), pca_predictions.argmax(axis = 0))
    pca_self_id[i, :] = np.diagonal(sp.stats.zscore(pca_predictions, axis = 1))
    
# For the figure, we also get self-identifiability and reconstructed self-identifiability
self_id = np.diagonal(sp.stats.zscore(predictions, axis = 1))

# %%
# Get the fig initiated
fig, axs = plt.subplots(1,3, figsize=(30, 10))
fig.subplots_adjust(hspace = .2, wspace = .2)
axs = axs.ravel()

# Variance explained vs Components
axs[0].plot(pca.explained_variance_ratio_*100, linewidth=2)
axs[0].set_xlabel('Components')
axs[0].set_ylabel('Variance Explained [%]')
axs[0].set_title('PCA reconstruction', size = 'x-large')

# Accuracy vs Components
axs[1].plot(steps, pca_target_from_database*100, linewidth = 2, label = 'Reconstructed')
axs[1].plot(steps, target_from_database.repeat(len(steps))*100, linewidth = 2, label = 'Original')
axs[1].set_xlabel('Components')
axs[1].set_ylabel('Accuracy [%]')
axs[1].set_title('Accuracy as a function of PCs', size = 'x-large')
axs[1].legend(fontsize = 13, frameon = True)

# Self identifiability vs Components
axs[2].plot(steps, pca_self_id.mean(axis = 1), linewidth = 2, label = 'Reconstructed')
axs[2].plot(steps, self_id.mean().repeat(len(steps)), linewidth = 2, label = 'Original')
axs[2].set_xlabel('Components')
axs[2].set_ylabel('Self identifiability')
axs[2].set_title('Self-Identifiability as a function of PCs', size = 'x-large')
axs[2].legend(fontsize = 13, frameon = True)

sns.despine()
plt.show()

# %%
# Get the PCA reconstruction from the number of components that give us the max self_identifiability 
pca = PCA(n_components = steps[np.argmax(pca_self_id.mean(axis = 1))]) 
pca.fit(fc) # Estimate the components (using an SVD on the centered fc)
fc_pca = pca.transform(fc) # Calculate the loadings
fc_recon = pca.inverse_transform(fc_pca) # Get projection onto components in signal space

# Accuracy and self-identifiability
pca_sub_target = fc_recon[:n_subs, :]
pca_sub_database = fc_recon[n_subs:, :]
pca_z_target = sp.stats.zscore(pca_sub_target, axis = 1)
pca_z_database = sp.stats.zscore(pca_sub_database, axis = 1)
pca_predictions = pca_z_target.dot(pca_z_database.transpose()) / (sub_database.shape[1] - 1) # target, database
pca_target_from_database = accuracy_score(range(n_subs), pca_predictions.argmax(axis = 1))
pca_database_from_target = accuracy_score(range(n_subs), pca_predictions.argmax(axis = 0))
pca_self_id = np.diagonal(sp.stats.zscore(pca_predictions, axis = 1))

print('When predicting the reconstructed target from the reconstructed database, we get a ' + str(pca_target_from_database) + ' accuracy')
print('When predicting the reconstructed database from the reconstructed target, we get a ' + str(pca_database_from_target) + ' accuracy')
# Out:
# When predicting the reconstructed target from the reconstructed database, we get a 0.8734177215189873 accuracy
# When predicting the reconstructed database from the reconstructed target, we get a 0.8987341772151899 accuracy

# %%
import numpy as np
vp_original = np.concatenate((np.expand_dims(self_id, axis = 1), np.expand_dims(np.repeat('Original', n_subs), axis = 1)), axis = 1)
vp_recon = np.concatenate((np.expand_dims(pca_self_id, axis = 1), np.expand_dims(np.repeat('Reconstructed', n_subs), axis = 1)), axis = 1)
self_id_grand = np.concatenate((vp_original, vp_recon), axis = 0)
self_id_plot = pd.DataFrame(data = self_id_grand, columns = ['Self Identifiability', 'Feature Space'])
self_id_plot['Self Identifiability'] = self_id_plot['Self Identifiability'].astype(float)
self_id_plot['Feature Space'] = self_id_plot['Feature Space'].astype('category', ordered = False, categories = ['Original', 'Reconstructed'])

plt.figure(figsize=(10, 10))
axs = sns.violinplot(x = 'Feature Space', y = 'Self Identifiability', data = self_id_plot)
axs.set_title('Self-identifiability: Original and Reconstructed Space', size = 'x-large')
sns.despine()
plt.show()

plt.figure(figsize=(10, 10))
axs = sns.heatmap(predictions, cmap='Reds', square=True)
plt.figure(figsize=(10, 10))
axs = sns.heatmap(pca_predictions, cmap='Reds', square=True)
# Out:
# /Users/jasondsc/opt/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3331: FutureWarning: specifying 'categories' or 'ordered' in .astype() is deprecated; pass a CategoricalDtype instead
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %% [markdown]
# # IV. Identifiability as a function of subjects' characteristics

# %%
# First we get subject number
def subs_list(sub):
    if sub < 10:
        return 'sub-000' + sub.astype(int).astype(str)
    elif sub >= 10 and sub < 100:
        return 'sub-00' + sub.astype(int).astype(str)
    else: 
        return 'sub-0' + sub.astype(int).astype(str)
    
    
# Get subject data from 
subs_analyzed = list(map(subs_list, sub_target[:, -1]))
subs_omega = pd.read_csv('data/OMEGA_BIDS/participants.csv', sep=',', header=0)
subs_omega = subs_omega[subs_omega['participants_id'].isin(subs_analyzed)]

# Wrangle data to get subjecs' age
sub_age = list(subs_omega['X.session.age.'].values)
for x in range(len(sub_age)):
    if isinstance(sub_age[x], str):
        sub_age[x] = sub_age[x][3:5]
    if (sub_age[x]==""):
        sub_age[x] = np.nan
        
sub_age = np.array(sub_age).astype(float)
age_mean = np.floor(np.nanmean(sub_age))
inds = np.where(np.isnan(sub_age))
sub_age[inds] = age_mean
subs_omega['X.session.age.'] = sub_age
subs_omega = subs_omega.rename(columns={'X.session.age.': 'age'})


# Wrangle data to get subjects' group
sub_group = list(subs_omega['Group'].values)
for x in range(len(sub_group)):
    if isinstance(sub_group[x], str):
        if sub_group[x] != 'Control':
            sub_group[x] = 'Spec'
    else:
        sub_group[x] = 'Control' # The most common label here is 'Control', so I decided to handles NaN's that way
subs_omega['Group'] = sub_group

sub_time= list(subs_omega['time_of_record'].values)
subs_omega['time_of_record']= sub_time

# Do some final wrangling before plotting relationshisp between variables and 
subs_omega['identifiability'] = self_id
subs_omega['pca_identifiability'] = pca_self_id
subs_omega = subs_omega.rename(columns={'Dominant.Hand': 'Dominant Hand'})
subs_omega = subs_omega.drop(['Year.of.birth', 'Questionnaire.Version'], axis = 1)

# %%
# Plot relations between group, age, gender, dominant hand -and- identifiability
fig, axs = plt.subplots(1,4, figsize=(35, 8), sharey=True)
fig.subplots_adjust(hspace = .2, wspace = .2)
axs = axs.ravel()

# Age
axs[0].scatter(subs_omega['age'].values, subs_omega['identifiability'].values)    
axs[0].set_title('Age vs Identifiability', fontsize = 20)
axs[0].set_xlabel('Age', fontsize = 15)
axs[0].set_ylabel('Self Identifiability', fontsize = 15)

# Gender
sns.violinplot(x = 'Gender', y = 'identifiability', data = subs_omega, ax = axs[1])
axs[1].set_xlabel('Gender', fontsize = 15)
axs[1].set_xticklabels(['Male','Female'], fontsize = 15)
axs[1].set_ylabel('')
axs[1].set_title('Gender vs Identifiability', fontsize = 20)


# Dominant hand
sns.violinplot(x = 'Dominant Hand', y = 'identifiability', data = subs_omega, ax = axs[2])
axs[2].set_ylabel('')
axs[2].set_xlabel('Dominant Hand', fontsize = 15)
axs[2].set_xticklabels(['Right','Left', 'Other'], fontsize = 15)
axs[2].set_title('Dominant Hand vs Identifiability', fontsize = 20)

# Group
sns.violinplot(x = 'Group', y = 'identifiability', data = subs_omega, ax = axs[3])
axs[3].set_ylabel('')
axs[3].set_xlabel('Group', fontsize = 15)
axs[3].set_xticklabels(['Control','Other'], fontsize = 15)
axs[3].set_title('Group vs Identifiability', fontsize = 20)

plt.suptitle('Relations between subjects\' characteristics and self identifiability (Original)', y=1.1, size = 30)
plt.tight_layout()
plt.show()

# %%
# Plot relations between group, age, gender, dominant hand -and- identifiability
fig, axs = plt.subplots(1,4, figsize=(35, 8), sharey=True)
fig.subplots_adjust(hspace = .2, wspace = .2)
axs = axs.ravel()

# Age
axs[0].scatter(subs_omega['age'].values, subs_omega['pca_identifiability'].values)    
axs[0].set_title('Age vs Identifiability', fontsize = 20)
axs[0].set_xlabel('Age', fontsize = 15)
axs[0].set_ylabel('Self Identifiability', fontsize = 15)

# Gender
sns.violinplot(x = 'Gender', y = 'pca_identifiability', data = subs_omega, ax = axs[1])
axs[1].set_xlabel('Gender', fontsize = 15)
axs[1].set_xticklabels(['Male','Female'], fontsize = 15)
axs[1].set_ylabel('')
axs[1].set_title('Gender vs Identifiability', fontsize = 20)


# Dominant hand
sns.violinplot(x = 'Dominant Hand', y = 'pca_identifiability', data = subs_omega, ax = axs[2])
axs[2].set_ylabel('')
axs[2].set_xlabel('Dominant Hand', fontsize = 15)
axs[2].set_xticklabels(['Right','Left', 'Other'], fontsize = 15)
axs[2].set_title('Dominant Hand vs Identifiability', fontsize = 20)

# Group
sns.violinplot(x = 'Group', y = 'pca_identifiability', data = subs_omega, ax = axs[3])
axs[3].set_ylabel('')
axs[3].set_xlabel('Group', fontsize = 15)
axs[3].set_xticklabels(['Control','Other'], fontsize = 15)
axs[3].set_title('Group vs Identifiability', fontsize = 20)

plt.suptitle('Relations between subjects\' characteristics and self identifiability (Reconstructed)', y=1.1, size = 30)
plt.tight_layout()
plt.show()

# %% [markdown]
# # V. Sanity checks: Identifiability as a function of summary statistics for motion, cardiac activity, and eye movements

# %%
# First we get a big data frame
sanity_check = pd.read_csv('dependencies/eog_ecg_motion.csv')
sanity_check = sanity_check.head(n_subs)
sanity_check['self_id'] = self_id
sanity_check['pca_self_id'] = pca_self_id

# Plot relations between motion, ecg, eog -and- identifiability
fig, axs = plt.subplots(1,3, figsize=(35, 8))
fig.subplots_adjust(hspace = .2, wspace = .2)
axs = axs.ravel()

# Motion
axs[0].scatter(sanity_check['motion'].values, sanity_check['self_id'].values)    
axs[0].set_title('Motion vs Identifiability', fontsize = 20)
axs[0].set_xlabel('Motion [m]', fontsize = 15)
axs[0].set_ylabel('Self Identifiability', fontsize = 15)

# ECG
axs[1].scatter(sanity_check['ecg'].values, sanity_check['self_id'].values)    
axs[1].set_title('ECG vs Identifiability', fontsize = 20)
axs[1].set_xlabel('ECG [vµ]', fontsize = 15)
axs[1].set_ylabel('Self Identifiability', fontsize = 15)

# EOG
axs[2].scatter(sanity_check['eog'].values, sanity_check['self_id'].values)    
axs[2].set_title('EOG vs Identifiability', fontsize = 20)
axs[2].set_xlabel('EOG [vµ]', fontsize = 15)
axs[2].set_ylabel('Self Identifiability', fontsize = 15)

plt.suptitle('Relations between measured artifacts and self identifiability (Original)', y=1.1, size = 30)
plt.tight_layout()
plt.show()

# %%
# Plot relations between motion, ecg, eog -and- identifiability
fig, axs = plt.subplots(1,3, figsize=(35, 8))
fig.subplots_adjust(hspace = .2, wspace = .2)
axs = axs.ravel()

# Motion
axs[0].scatter(sanity_check['motion'].values, sanity_check['pca_self_id'].values)    
axs[0].set_title('Motion vs Identifiability', fontsize = 20)
axs[0].set_xlabel('Motion [m]', fontsize = 15)
axs[0].set_ylabel('Self Identifiability', fontsize = 15)

# ECG
axs[1].scatter(sanity_check['ecg'].values, sanity_check['pca_self_id'].values)    
axs[1].set_title('ECG vs Identifiability', fontsize = 20)
axs[1].set_xlabel('ECG [vµ]', fontsize = 15)
axs[1].set_ylabel('Self Identifiability', fontsize = 15)

# EOG
axs[2].scatter(sanity_check['eog'].values, sanity_check['pca_self_id'].values)    
axs[2].set_title('EOG vs Identifiability', fontsize = 20)
axs[2].set_xlabel('EOG [vµ]', fontsize = 15)
axs[2].set_ylabel('Self Identifiability', fontsize = 15)

plt.suptitle('Relations between measured artifacts and self identifiability (Reconstructed)', y=1.1, size = 30)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10, 10))
axs = sns.regplot(subs_omega['identifiability'].values, subs_omega['pca_identifiability'].values)
axs.set_title('Self-identifiability: Original and Reconstructed Space', size = 'x-large')
sns.despine()
plt.show()
