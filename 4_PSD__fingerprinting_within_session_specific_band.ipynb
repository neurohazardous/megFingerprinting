# %% [markdown]
# ## License
# This file is part of the project megFingerprinting. All of megFingerprinting code is free software: you can redistribute it and/or modify it under the terms of the GNU General Public License as published by the Free Software Foundation, either version 3 of the License, or (at your option) any later version. megFingerprinting is distributed in the hope that it will be useful, but WITHOUT ANY WARRANTY; without even the implied warranty of MERCHANTABILITY or FITNESS FOR A PARTICULAR PURPOSE. See the GNU General Public License for more details. You should have received a copy of the GNU General Public License along with megFingerprinting. If not, see https://www.gnu.org/licenses/.

# %%
import difflib
from fuzzywuzzy import fuzz
import matplotlib.pyplot as plt
from mpl_toolkits.axes_grid1 import make_axes_locatable
import numpy as np
from os import listdir
from os.path import isfile, join
import pandas as pd
import re
import seaborn as sns
import scipy as sp
import scipy.io as sio
from sklearn.decomposition import PCA
from sklearn.metrics import accuracy_score
sns.set()
sns.set_style("whitegrid")
sns.set_palette(sns.color_palette("husl", 8))
# Out:
# /Users/jasondsc/opt/anaconda3/lib/python3.7/site-packages/fuzzywuzzy/fuzz.py:11: UserWarning: Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning
#   warnings.warn('Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning')

# %% [markdown]
# # I. Subject Identifiability: Original Feature Space vs PCA Reconstructed
#
# ## Select frequency band folder and adjust number of features

# %%
# Parameters
n_subs = 158 # Change here to get number of participants! 
nfreq= 34
n_feats = int(68*nfreq) # 201 hgamma   40 gamma    10 alpha    8 theta   8 delta  34 beta
n_measurements = 2

# %%
# Warangle data set into two big feature matrices
def prune_subject_csv(filename):
    '''
    This function takes in the subject's csv file from MATLAB, takes out the 
    doubled correlations (because of symmetry) and outputs a numpy array ready to be concatenated
    in the grand feature matrix
    Args:
        filename (string): Name of the csv matrix
    Returns: 
        sub_feat (np.array): Subject's features 
    '''
    #print(filename)
    print(filename[29:33])
    n_feats = int(68*nfreq)
    sub_feat = np.zeros([1, (n_feats)+1]) # Number of unique values in corr matrix + subject label
    psd_matrix = pd.read_csv(filename, header=None)
    mat=np.asmatrix(psd_matrix)
    sub_feat[0, :-1]=mat.flatten()
    sub_feat[0, -1] = int(filename[28:32])    
    return sub_feat


# Get n subjects: both training and testing datasets
onlyfiles = [f for f in listdir('output/Sources_PSD/beta/') if isfile(join('output/Sources_PSD/beta/', f))]
sub_target = np.zeros([n_subs, (n_feats)+1])
sub_database = np.zeros([n_subs, (n_feats)+1])
iv = 0
it = 0
for iFile in sorted(onlyfiles)[0:(n_subs*2)]: 
    sub = 'output/Sources_PSD/beta/' + iFile
    print(sub)
    if sub[39] == 'v':
        sub_target[iv, :] = prune_subject_csv(sub)
        iv += 1
    else:
        sub_database[it, :] = prune_subject_csv(sub)
        it += 1
# Out:
# output/Sources_PSD/beta/sub_0001_beta__training.csv
# 001_
# output/Sources_PSD/beta/sub_0001_beta__validation.csv
# 001_
# output/Sources_PSD/beta/sub_0002_beta__training.csv
# 002_
# output/Sources_PSD/beta/sub_0002_beta__validation.csv
# 002_
# output/Sources_PSD/beta/sub_0003_beta__training.csv
# 003_
# output/Sources_PSD/beta/sub_0003_beta__validation.csv
# 003_
# output/Sources_PSD/beta/sub_0004_beta__training.csv
# 004_
# output/Sources_PSD/beta/sub_0004_beta__validation.csv
# 004_
# output/Sources_PSD/beta/sub_0005_beta__training.csv
# 005_
# output/Sources_PSD/beta/sub_0005_beta__validation.csv
# 005_
# output/Sources_PSD/beta/sub_0006_beta__training.csv
# 006_
# output/Sources_PSD/beta/sub_0006_beta__validation.csv
# 006_
# output/Sources_PSD/beta/sub_0007_beta__training.csv
# 007_
# output/Sources_PSD/beta/sub_0007_beta__validation.csv
# 007_
# output/Sources_PSD/beta/sub_0008_beta__training.csv
# 008_
# output/Sources_PSD/beta/sub_0008_beta__validation.csv
# 008_
# output/Sources_PSD/beta/sub_0009_beta__training.csv
# 009_
# output/Sources_PSD/beta/sub_0009_beta__validation.csv
# 009_
# output/Sources_PSD/beta/sub_0011_beta__training.csv
# 011_
# output/Sources_PSD/beta/sub_0011_beta__validation.csv
# 011_
# output/Sources_PSD/beta/sub_0012_beta__training.csv
# 012_
# output/Sources_PSD/beta/sub_0012_beta__validation.csv
# 012_
# output/Sources_PSD/beta/sub_0013_beta__training.csv
# 013_
# output/Sources_PSD/beta/sub_0013_beta__validation.csv
# 013_
# output/Sources_PSD/beta/sub_0014_beta__training.csv
# 014_
# output/Sources_PSD/beta/sub_0014_beta__validation.csv
# 014_
# output/Sources_PSD/beta/sub_0015_beta__training.csv
# 015_
# output/Sources_PSD/beta/sub_0015_beta__validation.csv
# 015_
# output/Sources_PSD/beta/sub_0016_beta__training.csv
# 016_
# output/Sources_PSD/beta/sub_0016_beta__validation.csv
# 016_
# output/Sources_PSD/beta/sub_0018_beta__training.csv
# 018_
# output/Sources_PSD/beta/sub_0018_beta__validation.csv
# 018_
# output/Sources_PSD/beta/sub_0020_beta__training.csv
# 020_
# output/Sources_PSD/beta/sub_0020_beta__validation.csv
# 020_
# output/Sources_PSD/beta/sub_0021_beta__training.csv
# 021_
# output/Sources_PSD/beta/sub_0021_beta__validation.csv
# 021_
# output/Sources_PSD/beta/sub_0022_beta__training.csv
# 022_
# output/Sources_PSD/beta/sub_0022_beta__validation.csv
# 022_
# output/Sources_PSD/beta/sub_0023_beta__training.csv
# 023_
# output/Sources_PSD/beta/sub_0023_beta__validation.csv
# 023_
# output/Sources_PSD/beta/sub_0024_beta__training.csv
# 024_
# output/Sources_PSD/beta/sub_0024_beta__validation.csv
# 024_
# output/Sources_PSD/beta/sub_0025_beta__training.csv
# 025_
# output/Sources_PSD/beta/sub_0025_beta__validation.csv
# 025_
# output/Sources_PSD/beta/sub_0026_beta__training.csv
# 026_
# output/Sources_PSD/beta/sub_0026_beta__validation.csv
# 026_
# output/Sources_PSD/beta/sub_0028_beta__training.csv
# 028_
# output/Sources_PSD/beta/sub_0028_beta__validation.csv
# 028_
# output/Sources_PSD/beta/sub_0029_beta__training.csv
# 029_
# output/Sources_PSD/beta/sub_0029_beta__validation.csv
# 029_
# output/Sources_PSD/beta/sub_0030_beta__training.csv
# 030_
# output/Sources_PSD/beta/sub_0030_beta__validation.csv
# 030_
# output/Sources_PSD/beta/sub_0031_beta__training.csv
# 031_
# output/Sources_PSD/beta/sub_0031_beta__validation.csv
# 031_
# output/Sources_PSD/beta/sub_0032_beta__training.csv
# 032_
# output/Sources_PSD/beta/sub_0032_beta__validation.csv
# 032_
# output/Sources_PSD/beta/sub_0033_beta__training.csv
# 033_
# output/Sources_PSD/beta/sub_0033_beta__validation.csv
# 033_
# output/Sources_PSD/beta/sub_0035_beta__training.csv
# 035_
# output/Sources_PSD/beta/sub_0035_beta__validation.csv
# 035_
# output/Sources_PSD/beta/sub_0036_beta__training.csv
# 036_
# output/Sources_PSD/beta/sub_0036_beta__validation.csv
# 036_
# output/Sources_PSD/beta/sub_0037_beta__training.csv
# 037_
# output/Sources_PSD/beta/sub_0037_beta__validation.csv
# 037_
# output/Sources_PSD/beta/sub_0040_beta__training.csv
# 040_
# output/Sources_PSD/beta/sub_0040_beta__validation.csv
# 040_
# output/Sources_PSD/beta/sub_0041_beta__training.csv
# 041_
# output/Sources_PSD/beta/sub_0041_beta__validation.csv
# 041_
# output/Sources_PSD/beta/sub_0045_beta__training.csv
# 045_
# output/Sources_PSD/beta/sub_0045_beta__validation.csv
# 045_
# output/Sources_PSD/beta/sub_0046_beta__training.csv
# 046_
# output/Sources_PSD/beta/sub_0046_beta__validation.csv
# 046_
# output/Sources_PSD/beta/sub_0047_beta__training.csv
# 047_
# output/Sources_PSD/beta/sub_0047_beta__validation.csv
# 047_
# output/Sources_PSD/beta/sub_0048_beta__training.csv
# 048_
# output/Sources_PSD/beta/sub_0048_beta__validation.csv
# 048_
# output/Sources_PSD/beta/sub_0049_beta__training.csv
# 049_
# output/Sources_PSD/beta/sub_0049_beta__validation.csv
# 049_
# output/Sources_PSD/beta/sub_0050_beta__training.csv
# 050_
# output/Sources_PSD/beta/sub_0050_beta__validation.csv
# 050_
# output/Sources_PSD/beta/sub_0051_beta__training.csv
# 051_
# output/Sources_PSD/beta/sub_0051_beta__validation.csv
# 051_
# output/Sources_PSD/beta/sub_0052_beta__training.csv
# 052_
# output/Sources_PSD/beta/sub_0052_beta__validation.csv
# 052_
# output/Sources_PSD/beta/sub_0053_beta__training.csv
# 053_
# output/Sources_PSD/beta/sub_0053_beta__validation.csv
# 053_
# output/Sources_PSD/beta/sub_0054_beta__training.csv
# 054_
# output/Sources_PSD/beta/sub_0054_beta__validation.csv
# 054_
# output/Sources_PSD/beta/sub_0055_beta__training.csv
# 055_
# output/Sources_PSD/beta/sub_0055_beta__validation.csv
# 055_
# output/Sources_PSD/beta/sub_0056_beta__training.csv
# 056_
# output/Sources_PSD/beta/sub_0056_beta__validation.csv
# 056_
# output/Sources_PSD/beta/sub_0058_beta__training.csv
# 058_
# output/Sources_PSD/beta/sub_0058_beta__validation.csv
# 058_
# output/Sources_PSD/beta/sub_0059_beta__training.csv
# 059_
# output/Sources_PSD/beta/sub_0059_beta__validation.csv
# 059_
# output/Sources_PSD/beta/sub_0060_beta__training.csv
# 060_
# output/Sources_PSD/beta/sub_0060_beta__validation.csv
# 060_
# output/Sources_PSD/beta/sub_0061_beta__training.csv
# 061_
# output/Sources_PSD/beta/sub_0061_beta__validation.csv
# 061_
# output/Sources_PSD/beta/sub_0062_beta__training.csv
# 062_
# output/Sources_PSD/beta/sub_0062_beta__validation.csv
# 062_
# output/Sources_PSD/beta/sub_0063_beta__training.csv
# 063_
# output/Sources_PSD/beta/sub_0063_beta__validation.csv
# 063_
# output/Sources_PSD/beta/sub_0064_beta__training.csv
# 064_
# output/Sources_PSD/beta/sub_0064_beta__validation.csv
# 064_
# output/Sources_PSD/beta/sub_0065_beta__training.csv
# 065_
# output/Sources_PSD/beta/sub_0065_beta__validation.csv
# 065_
# output/Sources_PSD/beta/sub_0066_beta__training.csv
# 066_
# output/Sources_PSD/beta/sub_0066_beta__validation.csv
# 066_
# output/Sources_PSD/beta/sub_0068_beta__training.csv
# 068_
# output/Sources_PSD/beta/sub_0068_beta__validation.csv
# 068_
# output/Sources_PSD/beta/sub_0069_beta__training.csv
# 069_
# output/Sources_PSD/beta/sub_0069_beta__validation.csv
# 069_
# output/Sources_PSD/beta/sub_0070_beta__training.csv
# 070_
# output/Sources_PSD/beta/sub_0070_beta__validation.csv
# 070_
# output/Sources_PSD/beta/sub_0071_beta__training.csv
# 071_
# output/Sources_PSD/beta/sub_0071_beta__validation.csv
# 071_
# output/Sources_PSD/beta/sub_0074_beta__training.csv
# 074_
# output/Sources_PSD/beta/sub_0074_beta__validation.csv
# 074_
# output/Sources_PSD/beta/sub_0075_beta__training.csv
# 075_
# output/Sources_PSD/beta/sub_0075_beta__validation.csv
# 075_
# output/Sources_PSD/beta/sub_0076_beta__training.csv
# 076_
# output/Sources_PSD/beta/sub_0076_beta__validation.csv
# 076_
# output/Sources_PSD/beta/sub_0077_beta__training.csv
# 077_
# output/Sources_PSD/beta/sub_0077_beta__validation.csv
# 077_
# output/Sources_PSD/beta/sub_0078_beta__training.csv
# 078_
# output/Sources_PSD/beta/sub_0078_beta__validation.csv
# 078_
# output/Sources_PSD/beta/sub_0079_beta__training.csv
# 079_
# output/Sources_PSD/beta/sub_0079_beta__validation.csv
# 079_
# output/Sources_PSD/beta/sub_0080_beta__training.csv
# 080_
# output/Sources_PSD/beta/sub_0080_beta__validation.csv
# 080_
# output/Sources_PSD/beta/sub_0082_beta__training.csv
# 082_
# output/Sources_PSD/beta/sub_0082_beta__validation.csv
# 082_
# output/Sources_PSD/beta/sub_0083_beta__training.csv
# 083_
# output/Sources_PSD/beta/sub_0083_beta__validation.csv
# 083_
# output/Sources_PSD/beta/sub_0084_beta__training.csv
# 084_
# output/Sources_PSD/beta/sub_0084_beta__validation.csv
# 084_
# output/Sources_PSD/beta/sub_0085_beta__training.csv
# 085_
# output/Sources_PSD/beta/sub_0085_beta__validation.csv
# 085_
# output/Sources_PSD/beta/sub_0086_beta__training.csv
# 086_
# output/Sources_PSD/beta/sub_0086_beta__validation.csv
# 086_
# output/Sources_PSD/beta/sub_0087_beta__training.csv
# 087_
# output/Sources_PSD/beta/sub_0087_beta__validation.csv
# 087_
# output/Sources_PSD/beta/sub_0088_beta__training.csv
# 088_
# output/Sources_PSD/beta/sub_0088_beta__validation.csv
# 088_
# output/Sources_PSD/beta/sub_0089_beta__training.csv
# 089_
# output/Sources_PSD/beta/sub_0089_beta__validation.csv
# 089_
# output/Sources_PSD/beta/sub_0090_beta__training.csv
# 090_
# output/Sources_PSD/beta/sub_0090_beta__validation.csv
# 090_
# output/Sources_PSD/beta/sub_0091_beta__training.csv
# 091_
# output/Sources_PSD/beta/sub_0091_beta__validation.csv
# 091_
# output/Sources_PSD/beta/sub_0093_beta__training.csv
# 093_
# output/Sources_PSD/beta/sub_0093_beta__validation.csv
# 093_
# output/Sources_PSD/beta/sub_0094_beta__training.csv
# 094_
# output/Sources_PSD/beta/sub_0094_beta__validation.csv
# 094_
# output/Sources_PSD/beta/sub_0095_beta__training.csv
# 095_
# output/Sources_PSD/beta/sub_0095_beta__validation.csv
# 095_
# output/Sources_PSD/beta/sub_0096_beta__training.csv
# 096_
# output/Sources_PSD/beta/sub_0096_beta__validation.csv
# 096_
# output/Sources_PSD/beta/sub_0097_beta__training.csv
# 097_
# output/Sources_PSD/beta/sub_0097_beta__validation.csv
# 097_
# output/Sources_PSD/beta/sub_0098_beta__training.csv
# 098_
# output/Sources_PSD/beta/sub_0098_beta__validation.csv
# 098_
# output/Sources_PSD/beta/sub_0099_beta__training.csv
# 099_
# output/Sources_PSD/beta/sub_0099_beta__validation.csv
# 099_
# output/Sources_PSD/beta/sub_0101_beta__training.csv
# 101_
# output/Sources_PSD/beta/sub_0101_beta__validation.csv
# 101_
# output/Sources_PSD/beta/sub_0102_beta__training.csv
# 102_
# output/Sources_PSD/beta/sub_0102_beta__validation.csv
# 102_
# output/Sources_PSD/beta/sub_0103_beta__training.csv
# 103_
# output/Sources_PSD/beta/sub_0103_beta__validation.csv
# 103_
# output/Sources_PSD/beta/sub_0105_beta__training.csv
# 105_
# output/Sources_PSD/beta/sub_0105_beta__validation.csv
# 105_
# output/Sources_PSD/beta/sub_0106_beta__training.csv
# 106_
# output/Sources_PSD/beta/sub_0106_beta__validation.csv
# 106_
# output/Sources_PSD/beta/sub_0108_beta__training.csv
# 108_
# output/Sources_PSD/beta/sub_0108_beta__validation.csv
# 108_
# output/Sources_PSD/beta/sub_0109_beta__training.csv
# 109_
# output/Sources_PSD/beta/sub_0109_beta__validation.csv
# 109_
# output/Sources_PSD/beta/sub_0110_beta__training.csv
# 110_
# output/Sources_PSD/beta/sub_0110_beta__validation.csv
# 110_
# output/Sources_PSD/beta/sub_0111_beta__training.csv
# 111_
# output/Sources_PSD/beta/sub_0111_beta__validation.csv
# 111_
# output/Sources_PSD/beta/sub_0112_beta__training.csv
# 112_
# output/Sources_PSD/beta/sub_0112_beta__validation.csv
# 112_
# output/Sources_PSD/beta/sub_0114_beta__training.csv
# 114_
# output/Sources_PSD/beta/sub_0114_beta__validation.csv
# 114_
# output/Sources_PSD/beta/sub_0116_beta__training.csv
# 116_
# output/Sources_PSD/beta/sub_0116_beta__validation.csv
# 116_
# output/Sources_PSD/beta/sub_0117_beta__training.csv
# 117_
# output/Sources_PSD/beta/sub_0117_beta__validation.csv
# 117_
# output/Sources_PSD/beta/sub_0118_beta__training.csv
# 118_
# output/Sources_PSD/beta/sub_0118_beta__validation.csv
# 118_
# output/Sources_PSD/beta/sub_0119_beta__training.csv
# 119_
# output/Sources_PSD/beta/sub_0119_beta__validation.csv
# 119_
# output/Sources_PSD/beta/sub_0120_beta__training.csv
# 120_
# output/Sources_PSD/beta/sub_0120_beta__validation.csv
# 120_
# output/Sources_PSD/beta/sub_0121_beta__training.csv
# 121_
# output/Sources_PSD/beta/sub_0121_beta__validation.csv
# 121_
# output/Sources_PSD/beta/sub_0123_beta__training.csv
# 123_
# output/Sources_PSD/beta/sub_0123_beta__validation.csv
# 123_
# output/Sources_PSD/beta/sub_0125_beta__training.csv
# 125_
# output/Sources_PSD/beta/sub_0125_beta__validation.csv
# 125_
# output/Sources_PSD/beta/sub_0126_beta__training.csv
# 126_
# output/Sources_PSD/beta/sub_0126_beta__validation.csv
# 126_
# output/Sources_PSD/beta/sub_0127_beta__training.csv
# 127_
# output/Sources_PSD/beta/sub_0127_beta__validation.csv
# 127_
# output/Sources_PSD/beta/sub_0128_beta__training.csv
# 128_
# output/Sources_PSD/beta/sub_0128_beta__validation.csv
# 128_
# output/Sources_PSD/beta/sub_0129_beta__training.csv
# 129_
# output/Sources_PSD/beta/sub_0129_beta__validation.csv
# 129_
# output/Sources_PSD/beta/sub_0130_beta__training.csv
# 130_
# output/Sources_PSD/beta/sub_0130_beta__validation.csv
# 130_
# output/Sources_PSD/beta/sub_0131_beta__training.csv
# 131_
# output/Sources_PSD/beta/sub_0131_beta__validation.csv
# 131_
# output/Sources_PSD/beta/sub_0132_beta__training.csv
# 132_
# output/Sources_PSD/beta/sub_0132_beta__validation.csv
# 132_
# output/Sources_PSD/beta/sub_0133_beta__training.csv
# 133_
# output/Sources_PSD/beta/sub_0133_beta__validation.csv
# 133_
# output/Sources_PSD/beta/sub_0134_beta__training.csv
# 134_
# output/Sources_PSD/beta/sub_0134_beta__validation.csv
# 134_
# output/Sources_PSD/beta/sub_0135_beta__training.csv
# 135_
# output/Sources_PSD/beta/sub_0135_beta__validation.csv
# 135_
# output/Sources_PSD/beta/sub_0136_beta__training.csv
# 136_
# output/Sources_PSD/beta/sub_0136_beta__validation.csv
# 136_
# output/Sources_PSD/beta/sub_0139_beta__training.csv
# 139_
# output/Sources_PSD/beta/sub_0139_beta__validation.csv
# 139_
# output/Sources_PSD/beta/sub_0140_beta__training.csv
# 140_
# output/Sources_PSD/beta/sub_0140_beta__validation.csv
# 140_
# output/Sources_PSD/beta/sub_0141_beta__training.csv
# 141_
# output/Sources_PSD/beta/sub_0141_beta__validation.csv
# 141_
# output/Sources_PSD/beta/sub_0142_beta__training.csv
# 142_
# output/Sources_PSD/beta/sub_0142_beta__validation.csv
# 142_
# output/Sources_PSD/beta/sub_0143_beta__training.csv
# 143_
# output/Sources_PSD/beta/sub_0143_beta__validation.csv
# 143_
# output/Sources_PSD/beta/sub_0144_beta__training.csv
# 144_
# output/Sources_PSD/beta/sub_0144_beta__validation.csv
# 144_
# output/Sources_PSD/beta/sub_0145_beta__training.csv
# 145_
# output/Sources_PSD/beta/sub_0145_beta__validation.csv
# 145_
# output/Sources_PSD/beta/sub_0146_beta__training.csv
# 146_
# output/Sources_PSD/beta/sub_0146_beta__validation.csv
# 146_
# output/Sources_PSD/beta/sub_0147_beta__training.csv
# 147_
# output/Sources_PSD/beta/sub_0147_beta__validation.csv
# 147_
# output/Sources_PSD/beta/sub_0148_beta__training.csv
# 148_
# output/Sources_PSD/beta/sub_0148_beta__validation.csv
# 148_
# output/Sources_PSD/beta/sub_0149_beta__training.csv
# 149_
# output/Sources_PSD/beta/sub_0149_beta__validation.csv
# 149_
# output/Sources_PSD/beta/sub_0150_beta__training.csv
# 150_
# output/Sources_PSD/beta/sub_0150_beta__validation.csv
# 150_
# output/Sources_PSD/beta/sub_0151_beta__training.csv
# 151_
# output/Sources_PSD/beta/sub_0151_beta__validation.csv
# 151_
# output/Sources_PSD/beta/sub_0152_beta__training.csv
# 152_
# output/Sources_PSD/beta/sub_0152_beta__validation.csv
# 152_
# output/Sources_PSD/beta/sub_0154_beta__training.csv
# 154_
# output/Sources_PSD/beta/sub_0154_beta__validation.csv
# 154_
# output/Sources_PSD/beta/sub_0155_beta__training.csv
# 155_
# output/Sources_PSD/beta/sub_0155_beta__validation.csv
# 155_
# output/Sources_PSD/beta/sub_0156_beta__training.csv
# 156_
# output/Sources_PSD/beta/sub_0156_beta__validation.csv
# 156_
# output/Sources_PSD/beta/sub_0157_beta__training.csv
# 157_
# output/Sources_PSD/beta/sub_0157_beta__validation.csv
# 157_
# output/Sources_PSD/beta/sub_0158_beta__training.csv
# 158_
# output/Sources_PSD/beta/sub_0158_beta__validation.csv
# 158_
# output/Sources_PSD/beta/sub_0159_beta__training.csv
# 159_
# output/Sources_PSD/beta/sub_0159_beta__validation.csv
# 159_
# output/Sources_PSD/beta/sub_0160_beta__training.csv
# 160_
# output/Sources_PSD/beta/sub_0160_beta__validation.csv
# 160_
# output/Sources_PSD/beta/sub_0161_beta__training.csv
# 161_
# output/Sources_PSD/beta/sub_0161_beta__validation.csv
# 161_
# output/Sources_PSD/beta/sub_0162_beta__training.csv
# 162_
# output/Sources_PSD/beta/sub_0162_beta__validation.csv
# 162_
# output/Sources_PSD/beta/sub_0164_beta__training.csv
# 164_
# output/Sources_PSD/beta/sub_0164_beta__validation.csv
# 164_
# output/Sources_PSD/beta/sub_0165_beta__training.csv
# 165_
# output/Sources_PSD/beta/sub_0165_beta__validation.csv
# 165_
# output/Sources_PSD/beta/sub_0166_beta__training.csv
# 166_
# output/Sources_PSD/beta/sub_0166_beta__validation.csv
# 166_
# output/Sources_PSD/beta/sub_0167_beta__training.csv
# 167_
# output/Sources_PSD/beta/sub_0167_beta__validation.csv
# 167_
# output/Sources_PSD/beta/sub_0168_beta__training.csv
# 168_
# output/Sources_PSD/beta/sub_0168_beta__validation.csv
# 168_
# output/Sources_PSD/beta/sub_0169_beta__training.csv
# 169_
# output/Sources_PSD/beta/sub_0169_beta__validation.csv
# 169_
# output/Sources_PSD/beta/sub_0170_beta__training.csv
# 170_
# output/Sources_PSD/beta/sub_0170_beta__validation.csv
# 170_
# output/Sources_PSD/beta/sub_0172_beta__training.csv
# 172_
# output/Sources_PSD/beta/sub_0172_beta__validation.csv
# 172_
# output/Sources_PSD/beta/sub_0174_beta__training.csv
# 174_
# output/Sources_PSD/beta/sub_0174_beta__validation.csv
# 174_
# output/Sources_PSD/beta/sub_0175_beta__training.csv
# 175_
# output/Sources_PSD/beta/sub_0175_beta__validation.csv
# 175_
# output/Sources_PSD/beta/sub_0176_beta__training.csv
# 176_
# output/Sources_PSD/beta/sub_0176_beta__validation.csv
# 176_
# output/Sources_PSD/beta/sub_0177_beta__training.csv
# 177_
# output/Sources_PSD/beta/sub_0177_beta__validation.csv
# 177_
# output/Sources_PSD/beta/sub_0179_beta__training.csv
# 179_
# output/Sources_PSD/beta/sub_0179_beta__validation.csv
# 179_
# output/Sources_PSD/beta/sub_0181_beta__training.csv
# 181_
# output/Sources_PSD/beta/sub_0181_beta__validation.csv
# 181_
# output/Sources_PSD/beta/sub_0183_beta__training.csv
# 183_
# output/Sources_PSD/beta/sub_0183_beta__validation.csv
# 183_
# output/Sources_PSD/beta/sub_0184_beta__training.csv
# 184_
# output/Sources_PSD/beta/sub_0184_beta__validation.csv
# 184_
# output/Sources_PSD/beta/sub_0185_beta__training.csv
# 185_
# output/Sources_PSD/beta/sub_0185_beta__validation.csv
# 185_
# output/Sources_PSD/beta/sub_0186_beta__training.csv
# 186_
# output/Sources_PSD/beta/sub_0186_beta__validation.csv
# 186_
# output/Sources_PSD/beta/sub_0187_beta__training.csv
# 187_
# output/Sources_PSD/beta/sub_0187_beta__validation.csv
# 187_
# output/Sources_PSD/beta/sub_0188_beta__training.csv
# 188_
# output/Sources_PSD/beta/sub_0188_beta__validation.csv
# 188_
# output/Sources_PSD/beta/sub_0189_beta__training.csv
# 189_
# output/Sources_PSD/beta/sub_0189_beta__validation.csv
# 189_
# output/Sources_PSD/beta/sub_0190_beta__training.csv
# 190_
# output/Sources_PSD/beta/sub_0190_beta__validation.csv
# 190_

# %%
# Correlations can be computed as the dot product between two z-scored vectors
z_target = sp.stats.zscore(sub_target[:, :-1], axis = 1)
z_database = sp.stats.zscore(sub_database[:,:-1], axis = 1)
predictions = z_target.dot(z_database.transpose()) / (sub_database.shape[1] - 1) # target, database
target_from_database = accuracy_score(range(n_subs), predictions.argmax(axis = 1))
database_from_target = accuracy_score(range(n_subs), predictions.argmax(axis = 0))

print('When predicting the target from the database, we get a ' + str(target_from_database*100)[0:5] + '% accuracy')
print('When predicting the database from the target, we get a ' + str(database_from_target*100)[0:5] + '% accuracy')
# Out:
# When predicting the target from the database, we get a 96.20% accuracy
# When predicting the database from the target, we get a 95.56% accuracy

# %% [markdown]
# # We get pretty high raw accuracy scores (similar to what Finn et al., 2015). Now we look at the influence of using a PCA reconstruction (i.e. the framework Amico & Goni suggested) on the feature space

# %%
# Take feature matrix of each subject and put it in one, big matrix (n_subs * 2, features)
fc = np.concatenate((sub_target[:, :-1], sub_database[:, :-1]), axis = 0)
labels = np.concatenate((sub_target[:, -1], sub_database[:, -1]), axis = 0)
steps = np.concatenate((np.array([2, 5]), np.arange(10, (n_subs*2) ,10)), axis = 0) # 2, 5, 10 - n_subs*2 in 10 
pca_target_from_database = np.zeros(len(steps))
pca_database_from_target = np.zeros(len(steps))
pca_self_id = np.zeros((len(steps), n_subs))
# Get the PCA decomposition in an iterative manner and calculate raw accuracy at each step of the way 
for i in range(len(steps)):
    # PCA reconstruction usin i components
    pca = PCA(n_components = steps[i]) 
    pca.fit(fc) # Estimate the components (using an SVD on the centered fc)
    fc_pca = pca.transform(fc) # Calculate the loadings
    fc_recon = pca.inverse_transform(fc_pca) # Get projection onto components in signal space and add back means
    
    # Accuracy and self-identifiability
    pca_sub_target = fc_recon[:n_subs, :]
    pca_sub_database = fc_recon[n_subs:, :]
    pca_z_target = sp.stats.zscore(pca_sub_target, axis = 1)
    pca_z_database = sp.stats.zscore(pca_sub_database, axis = 1)
    pca_predictions = pca_z_target.dot(pca_z_database.transpose()) / (sub_database.shape[1] - 1) # target, database
    pca_target_from_database[i] = accuracy_score(range(n_subs), pca_predictions.argmax(axis = 1))
    pca_database_from_target[i] = accuracy_score(range(n_subs), pca_predictions.argmax(axis = 0))
    pca_self_id[i, :] = np.diagonal(sp.stats.zscore(pca_predictions, axis = 1))
    
# For the figure, we also get self-identifiability and reconstructed self-identifiability
self_id = np.diagonal(sp.stats.zscore(predictions, axis = 1))

# %%
# Get the fig initiated
fig, axs = plt.subplots(1,3, figsize=(30, 10))
fig.subplots_adjust(hspace = .2, wspace = .2)
axs = axs.ravel()

# Variance explained vs Components
axs[0].plot(pca.explained_variance_ratio_*100, linewidth=2)
axs[0].set_xlabel('Components')
axs[0].set_ylabel('Variance Explained [%]')
axs[0].set_title('PCA reconstruction', size = 'x-large')

# Accuracy vs Components
axs[1].plot(steps, pca_target_from_database*100, linewidth = 2, label = 'Reconstructed')
axs[1].plot(steps, target_from_database.repeat(len(steps))*100, linewidth = 2, label = 'Original')
axs[1].set_xlabel('Components')
axs[1].set_ylabel('Accuracy [%]')
axs[1].set_title('Accuracy as a function of PCs', size = 'x-large')
axs[1].legend(fontsize = 13, frameon = True)

# Self identifiability vs Components
axs[2].plot(steps, pca_self_id.mean(axis = 1), linewidth = 2, label = 'Reconstructed')
axs[2].plot(steps, self_id.mean().repeat(len(steps)), linewidth = 2, label = 'Original')
axs[2].set_xlabel('Components')
axs[2].set_ylabel('Self identifiability')
axs[2].set_title('Self-Identifiability as a function of PCs', size = 'x-large')
axs[2].legend(fontsize = 13, frameon = True)

sns.despine()
plt.show()

# %%
# Get the PCA reconstruction from the number of components that give us the max self_identifiability 
pca = PCA(n_components = steps[np.argmax(pca_self_id.mean(axis = 1))]) 
pca.fit(fc) # Estimate the components (using an SVD on the centered fc)
fc_pca = pca.transform(fc) # Calculate the loadings
fc_recon = pca.inverse_transform(fc_pca) # Get projection onto components in signal space

# Accuracy and self-identifiability
pca_sub_target = fc_recon[:n_subs, :]
pca_sub_database = fc_recon[n_subs:, :]
pca_z_target = sp.stats.zscore(pca_sub_target, axis = 1)
pca_z_database = sp.stats.zscore(pca_sub_database, axis = 1)
pca_predictions = pca_z_target.dot(pca_z_database.transpose()) / (sub_database.shape[1] - 1) # target, database
pca_target_from_database = accuracy_score(range(n_subs), pca_predictions.argmax(axis = 1))
pca_database_from_target = accuracy_score(range(n_subs), pca_predictions.argmax(axis = 0))
pca_self_id = np.diagonal(sp.stats.zscore(pca_predictions, axis = 1))

print('When predicting the reconstructed target from the reconstructed database, we get a ' + str(pca_target_from_database) + ' accuracy')
print('When predicting the reconstructed database from the reconstructed target, we get a ' + str(pca_database_from_target) + ' accuracy')
# Out:
# When predicting the reconstructed target from the reconstructed database, we get a 0.9683544303797469 accuracy
# When predicting the reconstructed database from the reconstructed target, we get a 0.9556962025316456 accuracy

# %%
import numpy as np
vp_original = np.concatenate((np.expand_dims(self_id, axis = 1), np.expand_dims(np.repeat('Original', n_subs), axis = 1)), axis = 1)
vp_recon = np.concatenate((np.expand_dims(pca_self_id, axis = 1), np.expand_dims(np.repeat('Reconstructed', n_subs), axis = 1)), axis = 1)
self_id_grand = np.concatenate((vp_original, vp_recon), axis = 0)
self_id_plot = pd.DataFrame(data = self_id_grand, columns = ['Self Identifiability', 'Feature Space'])
self_id_plot['Self Identifiability'] = self_id_plot['Self Identifiability'].astype(float)
self_id_plot['Feature Space'] = self_id_plot['Feature Space'].astype('category', ordered = False, categories = ['Original', 'Reconstructed'])

plt.figure(figsize=(10, 10))
axs = sns.violinplot(x = 'Feature Space', y = 'Self Identifiability', data = self_id_plot)
axs.set_title('Self-identifiability: Original and Reconstructed Space', size = 'x-large')
sns.despine()
plt.show()


plt.figure(figsize=(10, 10))
axs = sns.heatmap(predictions, cmap='Reds', square=True)
plt.figure(figsize=(10, 10))
axs = sns.heatmap(pca_predictions, cmap='Reds', square=True)
# Out:
# /Users/jasondsc/opt/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3331: FutureWarning: specifying 'categories' or 'ordered' in .astype() is deprecated; pass a CategoricalDtype instead
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %% [markdown]
# # IV. Identifiability as a function of subjects' characteristics

# %%
# First we get subject number
def subs_list(sub):
    if sub < 10:
        return 'sub-000' + sub.astype(int).astype(str)
    elif sub >= 10 and sub < 100:
        return 'sub-00' + sub.astype(int).astype(str)
    else: 
        return 'sub-0' + sub.astype(int).astype(str)
    
    
# Get subject data from 
subs_analyzed = list(map(subs_list, sub_target[:, -1]))
subs_omega = pd.read_csv('data/OMEGA_BIDS/participants.csv', sep=',', header=0)
subs_omega = subs_omega[subs_omega['participants_id'].isin(subs_analyzed)]

# Wrangle data to get subjecs' age
sub_age = list(subs_omega['X.session.age.'].values)
for x in range(len(sub_age)):
    if isinstance(sub_age[x], str):
        sub_age[x] = sub_age[x][3:5]
    if (sub_age[x]==""):
        sub_age[x] = np.nan
        
sub_age = np.array(sub_age).astype(float)
age_mean = np.floor(np.nanmean(sub_age))
inds = np.where(np.isnan(sub_age))
sub_age[inds] = age_mean
subs_omega['X.session.age.'] = sub_age
subs_omega = subs_omega.rename(columns={'X.session.age.': 'age'})


# Wrangle data to get subjects' group
sub_group = list(subs_omega['Group'].values)
for x in range(len(sub_group)):
    if isinstance(sub_group[x], str):
        if sub_group[x] != 'Control':
            sub_group[x] = 'Spec'
    else:
        sub_group[x] = 'Control' # The most common label here is 'Control', so I decided to handles NaN's that way
subs_omega['Group'] = sub_group

sub_time= list(subs_omega['time_of_record'].values)
subs_omega['time_of_record']= sub_time

# Do some final wrangling before plotting relationshisp between variables and 
subs_omega['identifiability'] = self_id
subs_omega['pca_identifiability'] = pca_self_id
subs_omega = subs_omega.rename(columns={'Dominant.Hand': 'Dominant Hand'})
subs_omega = subs_omega.drop(['Year.of.birth', 'Questionnaire.Version'], axis = 1)

# %%
# Plot relations between group, age, gender, dominant hand -and- identifiability
fig, axs = plt.subplots(1,4, figsize=(35, 8), sharey=True)
fig.subplots_adjust(hspace = .2, wspace = .2)
axs = axs.ravel()

# Age
axs[0].scatter(subs_omega['age'].values, subs_omega['identifiability'].values)    
axs[0].set_title('Age vs Identifiability', fontsize = 20)
axs[0].set_xlabel('Age', fontsize = 15)
axs[0].set_ylabel('Self Identifiability', fontsize = 15)

# Gender
sns.violinplot(x = 'Gender', y = 'identifiability', data = subs_omega, ax = axs[1])
axs[1].set_xlabel('Gender', fontsize = 15)
axs[1].set_xticklabels(['Male','Female'], fontsize = 15)
axs[1].set_ylabel('')
axs[1].set_title('Gender vs Identifiability', fontsize = 20)


# Dominant hand
sns.violinplot(x = 'Dominant Hand', y = 'identifiability', data = subs_omega, ax = axs[2])
axs[2].set_ylabel('')
axs[2].set_xlabel('Dominant Hand', fontsize = 15)
axs[2].set_xticklabels(['Right','Left', 'Other'], fontsize = 15)
axs[2].set_title('Dominant Hand vs Identifiability', fontsize = 20)

# Group
sns.violinplot(x = 'Group', y = 'identifiability', data = subs_omega, ax = axs[3])
axs[3].set_ylabel('')
axs[3].set_xlabel('Group', fontsize = 15)
axs[3].set_xticklabels(['Control','Other'], fontsize = 15)
axs[3].set_title('Group vs Identifiability', fontsize = 20)

plt.suptitle('Relations between subjects\' characteristics and self identifiability (Original)', y=1.1, size = 30)
plt.tight_layout()
plt.show()

# %%
# Plot relations between group, age, gender, dominant hand -and- identifiability
fig, axs = plt.subplots(1,4, figsize=(35, 8), sharey=True)
fig.subplots_adjust(hspace = .2, wspace = .2)
axs = axs.ravel()

# Age
axs[0].scatter(subs_omega['age'].values, subs_omega['pca_identifiability'].values)    
axs[0].set_title('Age vs Identifiability', fontsize = 20)
axs[0].set_xlabel('Age', fontsize = 15)
axs[0].set_ylabel('Self Identifiability', fontsize = 15)

# Gender
sns.violinplot(x = 'Gender', y = 'pca_identifiability', data = subs_omega, ax = axs[1])
axs[1].set_xlabel('Gender', fontsize = 15)
axs[1].set_xticklabels(['Male','Female'], fontsize = 15)
axs[1].set_ylabel('')
axs[1].set_title('Gender vs Identifiability', fontsize = 20)


# Dominant hand
sns.violinplot(x = 'Dominant Hand', y = 'pca_identifiability', data = subs_omega, ax = axs[2])
axs[2].set_ylabel('')
axs[2].set_xlabel('Dominant Hand', fontsize = 15)
axs[2].set_xticklabels(['Right','Left', 'Other'], fontsize = 15)
axs[2].set_title('Dominant Hand vs Identifiability', fontsize = 20)

# Group
sns.violinplot(x = 'Group', y = 'pca_identifiability', data = subs_omega, ax = axs[3])
axs[3].set_ylabel('')
axs[3].set_xlabel('Group', fontsize = 15)
axs[3].set_xticklabels(['Control','Other'], fontsize = 15)
axs[3].set_title('Group vs Identifiability', fontsize = 20)

plt.suptitle('Relations between subjects\' characteristics and self identifiability (Reconstructed)', y=1.1, size = 30)
plt.tight_layout()
plt.show()

# %% [markdown]
# # V. Sanity checks: Identifiability as a function of summary statistics for motion, cardiac activity, and eye movements

# %%
# First we get a big data frame
sanity_check = pd.read_csv('dependencies/eog_ecg_motion.csv')
sanity_check = sanity_check.head(n_subs)
sanity_check['self_id'] = self_id
sanity_check['pca_self_id'] = pca_self_id

# Plot relations between motion, ecg, eog -and- identifiability
fig, axs = plt.subplots(1,3, figsize=(35, 8))
fig.subplots_adjust(hspace = .2, wspace = .2)
axs = axs.ravel()

# Motion
axs[0].scatter(sanity_check['motion'].values, sanity_check['self_id'].values)    
axs[0].set_title('Motion vs Identifiability', fontsize = 20)
axs[0].set_xlabel('Motion [m]', fontsize = 15)
axs[0].set_ylabel('Self Identifiability', fontsize = 15)

# ECG
axs[1].scatter(sanity_check['ecg'].values, sanity_check['self_id'].values)    
axs[1].set_title('ECG vs Identifiability', fontsize = 20)
axs[1].set_xlabel('ECG [vµ]', fontsize = 15)
axs[1].set_ylabel('Self Identifiability', fontsize = 15)

# EOG
axs[2].scatter(sanity_check['eog'].values, sanity_check['self_id'].values)    
axs[2].set_title('EOG vs Identifiability', fontsize = 20)
axs[2].set_xlabel('EOG [vµ]', fontsize = 15)
axs[2].set_ylabel('Self Identifiability', fontsize = 15)

plt.suptitle('Relations between measured artifacts and self identifiability (Original)', y=1.1, size = 30)
plt.tight_layout()
plt.show()

# %%
# Plot relations between motion, ecg, eog -and- identifiability
fig, axs = plt.subplots(1,3, figsize=(35, 8))
fig.subplots_adjust(hspace = .2, wspace = .2)
axs = axs.ravel()

# Motion
axs[0].scatter(sanity_check['motion'].values, sanity_check['pca_self_id'].values)    
axs[0].set_title('Motion vs Identifiability', fontsize = 20)
axs[0].set_xlabel('Motion [m]', fontsize = 15)
axs[0].set_ylabel('Self Identifiability', fontsize = 15)

# ECG
axs[1].scatter(sanity_check['ecg'].values, sanity_check['pca_self_id'].values)    
axs[1].set_title('ECG vs Identifiability', fontsize = 20)
axs[1].set_xlabel('ECG [vµ]', fontsize = 15)
axs[1].set_ylabel('Self Identifiability', fontsize = 15)

# EOG
axs[2].scatter(sanity_check['eog'].values, sanity_check['pca_self_id'].values)    
axs[2].set_title('EOG vs Identifiability', fontsize = 20)
axs[2].set_xlabel('EOG [vµ]', fontsize = 15)
axs[2].set_ylabel('Self Identifiability', fontsize = 15)

plt.suptitle('Relations between measured artifacts and self identifiability (Reconstructed)', y=1.1, size = 30)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10, 10))
axs = sns.regplot(subs_omega['identifiability'].values, subs_omega['pca_identifiability'].values)
axs.set_title('Self-identifiability: Original and Reconstructed Space', size = 'x-large')
sns.despine()
plt.show()

# %%
# Plot rduration of recording identifiability
plt.figure(figsize=(10, 10))
axs = sns.regplot(subs_omega['time_of_record'].values, subs_omega['identifiability'].values)
axs.set_title('Duration of recording and self-identifiability', size = 'x-large')
sns.despine()
plt.show()
